# %% [markdown]
# # **Max Stack**
#
# A **Max Stack** is a specialized stack data structure that supports all the operations of a normal stack (push, pop, peek) and additionally provides a way to retrieve the maximum element in the stack in constant time O(1).
#
# **Key Features:**
# - All standard stack operations (push, pop, peek)
# - **getMax()**: Returns the maximum element in constant time O(1)
# - LIFO (Last In First Out) ordering maintained
# - Efficient tracking of maximum element across all operations
# - Can be implemented using arrays or linked lists
#
# **Why Max Stack?**
# In regular stacks, finding the maximum element requires O(n) time as we need to traverse all elements. Max Stack optimizes this to O(1) by maintaining additional information about the maximum elements.
#
# **Common Applications:**
# - **Performance monitoring**: Track peak CPU usage, memory consumption
# - **Trading systems**: Monitor highest stock prices, trading volumes
# - **Gaming**: Track high scores, maximum damage values
# - **Data analysis**: Real-time maximum tracking in streaming data
# - **Resource management**: Monitor peak resource usage
# - **Quality control**: Track maximum error rates, response times
#
# **Real-world Examples:**
# - **System monitoring**: Track peak CPU/memory usage in real-time
# - **Financial systems**: Monitor highest transaction values
# - **Gaming leaderboards**: Maintain high score tracking
# - **Network analysis**: Track maximum bandwidth usage
# - **Performance benchmarking**: Monitor peak performance metrics
# - **Quality assurance**: Track maximum error rates or response times

# %% [markdown]
# ## Max Stack Implementation Approaches
#
# There are several approaches to implement Max Stack:
#
# ### 1. **Two Stack Approach**
# - **Main Stack**: Stores actual elements
# - **Max Stack**: Stores maximum elements corresponding to each state
# - Space efficient but requires two data structures
#
# ### 2. **Single Stack with Pairs**
# - Store pairs of (element, current_maximum) in one stack
# - More memory per element but simpler conceptually
#
# ### 3. **Single Stack with Encoding**
# - Use mathematical encoding to store both element and maximum info
# - Most space efficient but complex implementation
#
# ### 4. **Auxiliary Maximum Tracking**
# - Maintain separate structure to track maximums
# - Flexible but may require more complex synchronization
#
# **We'll implement approaches 1 and 2 using both arrays and linked lists.**
#
# ## Time Complexity Goals
#
# | Operation | Target Complexity | Standard Stack |
# |-----------|-------------------|----------------|
# | **push()** | O(1) | O(1) |
# | **pop()** | O(1) | O(1) |
# | **peek()** | O(1) | O(1) |
# | **getMax()** | O(1) | O(n) |
# | **isEmpty()** | O(1) | O(1) |

# %%
# Import required libraries
from collections import deque
import sys

# Helper function to display stack contents
def display_stack_contents(stack_data, title="Stack Contents"):
    """Helper function to display stack contents in a readable format"""
    if not stack_data:
        print(f"{title}: Empty")
    else:
        print(f"{title}: {stack_data} (top → bottom)")

print("Max Stack Implementation - Setup Complete")
print("=" * 50)
# Out:
# Max Stack Implementation - Setup Complete
# ==================================================

# %% [markdown]
# ## Approach 1: Two Stack Implementation using Arrays
#
# This approach uses two separate stacks:
# - **Main Stack**: Stores the actual elements
# - **Max Stack**: Stores the maximum element at each state
#
# **Key Insight**: When we push an element, we also push the current maximum to the max_stack. When we pop, we pop from both stacks to maintain synchronization.
#
# **Space Optimization**: Instead of always pushing to max_stack, we only push when we find a new maximum or equal maximum.

# %%
class MaxStackArray:
    def __init__(self, max_size=100):
        """Initialize Max Stack using arrays with two-stack approach"""
        self.max_size = max_size
        
        # Main stack to store actual elements
        self.main_stack = [None] * max_size
        self.main_top = -1
        
        # Max stack to store maximum elements
        self.max_stack = [None] * max_size
        self.max_top = -1
        
        print(f"MaxStackArray initialized with max size: {max_size}")
    
    def is_empty(self):
        """Check if stack is empty"""
        return self.main_top == -1
    
    def is_full(self):
        """Check if stack is full"""
        return self.main_top == self.max_size - 1
    
    def size(self):
        """Return current number of elements"""
        return self.main_top + 1
    
    def push(self, element):
        """Push element to stack and update maximum tracking"""
        if self.is_full():
            raise OverflowError(f"Stack Overflow: Cannot push {element}")
        
        # Push to main stack
        self.main_top += 1
        self.main_stack[self.main_top] = element
        
        # Push to max stack (only if it's new maximum or equal to current maximum)
        if self.max_top == -1 or element >= self.max_stack[self.max_top]:
            self.max_top += 1
            self.max_stack[self.max_top] = element
        
        print(f"Pushed {element} | Current max: {self.get_max()}")
        return True
    
    def pop(self):
        """Pop element from stack and update maximum tracking"""
        if self.is_empty():
            raise IndexError("Stack Underflow: Cannot pop from empty stack")
        
        # Get element from main stack
        popped_element = self.main_stack[self.main_top]
        self.main_stack[self.main_top] = None
        self.main_top -= 1
        
        # Pop from max stack if the popped element was the maximum
        if self.max_top >= 0 and popped_element == self.max_stack[self.max_top]:
            self.max_stack[self.max_top] = None
            self.max_top -= 1
        
        print(f"Popped {popped_element} | Current max: {self.get_max() if not self.is_empty() else 'N/A'}")
        return popped_element
    
    def peek(self):
        """Return top element without removing it"""
        if self.is_empty():
            raise IndexError("Stack is empty: Cannot peek")
        return self.main_stack[self.main_top]
    
    def get_max(self):
        """Return maximum element in O(1) time"""
        if self.max_top == -1:
            raise IndexError("Stack is empty: No maximum element")
        return self.max_stack[self.max_top]
    
    def display(self):
        """Display both stacks for debugging"""
        print("\n--- Max Stack State ---")
        if self.is_empty():
            print("Stack is empty")
            return
        
        # Display main stack
        main_elements = [self.main_stack[i] for i in range(self.main_top + 1)]
        print(f"Main Stack: {main_elements} (bottom → top)")
        
        # Display max stack
        max_elements = [self.max_stack[i] for i in range(self.max_top + 1)]
        print(f"Max Stack:  {max_elements} (bottom → top)")
        
        print(f"Size: {self.size()} | Current Max: {self.get_max()}")
        print("--- End State ---\n")

# Test the Two Stack Array implementation
print("=== Testing MaxStackArray (Two Stack Approach) ===")

max_stack_array = MaxStackArray(10)
max_stack_array.display()

try:
    # Test sequence of operations
    operations = [
        ("push", 5),
        ("push", 2),
        ("push", 8),
        ("push", 10),
        ("push", 3),
        ("push", 10),  # Duplicate maximum
    ]
    
    for op, value in operations:
        if op == "push":
            max_stack_array.push(value)
    
    max_stack_array.display()
    
    # Test pop operations
    print("Testing pop operations:")
    for _ in range(3):
        max_stack_array.pop()
    
    max_stack_array.display()
    
    print(f"Current top: {max_stack_array.peek()}")
    print(f"Current maximum: {max_stack_array.get_max()}")

except (OverflowError, IndexError) as e:
    print(f"Error: {e}")
# Out:
# === Testing MaxStackArray (Two Stack Approach) ===
# MaxStackArray initialized with max size: 10
#
# --- Max Stack State ---
# Stack is empty
# Pushed 5 | Current max: 5
# Pushed 2 | Current max: 5
# Pushed 8 | Current max: 8
# Pushed 10 | Current max: 10
# Pushed 3 | Current max: 10
# Pushed 10 | Current max: 10
#
# --- Max Stack State ---
# Main Stack: [5, 2, 8, 10, 3, 10] (bottom → top)
# Max Stack:  [5, 8, 10, 10] (bottom → top)
# Size: 6 | Current Max: 10
# --- End State ---
#
# Testing pop operations:
# Popped 10 | Current max: 10
# Popped 3 | Current max: 10
# Popped 10 | Current max: 8
#
# --- Max Stack State ---
# Main Stack: [5, 2, 8] (bottom → top)
# Max Stack:  [5, 8] (bottom → top)
# Size: 3 | Current Max: 8
# --- End State ---
#
# Current top: 8
# Current maximum: 8

# %% [markdown]
# ## Approach 2: Single Stack with Pairs using Arrays
#
# This approach uses a single stack where each element is stored as a pair: `(actual_value, maximum_at_this_point)`.
#
# **Advantages:**
# - Simpler conceptually - only one stack to manage
# - Each element knows its maximum context
# - No synchronization issues between two stacks
#
# **Disadvantages:**
# - Higher memory usage - stores maximum with every element
# - More complex element structure

# %%
class MaxStackArrayPairs:
    def __init__(self, max_size=100):
        """Initialize Max Stack using array with single stack storing pairs"""
        self.max_size = max_size
        self.stack = [None] * max_size  # Each element will be (value, max_at_this_point)
        self.top = -1
        
        print(f"MaxStackArrayPairs initialized with max size: {max_size}")
    
    def is_empty(self):
        """Check if stack is empty"""
        return self.top == -1
    
    def is_full(self):
        """Check if stack is full"""
        return self.top == self.max_size - 1
    
    def size(self):
        """Return current number of elements"""
        return self.top + 1
    
    def push(self, element):
        """Push element with its maximum context"""
        if self.is_full():
            raise OverflowError(f"Stack Overflow: Cannot push {element}")
        
        # Determine maximum at this point
        if self.is_empty():
            current_max = element
        else:
            current_max = max(element, self.stack[self.top][1])
        
        # Push as pair (element, maximum_at_this_point)
        self.top += 1
        self.stack[self.top] = (element, current_max)
        
        print(f"Pushed {element} with max context {current_max}")
        return True
    
    def pop(self):
        """Pop element and return the actual value"""
        if self.is_empty():
            raise IndexError("Stack Underflow: Cannot pop from empty stack")
        
        popped_pair = self.stack[self.top]
        self.stack[self.top] = None
        self.top -= 1
        
        popped_value = popped_pair[0]
        print(f"Popped {popped_value} | New max: {self.get_max() if not self.is_empty() else 'N/A'}")
        return popped_value
    
    def peek(self):
        """Return top element's actual value"""
        if self.is_empty():
            raise IndexError("Stack is empty: Cannot peek")
        return self.stack[self.top][0]
    
    def get_max(self):
        """Return maximum element in O(1) time"""
        if self.is_empty():
            raise IndexError("Stack is empty: No maximum element")
        return self.stack[self.top][1]
    
    def display(self):
        """Display stack contents with maximum context"""
        print("\n--- Max Stack (Pairs) State ---")
        if self.is_empty():
            print("Stack is empty")
            return
        
        print("Stack contents (bottom → top):")
        for i in range(self.top + 1):
            value, max_val = self.stack[i]
            marker = " ← TOP" if i == self.top else ""
            print(f"  [{i}] Value: {value}, Max: {max_val}{marker}")
        
        print(f"Size: {self.size()} | Current Max: {self.get_max()}")
        print("--- End State ---\n")

# Test the Single Stack Pairs implementation
print("=== Testing MaxStackArrayPairs (Single Stack with Pairs) ===")

max_stack_pairs = MaxStackArrayPairs(10)
max_stack_pairs.display()

try:
    # Test sequence of operations
    test_values = [3, 5, 2, 8, 1, 10, 4]
    
    print("Pushing values:", test_values)
    for value in test_values:
        max_stack_pairs.push(value)
    
    max_stack_pairs.display()
    
    # Test accessing maximum at different states
    print("Testing maximum tracking:")
    while not max_stack_pairs.is_empty():
        print(f"Top: {max_stack_pairs.peek()}, Max: {max_stack_pairs.get_max()}")
        max_stack_pairs.pop()
    
    max_stack_pairs.display()

except (OverflowError, IndexError) as e:
    print(f"Error: {e}")
# Out:
# === Testing MaxStackArrayPairs (Single Stack with Pairs) ===
# MaxStackArrayPairs initialized with max size: 10
#
# --- Max Stack (Pairs) State ---
# Stack is empty
# Pushing values: [3, 5, 2, 8, 1, 10, 4]
# Pushed 3 with max context 3
# Pushed 5 with max context 5
# Pushed 2 with max context 5
# Pushed 8 with max context 8
# Pushed 1 with max context 8
# Pushed 10 with max context 10
# Pushed 4 with max context 10
#
# --- Max Stack (Pairs) State ---
# Stack contents (bottom → top):
#   [0] Value: 3, Max: 3
#   [1] Value: 5, Max: 5
#   [2] Value: 2, Max: 5
#   [3] Value: 8, Max: 8
#   [4] Value: 1, Max: 8
#   [5] Value: 10, Max: 10
#   [6] Value: 4, Max: 10 ← TOP
# Size: 7 | Current Max: 10
# --- End State ---
#
# Testing maximum tracking:
# Top: 4, Max: 10
# Popped 4 | New max: 10
# Top: 10, Max: 10
# Popped 10 | New max: 8
# Top: 1, Max: 8
# Popped 1 | New max: 8
# Top: 8, Max: 8
# Popped 8 | New max: 5
# Top: 2, Max: 5
# Popped 2 | New max: 5
# Top: 5, Max: 5
# Popped 5 | New max: 3
# Top: 3, Max: 3
# Popped 3 | New max: N/A
#
# --- Max Stack (Pairs) State ---
# Stack is empty

# %% [markdown]
# ## Approach 3: Max Stack using Linked Lists - Two Stack Approach
#
# Now let's implement Max Stack using linked lists. This approach provides dynamic memory allocation and eliminates the risk of stack overflow.
#
# **Advantages of Linked List Approach:**
# - Dynamic size - no fixed capacity limit
# - Memory efficient - allocates only what's needed
# - No stack overflow (except system memory limits)
# - Flexible and scalable

# %%
class Node:
    """Node class for linked list implementation"""
    def __init__(self, data):
        self.data = data
        self.next = None
    
    def __str__(self):
        return str(self.data)

class MaxStackLinkedList:
    def __init__(self):
        """Initialize Max Stack using linked lists with two-stack approach"""
        # Main stack (linked list)
        self.main_top = None
        self.main_size = 0
        
        # Max stack (linked list) 
        self.max_top = None
        self.max_size = 0
        
        print("MaxStackLinkedList initialized")
    
    def is_empty(self):
        """Check if stack is empty"""
        return self.main_top is None
    
    def size(self):
        """Return current number of elements"""
        return self.main_size
    
    def push(self, element):
        """Push element to stack and update maximum tracking"""
        # Push to main stack
        new_main_node = Node(element)
        new_main_node.next = self.main_top
        self.main_top = new_main_node
        self.main_size += 1
        
        # Push to max stack only if it's new maximum or equal to current maximum
        if self.max_top is None or element >= self.max_top.data:
            new_max_node = Node(element)
            new_max_node.next = self.max_top
            self.max_top = new_max_node
            self.max_size += 1
        
        print(f"Pushed {element} | Current max: {self.get_max()}")
        return True
    
    def pop(self):
        """Pop element from stack and update maximum tracking"""
        if self.is_empty():
            raise IndexError("Stack Underflow: Cannot pop from empty stack")
        
        # Pop from main stack
        popped_element = self.main_top.data
        self.main_top = self.main_top.next
        self.main_size -= 1
        
        # Pop from max stack if the popped element was the maximum
        if self.max_top and popped_element == self.max_top.data:
            self.max_top = self.max_top.next
            self.max_size -= 1
        
        print(f"Popped {popped_element} | Current max: {self.get_max() if not self.is_empty() else 'N/A'}")
        return popped_element
    
    def peek(self):
        """Return top element without removing it"""
        if self.is_empty():
            raise IndexError("Stack is empty: Cannot peek")
        return self.main_top.data
    
    def get_max(self):
        """Return maximum element in O(1) time"""
        if self.max_top is None:
            raise IndexError("Stack is empty: No maximum element")
        return self.max_top.data
    
    def _list_to_array(self, head):
        """Helper method to convert linked list to array for display"""
        result = []
        current = head
        while current:
            result.append(current.data)
            current = current.next
        return result
    
    def display(self):
        """Display both stacks for debugging"""
        print("\n--- Max Stack (Linked List) State ---")
        if self.is_empty():
            print("Stack is empty")
            return
        
        # Display main stack
        main_elements = self._list_to_array(self.main_top)
        print(f"Main Stack: {main_elements} (top → bottom)")
        
        # Display max stack
        max_elements = self._list_to_array(self.max_top)
        print(f"Max Stack:  {max_elements} (top → bottom)")
        
        print(f"Size: {self.size()} | Current Max: {self.get_max()}")
        print("--- End State ---\n")

# Test the Linked List implementation
print("=== Testing MaxStackLinkedList (Two Stack Approach) ===")

max_stack_ll = MaxStackLinkedList()
max_stack_ll.display()

try:
    # Test sequence with various patterns
    test_sequence = [1, 5, 2, 10, 3, 10, 15, 8, 15]
    
    print(f"Pushing sequence: {test_sequence}")
    for value in test_sequence:
        max_stack_ll.push(value)
    
    max_stack_ll.display()
    
    # Test popping while tracking maximum
    print("Testing pop operations with maximum tracking:")
    for i in range(5):
        print(f"Before pop - Top: {max_stack_ll.peek()}, Max: {max_stack_ll.get_max()}")
        max_stack_ll.pop()
    
    max_stack_ll.display()
    
    # Add more elements to test dynamic behavior
    print("Adding more elements:")
    for value in [20, 12, 25]:
        max_stack_ll.push(value)
    
    max_stack_ll.display()

except IndexError as e:
    print(f"Error: {e}")
# Out:
# === Testing MaxStackLinkedList (Two Stack Approach) ===
# MaxStackLinkedList initialized
#
# --- Max Stack (Linked List) State ---
# Stack is empty
# Pushing sequence: [1, 5, 2, 10, 3, 10, 15, 8, 15]
# Pushed 1 | Current max: 1
# Pushed 5 | Current max: 5
# Pushed 2 | Current max: 5
# Pushed 10 | Current max: 10
# Pushed 3 | Current max: 10
# Pushed 10 | Current max: 10
# Pushed 15 | Current max: 15
# Pushed 8 | Current max: 15
# Pushed 15 | Current max: 15
#
# --- Max Stack (Linked List) State ---
# Main Stack: [15, 8, 15, 10, 3, 10, 2, 5, 1] (top → bottom)
# Max Stack:  [15, 15, 10, 10, 5, 1] (top → bottom)
# Size: 9 | Current Max: 15
# --- End State ---
#
# Testing pop operations with maximum tracking:
# Before pop - Top: 15, Max: 15
# Popped 15 | Current max: 15
# Before pop - Top: 8, Max: 15
# Popped 8 | Current max: 15
# Before pop - Top: 15, Max: 15
# Popped 15 | Current max: 10
# Before pop - Top: 10, Max: 10
# Popped 10 | Current max: 10
# Before pop - Top: 3, Max: 10
# Popped 3 | Current max: 10
#
# --- Max Stack (Linked List) State ---
# Main Stack: [10, 2, 5, 1] (top → bottom)
# Max Stack:  [10, 5, 1] (top → bottom)
# Size: 4 | Current Max: 10
# --- End State ---
#
# Adding more elements:
# Pushed 20 | Current max: 20
# Pushed 12 | Current max: 20
# Pushed 25 | Current max: 25
#
# --- Max Stack (Linked List) State ---
# Main Stack: [25, 12, 20, 10, 2, 5, 1] (top → bottom)
# Max Stack:  [25, 20, 10, 5, 1] (top → bottom)
# Size: 7 | Current Max: 25
# --- End State ---

# %% [markdown]
# ## Approach 4: Single Stack with Pairs using Linked Lists
#
# This approach uses a single linked list where each node stores both the actual value and the maximum value at that point in the stack.

# %%
class PairNode:
    """Node class that stores both value and maximum context"""
    def __init__(self, value, max_value):
        self.value = value
        self.max_value = max_value
        self.next = None
    
    def __str__(self):
        return f"({self.value}, max:{self.max_value})"

class MaxStackLinkedListPairs:
    def __init__(self):
        """Initialize Max Stack using single linked list with pairs"""
        self.top = None
        self.stack_size = 0
        
        print("MaxStackLinkedListPairs initialized")
    
    def is_empty(self):
        """Check if stack is empty"""
        return self.top is None
    
    def size(self):
        """Return current number of elements"""
        return self.stack_size
    
    def push(self, element):
        """Push element with its maximum context"""
        # Determine maximum at this point
        if self.is_empty():
            current_max = element
        else:
            current_max = max(element, self.top.max_value)
        
        # Create new node with both value and maximum
        new_node = PairNode(element, current_max)
        new_node.next = self.top
        self.top = new_node
        self.stack_size += 1
        
        print(f"Pushed {element} with max context {current_max}")
        return True
    
    def pop(self):
        """Pop element and return the actual value"""
        if self.is_empty():
            raise IndexError("Stack Underflow: Cannot pop from empty stack")
        
        popped_value = self.top.value
        self.top = self.top.next
        self.stack_size -= 1
        
        print(f"Popped {popped_value} | New max: {self.get_max() if not self.is_empty() else 'N/A'}")
        return popped_value
    
    def peek(self):
        """Return top element's actual value"""
        if self.is_empty():
            raise IndexError("Stack is empty: Cannot peek")
        return self.top.value
    
    def get_max(self):
        """Return maximum element in O(1) time"""
        if self.is_empty():
            raise IndexError("Stack is empty: No maximum element")
        return self.top.max_value
    
    def display(self):
        """Display stack contents with maximum context"""
        print("\n--- Max Stack (Linked List Pairs) State ---")
        if self.is_empty():
            print("Stack is empty")
            return
        
        print("Stack contents (top → bottom):")
        current = self.top
        position = 1
        while current:
            marker = " ← TOP" if position == 1 else ""
            print(f"  [{position}] Value: {current.value}, Max: {current.max_value}{marker}")
            current = current.next
            position += 1
        
        print(f"Size: {self.size()} | Current Max: {self.get_max()}")
        print("--- End State ---\n")

# Test the Linked List Pairs implementation
print("=== Testing MaxStackLinkedListPairs (Single Stack with Pairs) ===")

max_stack_ll_pairs = MaxStackLinkedListPairs()
max_stack_ll_pairs.display()

try:
    # Test with ascending and descending patterns
    print("Test 1: Ascending then descending pattern")
    ascending = [1, 5, 10, 15, 20]
    descending = [18, 12, 8, 3]
    
    for value in ascending:
        max_stack_ll_pairs.push(value)
    
    max_stack_ll_pairs.display()
    
    for value in descending:
        max_stack_ll_pairs.push(value)
    
    max_stack_ll_pairs.display()
    
    # Test popping and maximum evolution
    print("Test 2: Pop sequence and observe maximum changes")
    while not max_stack_ll_pairs.is_empty():
        print(f"Current - Top: {max_stack_ll_pairs.peek()}, Max: {max_stack_ll_pairs.get_max()}")
        max_stack_ll_pairs.pop()
        if not max_stack_ll_pairs.is_empty():
            print(f"After pop - Top: {max_stack_ll_pairs.peek()}, Max: {max_stack_ll_pairs.get_max()}")
        print("-" * 30)
    
    max_stack_ll_pairs.display()

except IndexError as e:
    print(f"Error: {e}")
# Out:
# === Testing MaxStackLinkedListPairs (Single Stack with Pairs) ===
# MaxStackLinkedListPairs initialized
#
# --- Max Stack (Linked List Pairs) State ---
# Stack is empty
# Test 1: Ascending then descending pattern
# Pushed 1 with max context 1
# Pushed 5 with max context 5
# Pushed 10 with max context 10
# Pushed 15 with max context 15
# Pushed 20 with max context 20
#
# --- Max Stack (Linked List Pairs) State ---
# Stack contents (top → bottom):
#   [1] Value: 20, Max: 20 ← TOP
#   [2] Value: 15, Max: 15
#   [3] Value: 10, Max: 10
#   [4] Value: 5, Max: 5
#   [5] Value: 1, Max: 1
# Size: 5 | Current Max: 20
# --- End State ---
#
# Pushed 18 with max context 20
# Pushed 12 with max context 20
# Pushed 8 with max context 20
# Pushed 3 with max context 20
#
# --- Max Stack (Linked List Pairs) State ---
# Stack contents (top → bottom):
#   [1] Value: 3, Max: 20 ← TOP
#   [2] Value: 8, Max: 20
#   [3] Value: 12, Max: 20
#   [4] Value: 18, Max: 20
#   [5] Value: 20, Max: 20
#   [6] Value: 15, Max: 15
#   [7] Value: 10, Max: 10
#   [8] Value: 5, Max: 5
#   [9] Value: 1, Max: 1
# Size: 9 | Current Max: 20
# --- End State ---
#
# Test 2: Pop sequence and observe maximum changes
# Current - Top: 3, Max: 20
# Popped 3 | New max: 20
# After pop - Top: 8, Max: 20
# ------------------------------
# Current - Top: 8, Max: 20
# Popped 8 | New max: 20
# After pop - Top: 12, Max: 20
# ------------------------------
# Current - Top: 12, Max: 20
# Popped 12 | New max: 20
# After pop - Top: 18, Max: 20
# ------------------------------
# Current - Top: 18, Max: 20
# Popped 18 | New max: 20
# After pop - Top: 20, Max: 20
# ------------------------------
# Current - Top: 20, Max: 20
# Popped 20 | New max: 15
# After pop - Top: 15, Max: 15
# ------------------------------
# Current - Top: 15, Max: 15
# Popped 15 | New max: 10
# After pop - Top: 10, Max: 10
# ------------------------------
# Current - Top: 10, Max: 10
# Popped 10 | New max: 5
# After pop - Top: 5, Max: 5
# ------------------------------
# Current - Top: 5, Max: 5
# Popped 5 | New max: 1
# After pop - Top: 1, Max: 1
# ------------------------------
# Current - Top: 1, Max: 1
# Popped 1 | New max: N/A
# ------------------------------
#
# --- Max Stack (Linked List Pairs) State ---
# Stack is empty

# %% [markdown]
# ## Advanced Max Stack Operations
#
# Let's implement some additional useful operations that extend the basic Max Stack functionality:
#
# 1. **getSecondMax()**: Get the second maximum element
# 2. **getMin()**: Get the minimum element (bonus feature)
# 3. **getRange()**: Get the difference between max and min
# 4. **popMax()**: Pop elements until we remove the maximum
# 5. **size_above_threshold()**: Count elements above a threshold

# %%
class AdvancedMaxStack:
    """Advanced Max Stack with additional operations"""
    
    def __init__(self):
        self.main_stack = []
        self.max_stack = []
        self.min_stack = []  # Additional stack to track minimum
    
    def push(self, element):
        """Push element with max and min tracking"""
        self.main_stack.append(element)
        
        # Update max stack
        if not self.max_stack or element >= self.max_stack[-1]:
            self.max_stack.append(element)
        
        # Update min stack
        if not self.min_stack or element <= self.min_stack[-1]:
            self.min_stack.append(element)
        
        print(f"Pushed {element} | Max: {self.get_max()} | Min: {self.get_min()}")
    
    def pop(self):
        """Pop element with max and min tracking"""
        if not self.main_stack:
            raise IndexError("Stack is empty")
        
        popped = self.main_stack.pop()
        
        # Update max stack
        if self.max_stack and popped == self.max_stack[-1]:
            self.max_stack.pop()
        
        # Update min stack  
        if self.min_stack and popped == self.min_stack[-1]:
            self.min_stack.pop()
        
        print(f"Popped {popped} | Max: {self.get_max() if self.main_stack else 'N/A'} | Min: {self.get_min() if self.main_stack else 'N/A'}")
        return popped
    
    def get_max(self):
        """Get maximum element"""
        if not self.max_stack:
            raise IndexError("Stack is empty")
        return self.max_stack[-1]
    
    def get_min(self):
        """Get minimum element"""
        if not self.min_stack:
            raise IndexError("Stack is empty")
        return self.min_stack[-1]
    
    def get_second_max(self):
        """Get second maximum element"""
        if len(self.max_stack) < 2:
            # Need to find second maximum from main stack
            if len(set(self.main_stack)) < 2:
                raise ValueError("No second maximum exists")
            
            sorted_unique = sorted(set(self.main_stack), reverse=True)
            return sorted_unique[1]
        
        # If max_stack has multiple entries, second from top might be second max
        # This is a simplified approach - more complex logic needed for complete accuracy
        unique_maxs = list(set(self.max_stack))
        if len(unique_maxs) >= 2:
            unique_maxs.sort(reverse=True)
            return unique_maxs[1]
        else:
            # All elements in max_stack are same, find second max from main_stack
            sorted_unique = sorted(set(self.main_stack), reverse=True)
            return sorted_unique[1] if len(sorted_unique) >= 2 else None
    
    def get_range(self):
        """Get difference between max and min"""
        if not self.main_stack:
            raise IndexError("Stack is empty")
        return self.get_max() - self.get_min()
    
    def pop_max(self):
        """Pop elements until we remove the current maximum"""
        if not self.main_stack:
            raise IndexError("Stack is empty")
        
        target_max = self.get_max()
        popped_elements = []
        
        while self.main_stack:
            popped = self.pop()
            popped_elements.append(popped)
            if popped == target_max:
                break
        
        print(f"Popped elements to remove max {target_max}: {popped_elements}")
        return popped_elements
    
    def size_above_threshold(self, threshold):
        """Count elements above a threshold"""
        return sum(1 for x in self.main_stack if x > threshold)
    
    def display_advanced(self):
        """Display advanced stack state"""
        print("\n--- Advanced Max Stack State ---")
        if not self.main_stack:
            print("Stack is empty")
            return
        
        print(f"Main Stack: {self.main_stack}")
        print(f"Max Stack:  {self.max_stack}")
        print(f"Min Stack:  {self.min_stack}")
        print(f"Current Max: {self.get_max()}")
        print(f"Current Min: {self.get_min()}")
        print(f"Range: {self.get_range()}")
        
        try:
            print(f"Second Max: {self.get_second_max()}")
        except (ValueError, TypeError):
            print("Second Max: Not available")
        
        print(f"Size: {len(self.main_stack)}")
        print("--- End Advanced State ---\n")

# Test Advanced Max Stack
print("=== Testing Advanced Max Stack Operations ===")

adv_stack = AdvancedMaxStack()

try:
    # Test with varied data
    test_data = [5, 12, 8, 20, 3, 20, 15, 6, 20, 10]
    
    print(f"Pushing data: {test_data}")
    for val in test_data:
        adv_stack.push(val)
    
    adv_stack.display_advanced()
    
    # Test advanced operations
    print(f"Elements above threshold 10: {adv_stack.size_above_threshold(10)}")
    print(f"Elements above threshold 15: {adv_stack.size_above_threshold(15)}")
    
    # Test pop_max operation
    print("\nTesting pop_max operation:")
    adv_stack.pop_max()
    adv_stack.display_advanced()
    
    # Test after more pops
    print("Popping 3 more elements:")
    for _ in range(3):
        adv_stack.pop()
    
    adv_stack.display_advanced()

except (IndexError, ValueError) as e:
    print(f"Error: {e}")
# Out:
# === Testing Advanced Max Stack Operations ===
# Pushing data: [5, 12, 8, 20, 3, 20, 15, 6, 20, 10]
# Pushed 5 | Max: 5 | Min: 5
# Pushed 12 | Max: 12 | Min: 5
# Pushed 8 | Max: 12 | Min: 5
# Pushed 20 | Max: 20 | Min: 5
# Pushed 3 | Max: 20 | Min: 3
# Pushed 20 | Max: 20 | Min: 3
# Pushed 15 | Max: 20 | Min: 3
# Pushed 6 | Max: 20 | Min: 3
# Pushed 20 | Max: 20 | Min: 3
# Pushed 10 | Max: 20 | Min: 3
#
# --- Advanced Max Stack State ---
# Main Stack: [5, 12, 8, 20, 3, 20, 15, 6, 20, 10]
# Max Stack:  [5, 12, 20, 20, 20]
# Min Stack:  [5, 3]
# Current Max: 20
# Current Min: 3
# Range: 17
# Second Max: 12
# Size: 10
# --- End Advanced State ---
#
# Elements above threshold 10: 5
# Elements above threshold 15: 3
#
# Testing pop_max operation:
# Popped 10 | Max: 20 | Min: 3
# Popped 20 | Max: 20 | Min: 3
# Popped elements to remove max 20: [10, 20]
#
# --- Advanced Max Stack State ---
# Main Stack: [5, 12, 8, 20, 3, 20, 15, 6]
# Max Stack:  [5, 12, 20, 20]
# Min Stack:  [5, 3]
# Current Max: 20
# Current Min: 3
# Range: 17
# Second Max: 12
# Size: 8
# --- End Advanced State ---
#
# Popping 3 more elements:
# Popped 6 | Max: 20 | Min: 3
# Popped 15 | Max: 20 | Min: 3
# Popped 20 | Max: 20 | Min: 3
#
# --- Advanced Max Stack State ---
# Main Stack: [5, 12, 8, 20, 3]
# Max Stack:  [5, 12, 20]
# Min Stack:  [5, 3]
# Current Max: 20
# Current Min: 3
# Range: 17
# Second Max: 12
# Size: 5
# --- End Advanced State ---

# %% [markdown]
# ## Performance Comparison and Analysis
#
# Let's create a comprehensive comparison of all the Max Stack approaches we've implemented:

# %%
import time
import random

def performance_test():
    """Performance test comparing different Max Stack implementations"""
    
    # Test data
    test_sizes = [100, 500, 1000]
    operations_per_test = 1000
    
    print("=== Performance Comparison ===")
    print(f"Testing with {operations_per_test} operations each")
    print("=" * 60)
    
    for size in test_sizes:
        print(f"\nTest Size: {size} elements")
        print("-" * 40)
        
        # Generate test data
        test_data = [random.randint(1, 1000) for _ in range(size)]
        
        # Test Array Two-Stack approach
        start_time = time.time()
        try:
            stack1 = MaxStackArray(size + 100)  # Extra space for operations
            for val in test_data:
                stack1.push(val)
            
            # Perform mixed operations
            for _ in range(operations_per_test // 4):
                stack1.get_max()
                if not stack1.is_empty():
                    stack1.pop()
                stack1.push(random.randint(1, 1000))
                stack1.get_max()
            
            array_two_time = time.time() - start_time
            print(f"Array Two-Stack:     {array_two_time:.6f} seconds")
        except Exception as e:
            print(f"Array Two-Stack:     Error - {e}")
            array_two_time = float('inf')
        
        # Test Array Pairs approach
        start_time = time.time()
        try:
            stack2 = MaxStackArrayPairs(size + 100)
            for val in test_data:
                stack2.push(val)
            
            # Perform mixed operations
            for _ in range(operations_per_test // 4):
                stack2.get_max()
                if not stack2.is_empty():
                    stack2.pop()
                stack2.push(random.randint(1, 1000))
                stack2.get_max()
            
            array_pairs_time = time.time() - start_time
            print(f"Array Pairs:         {array_pairs_time:.6f} seconds")
        except Exception as e:
            print(f"Array Pairs:         Error - {e}")
            array_pairs_time = float('inf')
        
        # Test LinkedList Two-Stack approach
        start_time = time.time()
        try:
            stack3 = MaxStackLinkedList()
            for val in test_data:
                stack3.push(val)
            
            # Perform mixed operations
            for _ in range(operations_per_test // 4):
                stack3.get_max()
                if not stack3.is_empty():
                    stack3.pop()
                stack3.push(random.randint(1, 1000))
                stack3.get_max()
            
            ll_two_time = time.time() - start_time
            print(f"LinkedList Two-Stack: {ll_two_time:.6f} seconds")
        except Exception as e:
            print(f"LinkedList Two-Stack: Error - {e}")
            ll_two_time = float('inf')
        
        # Test LinkedList Pairs approach
        start_time = time.time()
        try:
            stack4 = MaxStackLinkedListPairs()
            for val in test_data:
                stack4.push(val)
            
            # Perform mixed operations
            for _ in range(operations_per_test // 4):
                stack4.get_max()
                if not stack4.is_empty():
                    stack4.pop()
                stack4.push(random.randint(1, 1000))
                stack4.get_max()
            
            ll_pairs_time = time.time() - start_time
            print(f"LinkedList Pairs:     {ll_pairs_time:.6f} seconds")
        except Exception as e:
            print(f"LinkedList Pairs:     Error - {e}")
            ll_pairs_time = float('inf')
        
        # Find the fastest
        times = {
            'Array Two-Stack': array_two_time,
            'Array Pairs': array_pairs_time,
            'LinkedList Two-Stack': ll_two_time,
            'LinkedList Pairs': ll_pairs_time
        }
        
        fastest = min(times, key=times.get)
        if times[fastest] != float('inf'):
            print(f"Fastest: {fastest}")

# Run performance test
performance_test()
# Out:
# === Performance Comparison ===
# Testing with 1000 operations each
# ============================================================
#
# Test Size: 100 elements
# ----------------------------------------
# MaxStackArray initialized with max size: 200
# Pushed 413 | Current max: 413
# Pushed 175 | Current max: 413
# Pushed 128 | Current max: 413
# Pushed 547 | Current max: 547
# Pushed 160 | Current max: 547
# Pushed 311 | Current max: 547
# Pushed 525 | Current max: 547
# Pushed 891 | Current max: 891
# Pushed 384 | Current max: 891
# Pushed 141 | Current max: 891
# Pushed 603 | Current max: 891
# Pushed 514 | Current max: 891
# Pushed 942 | Current max: 942
# Pushed 315 | Current max: 942
# Pushed 535 | Current max: 942
# Pushed 61 | Current max: 942
# Pushed 622 | Current max: 942
# Pushed 656 | Current max: 942
# Pushed 559 | Current max: 942
# Pushed 947 | Current max: 947
# Pushed 692 | Current max: 947
# Pushed 19 | Current max: 947
# Pushed 915 | Current max: 947
# Pushed 596 | Current max: 947
# Pushed 778 | Current max: 947
# Pushed 359 | Current max: 947
# Pushed 899 | Current max: 947
# Pushed 92 | Current max: 947
# Pushed 93 | Current max: 947
# Pushed 511 | Current max: 947
# Pushed 822 | Current max: 947
# Pushed 248 | Current max: 947
# Pushed 680 | Current max: 947
# Pushed 90 | Current max: 947
# Pushed 1000 | Current max: 1000
# Pushed 688 | Current max: 1000
# Pushed 617 | Current max: 1000
# Pushed 910 | Current max: 1000
# Pushed 930 | Current max: 1000
# Pushed 476 | Current max: 1000
# Pushed 241 | Current max: 1000
# Pushed 74 | Current max: 1000
# Pushed 683 | Current max: 1000
# Pushed 546 | Current max: 1000
# Pushed 421 | Current max: 1000
# Pushed 715 | Current max: 1000
# Pushed 184 | Current max: 1000
# Pushed 955 | Current max: 1000
# Pushed 631 | Current max: 1000
# Pushed 210 | Current max: 1000
# Pushed 337 | Current max: 1000
# Pushed 235 | Current max: 1000
# Pushed 126 | Current max: 1000
# Pushed 737 | Current max: 1000
# Pushed 407 | Current max: 1000
# Pushed 209 | Current max: 1000
# Pushed 114 | Current max: 1000
# Pushed 832 | Current max: 1000
# Pushed 481 | Current max: 1000
# Pushed 847 | Current max: 1000
# Pushed 186 | Current max: 1000
# Pushed 513 | Current max: 1000
# Pushed 684 | Current max: 1000
# Pushed 557 | Current max: 1000
# Pushed 872 | Current max: 1000
# Pushed 22 | Current max: 1000
# Pushed 253 | Current max: 1000
# Pushed 884 | Current max: 1000
# Pushed 905 | Current max: 1000
# Pushed 275 | Current max: 1000
# Pushed 777 | Current max: 1000
# Pushed 355 | Current max: 1000
# Pushed 33 | Current max: 1000
# Pushed 421 | Current max: 1000
# Pushed 941 | Current max: 1000
# Pushed 537 | Current max: 1000
# Pushed 912 | Current max: 1000
# Pushed 272 | Current max: 1000
# Pushed 649 | Current max: 1000
# Pushed 540 | Current max: 1000
# Pushed 375 | Current max: 1000
# Pushed 636 | Current max: 1000
# Pushed 296 | Current max: 1000
# Pushed 860 | Current max: 1000
# Pushed 653 | Current max: 1000
# Pushed 790 | Current max: 1000
# Pushed 199 | Current max: 1000
# Pushed 719 | Current max: 1000
# Pushed 351 | Current max: 1000
# Pushed 484 | Current max: 1000
# Pushed 560 | Current max: 1000
# Pushed 914 | Current max: 1000
# Pushed 920 | Current max: 1000
# Pushed 886 | Current max: 1000
# Pushed 822 | Current max: 1000
# Pushed 660 | Current max: 1000
# Pushed 963 | Current max: 1000
# Pushed 387 | Current max: 1000
# Pushed 785 | Current max: 1000
# Pushed 683 | Current max: 1000
# Popped 683 | Current max: 1000
# Pushed 696 | Current max: 1000
# Popped 696 | Current max: 1000
# Pushed 822 | Current max: 1000
# Popped 822 | Current max: 1000
# Pushed 168 | Current max: 1000
# Popped 168 | Current max: 1000
# Pushed 181 | Current max: 1000
# Popped 181 | Current max: 1000
# Pushed 582 | Current max: 1000
# Popped 582 | Current max: 1000
# Pushed 521 | Current max: 1000
# Popped 521 | Current max: 1000
# Pushed 704 | Current max: 1000
# Popped 704 | Current max: 1000
# Pushed 242 | Current max: 1000
# Popped 242 | Current max: 1000
# Pushed 923 | Current max: 1000
# Popped 923 | Current max: 1000
# Pushed 734 | Current max: 1000
# Popped 734 | Current max: 1000
# Pushed 930 | Current max: 1000
# Popped 930 | Current max: 1000
# Pushed 298 | Current max: 1000
# Popped 298 | Current max: 1000
# Pushed 277 | Current max: 1000
# Popped 277 | Current max: 1000
# Pushed 577 | Current max: 1000
# Popped 577 | Current max: 1000
# Pushed 163 | Current max: 1000
# Popped 163 | Current max: 1000
# Pushed 950 | Current max: 1000
# Popped 950 | Current max: 1000
# Pushed 101 | Current max: 1000
# Popped 101 | Current max: 1000
# Pushed 22 | Current max: 1000
# Popped 22 | Current max: 1000
# Pushed 98 | Current max: 1000
# Popped 98 | Current max: 1000
# Pushed 681 | Current max: 1000
# Popped 681 | Current max: 1000
# Pushed 721 | Current max: 1000
# Popped 721 | Current max: 1000
# Pushed 667 | Current max: 1000
# Popped 667 | Current max: 1000
# Pushed 408 | Current max: 1000
# Popped 408 | Current max: 1000
# Pushed 252 | Current max: 1000
# Popped 252 | Current max: 1000
# Pushed 584 | Current max: 1000
# Popped 584 | Current max: 1000
# Pushed 108 | Current max: 1000
# Popped 108 | Current max: 1000
# Pushed 560 | Current max: 1000
# Popped 560 | Current max: 1000
# Pushed 360 | Current max: 1000
# Popped 360 | Current max: 1000
# Pushed 480 | Current max: 1000
# Popped 480 | Current max: 1000
# Pushed 554 | Current max: 1000
# Popped 554 | Current max: 1000
# Pushed 70 | Current max: 1000
# Popped 70 | Current max: 1000
# Pushed 156 | Current max: 1000
# Popped 156 | Current max: 1000
# Pushed 745 | Current max: 1000
# Popped 745 | Current max: 1000
# Pushed 59 | Current max: 1000
# Popped 59 | Current max: 1000
# Pushed 635 | Current max: 1000
# Popped 635 | Current max: 1000
# Pushed 504 | Current max: 1000
# Popped 504 | Current max: 1000
# Pushed 857 | Current max: 1000
# Popped 857 | Current max: 1000
# Pushed 23 | Current max: 1000
# Popped 23 | Current max: 1000
# Pushed 211 | Current max: 1000
# Popped 211 | Current max: 1000
# Pushed 412 | Current max: 1000
# Popped 412 | Current max: 1000
# Pushed 426 | Current max: 1000
# Popped 426 | Current max: 1000
# Pushed 354 | Current max: 1000
# Popped 354 | Current max: 1000
# Pushed 618 | Current max: 1000
# Popped 618 | Current max: 1000
# Pushed 216 | Current max: 1000
# Popped 216 | Current max: 1000
# Pushed 462 | Current max: 1000
# Popped 462 | Current max: 1000
# Pushed 173 | Current max: 1000
# Popped 173 | Current max: 1000
# Pushed 495 | Current max: 1000
# Popped 495 | Current max: 1000
# Pushed 476 | Current max: 1000
# Popped 476 | Current max: 1000
# Pushed 670 | Current max: 1000
# Popped 670 | Current max: 1000
# Pushed 810 | Current max: 1000
# Popped 810 | Current max: 1000
# Pushed 634 | Current max: 1000
# Popped 634 | Current max: 1000
# Pushed 995 | Current max: 1000
# Popped 995 | Current max: 1000
# Pushed 318 | Current max: 1000
# Popped 318 | Current max: 1000
# Pushed 345 | Current max: 1000
# Popped 345 | Current max: 1000
# Pushed 487 | Current max: 1000
# Popped 487 | Current max: 1000
# Pushed 356 | Current max: 1000
# Popped 356 | Current max: 1000
# Pushed 8 | Current max: 1000
# Popped 8 | Current max: 1000
# Pushed 828 | Current max: 1000
# Popped 828 | Current max: 1000
# Pushed 83 | Current max: 1000
# Popped 83 | Current max: 1000
# Pushed 844 | Current max: 1000
# Popped 844 | Current max: 1000
# Pushed 857 | Current max: 1000
# Popped 857 | Current max: 1000
# Pushed 525 | Current max: 1000
# Popped 525 | Current max: 1000
# Pushed 640 | Current max: 1000
# Popped 640 | Current max: 1000
# Pushed 765 | Current max: 1000
# Popped 765 | Current max: 1000
# Pushed 966 | Current max: 1000
# Popped 966 | Current max: 1000
# Pushed 334 | Current max: 1000
# Popped 334 | Current max: 1000
# Pushed 779 | Current max: 1000
# Popped 779 | Current max: 1000
# Pushed 534 | Current max: 1000
# Popped 534 | Current max: 1000
# Pushed 941 | Current max: 1000
# Popped 941 | Current max: 1000
# Pushed 178 | Current max: 1000
# Popped 178 | Current max: 1000
# Pushed 89 | Current max: 1000
# Popped 89 | Current max: 1000
# Pushed 510 | Current max: 1000
# Popped 510 | Current max: 1000
# Pushed 589 | Current max: 1000
# Popped 589 | Current max: 1000
# Pushed 825 | Current max: 1000
# Popped 825 | Current max: 1000
# Pushed 766 | Current max: 1000
# Popped 766 | Current max: 1000
# Pushed 888 | Current max: 1000
# Popped 888 | Current max: 1000
# Pushed 10 | Current max: 1000
# Popped 10 | Current max: 1000
# Pushed 822 | Current max: 1000
# Popped 822 | Current max: 1000
# Pushed 151 | Current max: 1000
# Popped 151 | Current max: 1000
# Pushed 114 | Current max: 1000
# Popped 114 | Current max: 1000
# Pushed 354 | Current max: 1000
# Popped 354 | Current max: 1000
# Pushed 67 | Current max: 1000
# Popped 67 | Current max: 1000
# Pushed 925 | Current max: 1000
# Popped 925 | Current max: 1000
# Pushed 292 | Current max: 1000
# Popped 292 | Current max: 1000
# Pushed 517 | Current max: 1000
# Popped 517 | Current max: 1000
# Pushed 603 | Current max: 1000
# Popped 603 | Current max: 1000
# Pushed 523 | Current max: 1000
# Popped 523 | Current max: 1000
# Pushed 249 | Current max: 1000
# Popped 249 | Current max: 1000
# Pushed 521 | Current max: 1000
# Popped 521 | Current max: 1000
# Pushed 200 | Current max: 1000
# Popped 200 | Current max: 1000
# Pushed 103 | Current max: 1000
# Popped 103 | Current max: 1000
# Pushed 789 | Current max: 1000
# Popped 789 | Current max: 1000
# Pushed 461 | Current max: 1000
# Popped 461 | Current max: 1000
# Pushed 438 | Current max: 1000
# Popped 438 | Current max: 1000
# Pushed 858 | Current max: 1000
# Popped 858 | Current max: 1000
# Pushed 802 | Current max: 1000
# Popped 802 | Current max: 1000
# Pushed 867 | Current max: 1000
# Popped 867 | Current max: 1000
# Pushed 796 | Current max: 1000
# Popped 796 | Current max: 1000
# Pushed 362 | Current max: 1000
# Popped 362 | Current max: 1000
# Pushed 11 | Current max: 1000
# Popped 11 | Current max: 1000
# Pushed 852 | Current max: 1000
# Popped 852 | Current max: 1000
# Pushed 574 | Current max: 1000
# Popped 574 | Current max: 1000
# Pushed 772 | Current max: 1000
# Popped 772 | Current max: 1000
# Pushed 919 | Current max: 1000
# Popped 919 | Current max: 1000
# Pushed 590 | Current max: 1000
# Popped 590 | Current max: 1000
# Pushed 132 | Current max: 1000
# Popped 132 | Current max: 1000
# Pushed 711 | Current max: 1000
# Popped 711 | Current max: 1000
# Pushed 45 | Current max: 1000
# Popped 45 | Current max: 1000
# Pushed 822 | Current max: 1000
# Popped 822 | Current max: 1000
# Pushed 561 | Current max: 1000
# Popped 561 | Current max: 1000
# Pushed 884 | Current max: 1000
# Popped 884 | Current max: 1000
# Pushed 391 | Current max: 1000
# Popped 391 | Current max: 1000
# Pushed 803 | Current max: 1000
# Popped 803 | Current max: 1000
# Pushed 40 | Current max: 1000
# Popped 40 | Current max: 1000
# Pushed 488 | Current max: 1000
# Popped 488 | Current max: 1000
# Pushed 473 | Current max: 1000
# Popped 473 | Current max: 1000
# Pushed 919 | Current max: 1000
# Popped 919 | Current max: 1000
# Pushed 152 | Current max: 1000
# Popped 152 | Current max: 1000
# Pushed 120 | Current max: 1000
# Popped 120 | Current max: 1000
# Pushed 758 | Current max: 1000
# Popped 758 | Current max: 1000
# Pushed 905 | Current max: 1000
# Popped 905 | Current max: 1000
# Pushed 346 | Current max: 1000
# Popped 346 | Current max: 1000
# Pushed 277 | Current max: 1000
# Popped 277 | Current max: 1000
# Pushed 550 | Current max: 1000
# Popped 550 | Current max: 1000
# Pushed 403 | Current max: 1000
# Popped 403 | Current max: 1000
# Pushed 232 | Current max: 1000
# Popped 232 | Current max: 1000
# Pushed 78 | Current max: 1000
# Popped 78 | Current max: 1000
# Pushed 171 | Current max: 1000
# Popped 171 | Current max: 1000
# Pushed 185 | Current max: 1000
# Popped 185 | Current max: 1000
# Pushed 323 | Current max: 1000
# Popped 323 | Current max: 1000
# Pushed 217 | Current max: 1000
# Popped 217 | Current max: 1000
# Pushed 287 | Current max: 1000
# Popped 287 | Current max: 1000
# Pushed 905 | Current max: 1000
# Popped 905 | Current max: 1000
# Pushed 960 | Current max: 1000
# Popped 960 | Current max: 1000
# Pushed 53 | Current max: 1000
# Popped 53 | Current max: 1000
# Pushed 342 | Current max: 1000
# Popped 342 | Current max: 1000
# Pushed 945 | Current max: 1000
# Popped 945 | Current max: 1000
# Pushed 82 | Current max: 1000
# Popped 82 | Current max: 1000
# Pushed 73 | Current max: 1000
# Popped 73 | Current max: 1000
# Pushed 336 | Current max: 1000
# Popped 336 | Current max: 1000
# Pushed 817 | Current max: 1000
# Popped 817 | Current max: 1000
# Pushed 802 | Current max: 1000
# Popped 802 | Current max: 1000
# Pushed 581 | Current max: 1000
# Popped 581 | Current max: 1000
# Pushed 371 | Current max: 1000
# Popped 371 | Current max: 1000
# Pushed 876 | Current max: 1000
# Popped 876 | Current max: 1000
# Pushed 798 | Current max: 1000
# Popped 798 | Current max: 1000
# Pushed 24 | Current max: 1000
# Popped 24 | Current max: 1000
# Pushed 485 | Current max: 1000
# Popped 485 | Current max: 1000
# Pushed 586 | Current max: 1000
# Popped 586 | Current max: 1000
# Pushed 794 | Current max: 1000
# Popped 794 | Current max: 1000
# Pushed 702 | Current max: 1000
# Popped 702 | Current max: 1000
# Pushed 559 | Current max: 1000
# Popped 559 | Current max: 1000
# Pushed 44 | Current max: 1000
# Popped 44 | Current max: 1000
# Pushed 129 | Current max: 1000
# Popped 129 | Current max: 1000
# Pushed 794 | Current max: 1000
# Popped 794 | Current max: 1000
# Pushed 583 | Current max: 1000
# Popped 583 | Current max: 1000
# Pushed 654 | Current max: 1000
# Popped 654 | Current max: 1000
# Pushed 805 | Current max: 1000
# Popped 805 | Current max: 1000
# Pushed 309 | Current max: 1000
# Popped 309 | Current max: 1000
# Pushed 99 | Current max: 1000
# Popped 99 | Current max: 1000
# Pushed 297 | Current max: 1000
# Popped 297 | Current max: 1000
# Pushed 946 | Current max: 1000
# Popped 946 | Current max: 1000
# Pushed 287 | Current max: 1000
# Popped 287 | Current max: 1000
# Pushed 101 | Current max: 1000
# Popped 101 | Current max: 1000
# Pushed 507 | Current max: 1000
# Popped 507 | Current max: 1000
# Pushed 60 | Current max: 1000
# Popped 60 | Current max: 1000
# Pushed 745 | Current max: 1000
# Popped 745 | Current max: 1000
# Pushed 272 | Current max: 1000
# Popped 272 | Current max: 1000
# Pushed 740 | Current max: 1000
# Popped 740 | Current max: 1000
# Pushed 287 | Current max: 1000
# Popped 287 | Current max: 1000
# Pushed 856 | Current max: 1000
# Popped 856 | Current max: 1000
# Pushed 53 | Current max: 1000
# Popped 53 | Current max: 1000
# Pushed 193 | Current max: 1000
# Popped 193 | Current max: 1000
# Pushed 542 | Current max: 1000
# Popped 542 | Current max: 1000
# Pushed 132 | Current max: 1000
# Popped 132 | Current max: 1000
# Pushed 297 | Current max: 1000
# Popped 297 | Current max: 1000
# Pushed 856 | Current max: 1000
# Popped 856 | Current max: 1000
# Pushed 860 | Current max: 1000
# Popped 860 | Current max: 1000
# Pushed 618 | Current max: 1000
# Popped 618 | Current max: 1000
# Pushed 281 | Current max: 1000
# Popped 281 | Current max: 1000
# Pushed 730 | Current max: 1000
# Popped 730 | Current max: 1000
# Pushed 285 | Current max: 1000
# Popped 285 | Current max: 1000
# Pushed 192 | Current max: 1000
# Popped 192 | Current max: 1000
# Pushed 641 | Current max: 1000
# Popped 641 | Current max: 1000
# Pushed 901 | Current max: 1000
# Popped 901 | Current max: 1000
# Pushed 775 | Current max: 1000
# Popped 775 | Current max: 1000
# Pushed 673 | Current max: 1000
# Popped 673 | Current max: 1000
# Pushed 438 | Current max: 1000
# Popped 438 | Current max: 1000
# Pushed 541 | Current max: 1000
# Popped 541 | Current max: 1000
# Pushed 585 | Current max: 1000
# Popped 585 | Current max: 1000
# Pushed 17 | Current max: 1000
# Popped 17 | Current max: 1000
# Pushed 935 | Current max: 1000
# Popped 935 | Current max: 1000
# Pushed 404 | Current max: 1000
# Popped 404 | Current max: 1000
# Pushed 733 | Current max: 1000
# Popped 733 | Current max: 1000
# Pushed 140 | Current max: 1000
# Popped 140 | Current max: 1000
# Pushed 765 | Current max: 1000
# Popped 765 | Current max: 1000
# Pushed 598 | Current max: 1000
# Popped 598 | Current max: 1000
# Pushed 923 | Current max: 1000
# Popped 923 | Current max: 1000
# Pushed 952 | Current max: 1000
# Popped 952 | Current max: 1000
# Pushed 905 | Current max: 1000
# Popped 905 | Current max: 1000
# Pushed 281 | Current max: 1000
# Popped 281 | Current max: 1000
# Pushed 380 | Current max: 1000
# Popped 380 | Current max: 1000
# Pushed 988 | Current max: 1000
# Popped 988 | Current max: 1000
# Pushed 533 | Current max: 1000
# Popped 533 | Current max: 1000
# Pushed 864 | Current max: 1000
# Popped 864 | Current max: 1000
# Pushed 649 | Current max: 1000
# Popped 649 | Current max: 1000
# Pushed 312 | Current max: 1000
# Popped 312 | Current max: 1000
# Pushed 295 | Current max: 1000
# Popped 295 | Current max: 1000
# Pushed 296 | Current max: 1000
# Popped 296 | Current max: 1000
# Pushed 725 | Current max: 1000
# Popped 725 | Current max: 1000
# Pushed 467 | Current max: 1000
# Popped 467 | Current max: 1000
# Pushed 16 | Current max: 1000
# Popped 16 | Current max: 1000
# Pushed 468 | Current max: 1000
# Popped 468 | Current max: 1000
# Pushed 857 | Current max: 1000
# Popped 857 | Current max: 1000
# Pushed 488 | Current max: 1000
# Popped 488 | Current max: 1000
# Pushed 796 | Current max: 1000
# Popped 796 | Current max: 1000
# Pushed 854 | Current max: 1000
# Popped 854 | Current max: 1000
# Pushed 98 | Current max: 1000
# Popped 98 | Current max: 1000
# Pushed 987 | Current max: 1000
# Popped 987 | Current max: 1000
# Pushed 307 | Current max: 1000
# Popped 307 | Current max: 1000
# Pushed 667 | Current max: 1000
# Popped 667 | Current max: 1000
# Pushed 855 | Current max: 1000
# Popped 855 | Current max: 1000
# Pushed 257 | Current max: 1000
# Popped 257 | Current max: 1000
# Pushed 305 | Current max: 1000
# Popped 305 | Current max: 1000
# Pushed 537 | Current max: 1000
# Popped 537 | Current max: 1000
# Pushed 553 | Current max: 1000
# Popped 553 | Current max: 1000
# Pushed 689 | Current max: 1000
# Popped 689 | Current max: 1000
# Pushed 527 | Current max: 1000
# Popped 527 | Current max: 1000
# Pushed 173 | Current max: 1000
# Popped 173 | Current max: 1000
# Pushed 361 | Current max: 1000
# Popped 361 | Current max: 1000
# Pushed 190 | Current max: 1000
# Popped 190 | Current max: 1000
# Pushed 899 | Current max: 1000
# Popped 899 | Current max: 1000
# Pushed 925 | Current max: 1000
# Popped 925 | Current max: 1000
# Pushed 40 | Current max: 1000
# Popped 40 | Current max: 1000
# Pushed 526 | Current max: 1000
# Popped 526 | Current max: 1000
# Pushed 511 | Current max: 1000
# Popped 511 | Current max: 1000
# Pushed 178 | Current max: 1000
# Popped 178 | Current max: 1000
# Pushed 736 | Current max: 1000
# Popped 736 | Current max: 1000
# Pushed 837 | Current max: 1000
# Popped 837 | Current max: 1000
# Pushed 190 | Current max: 1000
# Popped 190 | Current max: 1000
# Pushed 443 | Current max: 1000
# Popped 443 | Current max: 1000
# Pushed 388 | Current max: 1000
# Popped 388 | Current max: 1000
# Pushed 474 | Current max: 1000
# Popped 474 | Current max: 1000
# Pushed 346 | Current max: 1000
# Popped 346 | Current max: 1000
# Pushed 306 | Current max: 1000
# Popped 306 | Current max: 1000
# Pushed 706 | Current max: 1000
# Popped 706 | Current max: 1000
# Pushed 398 | Current max: 1000
# Popped 398 | Current max: 1000
# Pushed 51 | Current max: 1000
# Popped 51 | Current max: 1000
# Pushed 130 | Current max: 1000
# Popped 130 | Current max: 1000
# Pushed 865 | Current max: 1000
# Array Two-Stack:     0.004620 seconds
# MaxStackArrayPairs initialized with max size: 200
# Pushed 413 with max context 413
# Pushed 175 with max context 413
# Pushed 128 with max context 413
# Pushed 547 with max context 547
# Pushed 160 with max context 547
# Pushed 311 with max context 547
# Pushed 525 with max context 547
# Pushed 891 with max context 891
# Pushed 384 with max context 891
# Pushed 141 with max context 891
# Pushed 603 with max context 891
# Pushed 514 with max context 891
# Pushed 942 with max context 942
# Pushed 315 with max context 942
# Pushed 535 with max context 942
# Pushed 61 with max context 942
# Pushed 622 with max context 942
# Pushed 656 with max context 942
# Pushed 559 with max context 942
# Pushed 947 with max context 947
# Pushed 692 with max context 947
# Pushed 19 with max context 947
# Pushed 915 with max context 947
# Pushed 596 with max context 947
# Pushed 778 with max context 947
# Pushed 359 with max context 947
# Pushed 899 with max context 947
# Pushed 92 with max context 947
# Pushed 93 with max context 947
# Pushed 511 with max context 947
# Pushed 822 with max context 947
# Pushed 248 with max context 947
# Pushed 680 with max context 947
# Pushed 90 with max context 947
# Pushed 1000 with max context 1000
# Pushed 688 with max context 1000
# Pushed 617 with max context 1000
# Pushed 910 with max context 1000
# Pushed 930 with max context 1000
# Pushed 476 with max context 1000
# Pushed 241 with max context 1000
# Pushed 74 with max context 1000
# Pushed 683 with max context 1000
# Pushed 546 with max context 1000
# Pushed 421 with max context 1000
# Pushed 715 with max context 1000
# Pushed 184 with max context 1000
# Pushed 955 with max context 1000
# Pushed 631 with max context 1000
# Pushed 210 with max context 1000
# Pushed 337 with max context 1000
# Pushed 235 with max context 1000
# Pushed 126 with max context 1000
# Pushed 737 with max context 1000
# Pushed 407 with max context 1000
# Pushed 209 with max context 1000
# Pushed 114 with max context 1000
# Pushed 832 with max context 1000
# Pushed 481 with max context 1000
# Pushed 847 with max context 1000
# Pushed 186 with max context 1000
# Pushed 513 with max context 1000
# Pushed 684 with max context 1000
# Pushed 557 with max context 1000
# Pushed 872 with max context 1000
# Pushed 22 with max context 1000
# Pushed 253 with max context 1000
# Pushed 884 with max context 1000
# Pushed 905 with max context 1000
# Pushed 275 with max context 1000
# Pushed 777 with max context 1000
# Pushed 355 with max context 1000
# Pushed 33 with max context 1000
# Pushed 421 with max context 1000
# Pushed 941 with max context 1000
# Pushed 537 with max context 1000
# Pushed 912 with max context 1000
# Pushed 272 with max context 1000
# Pushed 649 with max context 1000
# Pushed 540 with max context 1000
# Pushed 375 with max context 1000
# Pushed 636 with max context 1000
# Pushed 296 with max context 1000
# Pushed 860 with max context 1000
# Pushed 653 with max context 1000
# Pushed 790 with max context 1000
# Pushed 199 with max context 1000
# Pushed 719 with max context 1000
# Pushed 351 with max context 1000
# Pushed 484 with max context 1000
# Pushed 560 with max context 1000
# Pushed 914 with max context 1000
# Pushed 920 with max context 1000
# Pushed 886 with max context 1000
# Pushed 822 with max context 1000
# Pushed 660 with max context 1000
# Pushed 963 with max context 1000
# Pushed 387 with max context 1000
# Pushed 785 with max context 1000
# Pushed 683 with max context 1000
# Popped 683 | New max: 1000
# Pushed 176 with max context 1000
# Popped 176 | New max: 1000
# Pushed 827 with max context 1000
# Popped 827 | New max: 1000
# Pushed 464 with max context 1000
# Popped 464 | New max: 1000
# Pushed 835 with max context 1000
# Popped 835 | New max: 1000
# Pushed 382 with max context 1000
# Popped 382 | New max: 1000
# Pushed 305 with max context 1000
# Popped 305 | New max: 1000
# Pushed 880 with max context 1000
# Popped 880 | New max: 1000
# Pushed 562 with max context 1000
# Popped 562 | New max: 1000
# Pushed 523 with max context 1000
# Popped 523 | New max: 1000
# Pushed 903 with max context 1000
# Popped 903 | New max: 1000
# Pushed 677 with max context 1000
# Popped 677 | New max: 1000
# Pushed 509 with max context 1000
# Popped 509 | New max: 1000
# Pushed 3 with max context 1000
# Popped 3 | New max: 1000
# Pushed 249 with max context 1000
# Popped 249 | New max: 1000
# Pushed 811 with max context 1000
# Popped 811 | New max: 1000
# Pushed 203 with max context 1000
# Popped 203 | New max: 1000
# Pushed 10 with max context 1000
# Popped 10 | New max: 1000
# Pushed 531 with max context 1000
# Popped 531 | New max: 1000
# Pushed 839 with max context 1000
# Popped 839 | New max: 1000
# Pushed 74 with max context 1000
# Popped 74 | New max: 1000
# Pushed 262 with max context 1000
# Popped 262 | New max: 1000
# Pushed 670 with max context 1000
# Popped 670 | New max: 1000
# Pushed 463 with max context 1000
# Popped 463 | New max: 1000
# Pushed 618 with max context 1000
# Popped 618 | New max: 1000
# Pushed 906 with max context 1000
# Popped 906 | New max: 1000
# Pushed 170 with max context 1000
# Popped 170 | New max: 1000
# Pushed 85 with max context 1000
# Popped 85 | New max: 1000
# Pushed 496 with max context 1000
# Popped 496 | New max: 1000
# Pushed 281 with max context 1000
# Popped 281 | New max: 1000
# Pushed 900 with max context 1000
# Popped 900 | New max: 1000
# Pushed 402 with max context 1000
# Popped 402 | New max: 1000
# Pushed 849 with max context 1000
# Popped 849 | New max: 1000
# Pushed 111 with max context 1000
# Popped 111 | New max: 1000
# Pushed 143 with max context 1000
# Popped 143 | New max: 1000
# Pushed 305 with max context 1000
# Popped 305 | New max: 1000
# Pushed 564 with max context 1000
# Popped 564 | New max: 1000
# Pushed 269 with max context 1000
# Popped 269 | New max: 1000
# Pushed 185 with max context 1000
# Popped 185 | New max: 1000
# Pushed 420 with max context 1000
# Popped 420 | New max: 1000
# Pushed 713 with max context 1000
# Popped 713 | New max: 1000
# Pushed 109 with max context 1000
# Popped 109 | New max: 1000
# Pushed 935 with max context 1000
# Popped 935 | New max: 1000
# Pushed 809 with max context 1000
# Popped 809 | New max: 1000
# Pushed 437 with max context 1000
# Popped 437 | New max: 1000
# Pushed 359 with max context 1000
# Popped 359 | New max: 1000
# Pushed 482 with max context 1000
# Popped 482 | New max: 1000
# Pushed 638 with max context 1000
# Popped 638 | New max: 1000
# Pushed 706 with max context 1000
# Popped 706 | New max: 1000
# Pushed 213 with max context 1000
# Popped 213 | New max: 1000
# Pushed 825 with max context 1000
# Popped 825 | New max: 1000
# Pushed 102 with max context 1000
# Popped 102 | New max: 1000
# Pushed 669 with max context 1000
# Popped 669 | New max: 1000
# Pushed 696 with max context 1000
# Popped 696 | New max: 1000
# Pushed 82 with max context 1000
# Popped 82 | New max: 1000
# Pushed 562 with max context 1000
# Popped 562 | New max: 1000
# Pushed 377 with max context 1000
# Popped 377 | New max: 1000
# Pushed 400 with max context 1000
# Popped 400 | New max: 1000
# Pushed 216 with max context 1000
# Popped 216 | New max: 1000
# Pushed 884 with max context 1000
# Popped 884 | New max: 1000
# Pushed 955 with max context 1000
# Popped 955 | New max: 1000
# Pushed 42 with max context 1000
# Popped 42 | New max: 1000
# Pushed 422 with max context 1000
# Popped 422 | New max: 1000
# Pushed 420 with max context 1000
# Popped 420 | New max: 1000
# Pushed 293 with max context 1000
# Popped 293 | New max: 1000
# Pushed 866 with max context 1000
# Popped 866 | New max: 1000
# Pushed 682 with max context 1000
# Popped 682 | New max: 1000
# Pushed 982 with max context 1000
# Popped 982 | New max: 1000
# Pushed 784 with max context 1000
# Popped 784 | New max: 1000
# Pushed 38 with max context 1000
# Popped 38 | New max: 1000
# Pushed 554 with max context 1000
# Popped 554 | New max: 1000
# Pushed 672 with max context 1000
# Popped 672 | New max: 1000
# Pushed 106 with max context 1000
# Popped 106 | New max: 1000
# Pushed 987 with max context 1000
# Popped 987 | New max: 1000
# Pushed 26 with max context 1000
# Popped 26 | New max: 1000
# Pushed 311 with max context 1000
# Popped 311 | New max: 1000
# Pushed 815 with max context 1000
# Popped 815 | New max: 1000
# Pushed 6 with max context 1000
# Popped 6 | New max: 1000
# Pushed 577 with max context 1000
# Popped 577 | New max: 1000
# Pushed 242 with max context 1000
# Popped 242 | New max: 1000
# Pushed 344 with max context 1000
# Popped 344 | New max: 1000
# Pushed 937 with max context 1000
# Popped 937 | New max: 1000
# Pushed 426 with max context 1000
# Popped 426 | New max: 1000
# Pushed 117 with max context 1000
# Popped 117 | New max: 1000
# Pushed 196 with max context 1000
# Popped 196 | New max: 1000
# Pushed 203 with max context 1000
# Popped 203 | New max: 1000
# Pushed 728 with max context 1000
# Popped 728 | New max: 1000
# Pushed 306 with max context 1000
# Popped 306 | New max: 1000
# Pushed 674 with max context 1000
# Popped 674 | New max: 1000
# Pushed 598 with max context 1000
# Popped 598 | New max: 1000
# Pushed 435 with max context 1000
# Popped 435 | New max: 1000
# Pushed 86 with max context 1000
# Popped 86 | New max: 1000
# Pushed 479 with max context 1000
# Popped 479 | New max: 1000
# Pushed 67 with max context 1000
# Popped 67 | New max: 1000
# Pushed 424 with max context 1000
# Popped 424 | New max: 1000
# Pushed 906 with max context 1000
# Popped 906 | New max: 1000
# Pushed 409 with max context 1000
# Popped 409 | New max: 1000
# Pushed 552 with max context 1000
# Popped 552 | New max: 1000
# Pushed 741 with max context 1000
# Popped 741 | New max: 1000
# Pushed 660 with max context 1000
# Popped 660 | New max: 1000
# Pushed 917 with max context 1000
# Popped 917 | New max: 1000
# Pushed 773 with max context 1000
# Popped 773 | New max: 1000
# Pushed 705 with max context 1000
# Popped 705 | New max: 1000
# Pushed 210 with max context 1000
# Popped 210 | New max: 1000
# Pushed 71 with max context 1000
# Popped 71 | New max: 1000
# Pushed 152 with max context 1000
# Popped 152 | New max: 1000
# Pushed 534 with max context 1000
# Popped 534 | New max: 1000
# Pushed 977 with max context 1000
# Popped 977 | New max: 1000
# Pushed 989 with max context 1000
# Popped 989 | New max: 1000
# Pushed 56 with max context 1000
# Popped 56 | New max: 1000
# Pushed 840 with max context 1000
# Popped 840 | New max: 1000
# Pushed 588 with max context 1000
# Popped 588 | New max: 1000
# Pushed 751 with max context 1000
# Popped 751 | New max: 1000
# Pushed 858 with max context 1000
# Popped 858 | New max: 1000
# Pushed 931 with max context 1000
# Popped 931 | New max: 1000
# Pushed 392 with max context 1000
# Popped 392 | New max: 1000
# Pushed 155 with max context 1000
# Popped 155 | New max: 1000
# Pushed 748 with max context 1000
# Popped 748 | New max: 1000
# Pushed 496 with max context 1000
# Popped 496 | New max: 1000
# Pushed 126 with max context 1000
# Popped 126 | New max: 1000
# Pushed 311 with max context 1000
# Popped 311 | New max: 1000
# Pushed 300 with max context 1000
# Popped 300 | New max: 1000
# Pushed 499 with max context 1000
# Popped 499 | New max: 1000
# Pushed 17 with max context 1000
# Popped 17 | New max: 1000
# Pushed 140 with max context 1000
# Popped 140 | New max: 1000
# Pushed 98 with max context 1000
# Popped 98 | New max: 1000
# Pushed 30 with max context 1000
# Popped 30 | New max: 1000
# Pushed 809 with max context 1000
# Popped 809 | New max: 1000
# Pushed 276 with max context 1000
# Popped 276 | New max: 1000
# Pushed 801 with max context 1000
# Popped 801 | New max: 1000
# Pushed 322 with max context 1000
# Popped 322 | New max: 1000
# Pushed 15 with max context 1000
# Popped 15 | New max: 1000
# Pushed 524 with max context 1000
# Popped 524 | New max: 1000
# Pushed 475 with max context 1000
# Popped 475 | New max: 1000
# Pushed 879 with max context 1000
# Popped 879 | New max: 1000
# Pushed 10 with max context 1000
# Popped 10 | New max: 1000
# Pushed 571 with max context 1000
# Popped 571 | New max: 1000
# Pushed 968 with max context 1000
# Popped 968 | New max: 1000
# Pushed 7 with max context 1000
# Popped 7 | New max: 1000
# Pushed 328 with max context 1000
# Popped 328 | New max: 1000
# Pushed 92 with max context 1000
# Popped 92 | New max: 1000
# Pushed 675 with max context 1000
# Popped 675 | New max: 1000
# Pushed 354 with max context 1000
# Popped 354 | New max: 1000
# Pushed 652 with max context 1000
# Popped 652 | New max: 1000
# Pushed 33 with max context 1000
# Popped 33 | New max: 1000
# Pushed 13 with max context 1000
# Popped 13 | New max: 1000
# Pushed 831 with max context 1000
# Popped 831 | New max: 1000
# Pushed 705 with max context 1000
# Popped 705 | New max: 1000
# Pushed 492 with max context 1000
# Popped 492 | New max: 1000
# Pushed 661 with max context 1000
# Popped 661 | New max: 1000
# Pushed 592 with max context 1000
# Popped 592 | New max: 1000
# Pushed 16 with max context 1000
# Popped 16 | New max: 1000
# Pushed 855 with max context 1000
# Popped 855 | New max: 1000
# Pushed 517 with max context 1000
# Popped 517 | New max: 1000
# Pushed 16 with max context 1000
# Popped 16 | New max: 1000
# Pushed 20 with max context 1000
# Popped 20 | New max: 1000
# Pushed 353 with max context 1000
# Popped 353 | New max: 1000
# Pushed 227 with max context 1000
# Popped 227 | New max: 1000
# Pushed 137 with max context 1000
# Popped 137 | New max: 1000
# Pushed 994 with max context 1000
# Popped 994 | New max: 1000
# Pushed 938 with max context 1000
# Popped 938 | New max: 1000
# Pushed 704 with max context 1000
# Popped 704 | New max: 1000
# Pushed 194 with max context 1000
# Popped 194 | New max: 1000
# Pushed 487 with max context 1000
# Popped 487 | New max: 1000
# Pushed 878 with max context 1000
# Popped 878 | New max: 1000
# Pushed 382 with max context 1000
# Popped 382 | New max: 1000
# Pushed 910 with max context 1000
# Popped 910 | New max: 1000
# Pushed 998 with max context 1000
# Popped 998 | New max: 1000
# Pushed 878 with max context 1000
# Popped 878 | New max: 1000
# Pushed 194 with max context 1000
# Popped 194 | New max: 1000
# Pushed 846 with max context 1000
# Popped 846 | New max: 1000
# Pushed 469 with max context 1000
# Popped 469 | New max: 1000
# Pushed 156 with max context 1000
# Popped 156 | New max: 1000
# Pushed 438 with max context 1000
# Popped 438 | New max: 1000
# Pushed 577 with max context 1000
# Popped 577 | New max: 1000
# Pushed 361 with max context 1000
# Popped 361 | New max: 1000
# Pushed 638 with max context 1000
# Popped 638 | New max: 1000
# Pushed 745 with max context 1000
# Popped 745 | New max: 1000
# Pushed 958 with max context 1000
# Popped 958 | New max: 1000
# Pushed 539 with max context 1000
# Popped 539 | New max: 1000
# Pushed 91 with max context 1000
# Popped 91 | New max: 1000
# Pushed 212 with max context 1000
# Popped 212 | New max: 1000
# Pushed 954 with max context 1000
# Popped 954 | New max: 1000
# Pushed 214 with max context 1000
# Popped 214 | New max: 1000
# Pushed 423 with max context 1000
# Popped 423 | New max: 1000
# Pushed 847 with max context 1000
# Popped 847 | New max: 1000
# Pushed 457 with max context 1000
# Popped 457 | New max: 1000
# Pushed 435 with max context 1000
# Popped 435 | New max: 1000
# Pushed 1 with max context 1000
# Popped 1 | New max: 1000
# Pushed 45 with max context 1000
# Popped 45 | New max: 1000
# Pushed 501 with max context 1000
# Popped 501 | New max: 1000
# Pushed 145 with max context 1000
# Popped 145 | New max: 1000
# Pushed 916 with max context 1000
# Popped 916 | New max: 1000
# Pushed 68 with max context 1000
# Popped 68 | New max: 1000
# Pushed 752 with max context 1000
# Popped 752 | New max: 1000
# Pushed 574 with max context 1000
# Popped 574 | New max: 1000
# Pushed 887 with max context 1000
# Popped 887 | New max: 1000
# Pushed 190 with max context 1000
# Popped 190 | New max: 1000
# Pushed 501 with max context 1000
# Popped 501 | New max: 1000
# Pushed 956 with max context 1000
# Popped 956 | New max: 1000
# Pushed 40 with max context 1000
# Popped 40 | New max: 1000
# Pushed 432 with max context 1000
# Popped 432 | New max: 1000
# Pushed 841 with max context 1000
# Popped 841 | New max: 1000
# Pushed 689 with max context 1000
# Popped 689 | New max: 1000
# Pushed 342 with max context 1000
# Popped 342 | New max: 1000
# Pushed 57 with max context 1000
# Popped 57 | New max: 1000
# Pushed 848 with max context 1000
# Popped 848 | New max: 1000
# Pushed 897 with max context 1000
# Popped 897 | New max: 1000
# Pushed 621 with max context 1000
# Popped 621 | New max: 1000
# Pushed 811 with max context 1000
# Popped 811 | New max: 1000
# Pushed 78 with max context 1000
# Popped 78 | New max: 1000
# Pushed 787 with max context 1000
# Popped 787 | New max: 1000
# Pushed 562 with max context 1000
# Popped 562 | New max: 1000
# Pushed 537 with max context 1000
# Popped 537 | New max: 1000
# Pushed 67 with max context 1000
# Popped 67 | New max: 1000
# Pushed 67 with max context 1000
# Popped 67 | New max: 1000
# Pushed 770 with max context 1000
# Popped 770 | New max: 1000
# Pushed 380 with max context 1000
# Popped 380 | New max: 1000
# Pushed 460 with max context 1000
# Popped 460 | New max: 1000
# Pushed 901 with max context 1000
# Popped 901 | New max: 1000
# Pushed 676 with max context 1000
# Popped 676 | New max: 1000
# Pushed 348 with max context 1000
# Popped 348 | New max: 1000
# Pushed 132 with max context 1000
# Popped 132 | New max: 1000
# Pushed 520 with max context 1000
# Popped 520 | New max: 1000
# Pushed 479 with max context 1000
# Popped 479 | New max: 1000
# Pushed 210 with max context 1000
# Popped 210 | New max: 1000
# Pushed 470 with max context 1000
# Popped 470 | New max: 1000
# Pushed 738 with max context 1000
# Popped 738 | New max: 1000
# Pushed 898 with max context 1000
# Popped 898 | New max: 1000
# Pushed 829 with max context 1000
# Popped 829 | New max: 1000
# Pushed 854 with max context 1000
# Popped 854 | New max: 1000
# Pushed 807 with max context 1000
# Popped 807 | New max: 1000
# Pushed 527 with max context 1000
# Popped 527 | New max: 1000
# Pushed 856 with max context 1000
# Popped 856 | New max: 1000
# Pushed 411 with max context 1000
# Popped 411 | New max: 1000
# Pushed 960 with max context 1000
# Popped 960 | New max: 1000
# Pushed 439 with max context 1000
# Popped 439 | New max: 1000
# Pushed 472 with max context 1000
# Popped 472 | New max: 1000
# Pushed 195 with max context 1000
# Popped 195 | New max: 1000
# Pushed 458 with max context 1000
# Popped 458 | New max: 1000
# Pushed 390 with max context 1000
# Popped 390 | New max: 1000
# Pushed 93 with max context 1000
# Popped 93 | New max: 1000
# Pushed 663 with max context 1000
# Popped 663 | New max: 1000
# Pushed 946 with max context 1000
# Popped 946 | New max: 1000
# Pushed 650 with max context 1000
# Popped 650 | New max: 1000
# Pushed 832 with max context 1000
# Popped 832 | New max: 1000
# Pushed 583 with max context 1000
# Popped 583 | New max: 1000
# Pushed 581 with max context 1000
# Popped 581 | New max: 1000
# Pushed 462 with max context 1000
# Popped 462 | New max: 1000
# Pushed 142 with max context 1000
# Popped 142 | New max: 1000
# Pushed 189 with max context 1000
# Array Pairs:         0.004910 seconds
# MaxStackLinkedList initialized
# Pushed 413 | Current max: 413
# Pushed 175 | Current max: 413
# Pushed 128 | Current max: 413
# Pushed 547 | Current max: 547
# Pushed 160 | Current max: 547
# Pushed 311 | Current max: 547
# Pushed 525 | Current max: 547
# Pushed 891 | Current max: 891
# Pushed 384 | Current max: 891
# Pushed 141 | Current max: 891
# Pushed 603 | Current max: 891
# Pushed 514 | Current max: 891
# Pushed 942 | Current max: 942
# Pushed 315 | Current max: 942
# Pushed 535 | Current max: 942
# Pushed 61 | Current max: 942
# Pushed 622 | Current max: 942
# Pushed 656 | Current max: 942
# Pushed 559 | Current max: 942
# Pushed 947 | Current max: 947
# Pushed 692 | Current max: 947
# Pushed 19 | Current max: 947
# Pushed 915 | Current max: 947
# Pushed 596 | Current max: 947
# Pushed 778 | Current max: 947
# Pushed 359 | Current max: 947
# Pushed 899 | Current max: 947
# Pushed 92 | Current max: 947
# Pushed 93 | Current max: 947
# Pushed 511 | Current max: 947
# Pushed 822 | Current max: 947
# Pushed 248 | Current max: 947
# Pushed 680 | Current max: 947
# Pushed 90 | Current max: 947
# Pushed 1000 | Current max: 1000
# Pushed 688 | Current max: 1000
# Pushed 617 | Current max: 1000
# Pushed 910 | Current max: 1000
# Pushed 930 | Current max: 1000
# Pushed 476 | Current max: 1000
# Pushed 241 | Current max: 1000
# Pushed 74 | Current max: 1000
# Pushed 683 | Current max: 1000
# Pushed 546 | Current max: 1000
# Pushed 421 | Current max: 1000
# Pushed 715 | Current max: 1000
# Pushed 184 | Current max: 1000
# Pushed 955 | Current max: 1000
# Pushed 631 | Current max: 1000
# Pushed 210 | Current max: 1000
# Pushed 337 | Current max: 1000
# Pushed 235 | Current max: 1000
# Pushed 126 | Current max: 1000
# Pushed 737 | Current max: 1000
# Pushed 407 | Current max: 1000
# Pushed 209 | Current max: 1000
# Pushed 114 | Current max: 1000
# Pushed 832 | Current max: 1000
# Pushed 481 | Current max: 1000
# Pushed 847 | Current max: 1000
# Pushed 186 | Current max: 1000
# Pushed 513 | Current max: 1000
# Pushed 684 | Current max: 1000
# Pushed 557 | Current max: 1000
# Pushed 872 | Current max: 1000
# Pushed 22 | Current max: 1000
# Pushed 253 | Current max: 1000
# Pushed 884 | Current max: 1000
# Pushed 905 | Current max: 1000
# Pushed 275 | Current max: 1000
# Pushed 777 | Current max: 1000
# Pushed 355 | Current max: 1000
# Pushed 33 | Current max: 1000
# Pushed 421 | Current max: 1000
# Pushed 941 | Current max: 1000
# Pushed 537 | Current max: 1000
# Pushed 912 | Current max: 1000
# Pushed 272 | Current max: 1000
# Pushed 649 | Current max: 1000
# Pushed 540 | Current max: 1000
# Pushed 375 | Current max: 1000
# Pushed 636 | Current max: 1000
# Pushed 296 | Current max: 1000
# Pushed 860 | Current max: 1000
# Pushed 653 | Current max: 1000
# Pushed 790 | Current max: 1000
# Pushed 199 | Current max: 1000
# Pushed 719 | Current max: 1000
# Pushed 351 | Current max: 1000
# Pushed 484 | Current max: 1000
# Pushed 560 | Current max: 1000
# Pushed 914 | Current max: 1000
# Pushed 920 | Current max: 1000
# Pushed 886 | Current max: 1000
# Pushed 822 | Current max: 1000
# Pushed 660 | Current max: 1000
# Pushed 963 | Current max: 1000
# Pushed 387 | Current max: 1000
# Pushed 785 | Current max: 1000
# Pushed 683 | Current max: 1000
# Popped 683 | Current max: 1000
# Pushed 246 | Current max: 1000
# Popped 246 | Current max: 1000
# Pushed 288 | Current max: 1000
# Popped 288 | Current max: 1000
# Pushed 278 | Current max: 1000
# Popped 278 | Current max: 1000
# Pushed 494 | Current max: 1000
# Popped 494 | Current max: 1000
# Pushed 567 | Current max: 1000
# Popped 567 | Current max: 1000
# Pushed 141 | Current max: 1000
# Popped 141 | Current max: 1000
# Pushed 224 | Current max: 1000
# Popped 224 | Current max: 1000
# Pushed 43 | Current max: 1000
# Popped 43 | Current max: 1000
# Pushed 15 | Current max: 1000
# Popped 15 | Current max: 1000
# Pushed 42 | Current max: 1000
# Popped 42 | Current max: 1000
# Pushed 958 | Current max: 1000
# Popped 958 | Current max: 1000
# Pushed 566 | Current max: 1000
# Popped 566 | Current max: 1000
# Pushed 92 | Current max: 1000
# Popped 92 | Current max: 1000
# Pushed 409 | Current max: 1000
# Popped 409 | Current max: 1000
# Pushed 877 | Current max: 1000
# Popped 877 | Current max: 1000
# Pushed 606 | Current max: 1000
# Popped 606 | Current max: 1000
# Pushed 446 | Current max: 1000
# Popped 446 | Current max: 1000
# Pushed 878 | Current max: 1000
# Popped 878 | Current max: 1000
# Pushed 413 | Current max: 1000
# Popped 413 | Current max: 1000
# Pushed 446 | Current max: 1000
# Popped 446 | Current max: 1000
# Pushed 933 | Current max: 1000
# Popped 933 | Current max: 1000
# Pushed 951 | Current max: 1000
# Popped 951 | Current max: 1000
# Pushed 102 | Current max: 1000
# Popped 102 | Current max: 1000
# Pushed 914 | Current max: 1000
# Popped 914 | Current max: 1000
# Pushed 38 | Current max: 1000
# Popped 38 | Current max: 1000
# Pushed 866 | Current max: 1000
# Popped 866 | Current max: 1000
# Pushed 839 | Current max: 1000
# Popped 839 | Current max: 1000
# Pushed 261 | Current max: 1000
# Popped 261 | Current max: 1000
# Pushed 257 | Current max: 1000
# Popped 257 | Current max: 1000
# Pushed 846 | Current max: 1000
# Popped 846 | Current max: 1000
# Pushed 585 | Current max: 1000
# Popped 585 | Current max: 1000
# Pushed 359 | Current max: 1000
# Popped 359 | Current max: 1000
# Pushed 23 | Current max: 1000
# Popped 23 | Current max: 1000
# Pushed 415 | Current max: 1000
# Popped 415 | Current max: 1000
# Pushed 516 | Current max: 1000
# Popped 516 | Current max: 1000
# Pushed 93 | Current max: 1000
# Popped 93 | Current max: 1000
# Pushed 425 | Current max: 1000
# Popped 425 | Current max: 1000
# Pushed 58 | Current max: 1000
# Popped 58 | Current max: 1000
# Pushed 657 | Current max: 1000
# Popped 657 | Current max: 1000
# Pushed 162 | Current max: 1000
# Popped 162 | Current max: 1000
# Pushed 947 | Current max: 1000
# Popped 947 | Current max: 1000
# Pushed 563 | Current max: 1000
# Popped 563 | Current max: 1000
# Pushed 914 | Current max: 1000
# Popped 914 | Current max: 1000
# Pushed 253 | Current max: 1000
# Popped 253 | Current max: 1000
# Pushed 451 | Current max: 1000
# Popped 451 | Current max: 1000
# Pushed 558 | Current max: 1000
# Popped 558 | Current max: 1000
# Pushed 908 | Current max: 1000
# Popped 908 | Current max: 1000
# Pushed 482 | Current max: 1000
# Popped 482 | Current max: 1000
# Pushed 13 | Current max: 1000
# Popped 13 | Current max: 1000
# Pushed 899 | Current max: 1000
# Popped 899 | Current max: 1000
# Pushed 389 | Current max: 1000
# Popped 389 | Current max: 1000
# Pushed 872 | Current max: 1000
# Popped 872 | Current max: 1000
# Pushed 638 | Current max: 1000
# Popped 638 | Current max: 1000
# Pushed 655 | Current max: 1000
# Popped 655 | Current max: 1000
# Pushed 350 | Current max: 1000
# Popped 350 | Current max: 1000
# Pushed 462 | Current max: 1000
# Popped 462 | Current max: 1000
# Pushed 279 | Current max: 1000
# Popped 279 | Current max: 1000
# Pushed 896 | Current max: 1000
# Popped 896 | Current max: 1000
# Pushed 314 | Current max: 1000
# Popped 314 | Current max: 1000
# Pushed 931 | Current max: 1000
# Popped 931 | Current max: 1000
# Pushed 496 | Current max: 1000
# Popped 496 | Current max: 1000
# Pushed 256 | Current max: 1000
# Popped 256 | Current max: 1000
# Pushed 729 | Current max: 1000
# Popped 729 | Current max: 1000
# Pushed 578 | Current max: 1000
# Popped 578 | Current max: 1000
# Pushed 176 | Current max: 1000
# Popped 176 | Current max: 1000
# Pushed 890 | Current max: 1000
# Popped 890 | Current max: 1000
# Pushed 395 | Current max: 1000
# Popped 395 | Current max: 1000
# Pushed 738 | Current max: 1000
# Popped 738 | Current max: 1000
# Pushed 918 | Current max: 1000
# Popped 918 | Current max: 1000
# Pushed 206 | Current max: 1000
# Popped 206 | Current max: 1000
# Pushed 217 | Current max: 1000
# Popped 217 | Current max: 1000
# Pushed 316 | Current max: 1000
# Popped 316 | Current max: 1000
# Pushed 533 | Current max: 1000
# Popped 533 | Current max: 1000
# Pushed 763 | Current max: 1000
# Popped 763 | Current max: 1000
# Pushed 263 | Current max: 1000
# Popped 263 | Current max: 1000
# Pushed 570 | Current max: 1000
# Popped 570 | Current max: 1000
# Pushed 41 | Current max: 1000
# Popped 41 | Current max: 1000
# Pushed 501 | Current max: 1000
# Popped 501 | Current max: 1000
# Pushed 753 | Current max: 1000
# Popped 753 | Current max: 1000
# Pushed 106 | Current max: 1000
# Popped 106 | Current max: 1000
# Pushed 201 | Current max: 1000
# Popped 201 | Current max: 1000
# Pushed 459 | Current max: 1000
# Popped 459 | Current max: 1000
# Pushed 348 | Current max: 1000
# Popped 348 | Current max: 1000
# Pushed 98 | Current max: 1000
# Popped 98 | Current max: 1000
# Pushed 468 | Current max: 1000
# Popped 468 | Current max: 1000
# Pushed 524 | Current max: 1000
# Popped 524 | Current max: 1000
# Pushed 503 | Current max: 1000
# Popped 503 | Current max: 1000
# Pushed 203 | Current max: 1000
# Popped 203 | Current max: 1000
# Pushed 395 | Current max: 1000
# Popped 395 | Current max: 1000
# Pushed 70 | Current max: 1000
# Popped 70 | Current max: 1000
# Pushed 151 | Current max: 1000
# Popped 151 | Current max: 1000
# Pushed 361 | Current max: 1000
# Popped 361 | Current max: 1000
# Pushed 706 | Current max: 1000
# Popped 706 | Current max: 1000
# Pushed 365 | Current max: 1000
# Popped 365 | Current max: 1000
# Pushed 898 | Current max: 1000
# Popped 898 | Current max: 1000
# Pushed 787 | Current max: 1000
# Popped 787 | Current max: 1000
# Pushed 365 | Current max: 1000
# Popped 365 | Current max: 1000
# Pushed 96 | Current max: 1000
# Popped 96 | Current max: 1000
# Pushed 486 | Current max: 1000
# Popped 486 | Current max: 1000
# Pushed 573 | Current max: 1000
# Popped 573 | Current max: 1000
# Pushed 879 | Current max: 1000
# Popped 879 | Current max: 1000
# Pushed 528 | Current max: 1000
# Popped 528 | Current max: 1000
# Pushed 81 | Current max: 1000
# Popped 81 | Current max: 1000
# Pushed 807 | Current max: 1000
# Popped 807 | Current max: 1000
# Pushed 613 | Current max: 1000
# Popped 613 | Current max: 1000
# Pushed 196 | Current max: 1000
# Popped 196 | Current max: 1000
# Pushed 39 | Current max: 1000
# Popped 39 | Current max: 1000
# Pushed 439 | Current max: 1000
# Popped 439 | Current max: 1000
# Pushed 968 | Current max: 1000
# Popped 968 | Current max: 1000
# Pushed 633 | Current max: 1000
# Popped 633 | Current max: 1000
# Pushed 767 | Current max: 1000
# Popped 767 | Current max: 1000
# Pushed 976 | Current max: 1000
# Popped 976 | Current max: 1000
# Pushed 112 | Current max: 1000
# Popped 112 | Current max: 1000
# Pushed 13 | Current max: 1000
# Popped 13 | Current max: 1000
# Pushed 716 | Current max: 1000
# Popped 716 | Current max: 1000
# Pushed 628 | Current max: 1000
# Popped 628 | Current max: 1000
# Pushed 69 | Current max: 1000
# Popped 69 | Current max: 1000
# Pushed 460 | Current max: 1000
# Popped 460 | Current max: 1000
# Pushed 551 | Current max: 1000
# Popped 551 | Current max: 1000
# Pushed 884 | Current max: 1000
# Popped 884 | Current max: 1000
# Pushed 95 | Current max: 1000
# Popped 95 | Current max: 1000
# Pushed 639 | Current max: 1000
# Popped 639 | Current max: 1000
# Pushed 30 | Current max: 1000
# Popped 30 | Current max: 1000
# Pushed 150 | Current max: 1000
# Popped 150 | Current max: 1000
# Pushed 957 | Current max: 1000
# Popped 957 | Current max: 1000
# Pushed 336 | Current max: 1000
# Popped 336 | Current max: 1000
# Pushed 158 | Current max: 1000
# ...
# Pushed 787 with max context 1000
# Pushed 453 with max context 1000
# Pushed 995 with max context 1000
# Pushed 184 with max context 1000
# Pushed 320 with max context 1000
# Pushed 87 with max context 1000
# Pushed 96 with max context 1000
# Pushed 86 with max context 1000
# Pushed 889 with max context 1000
# Pushed 471 with max context 1000
# Pushed 595 with max context 1000
# Pushed 453 with max context 1000
# Pushed 617 with max context 1000
# Pushed 341 with max context 1000
# Pushed 91 with max context 1000
# Pushed 491 with max context 1000
# Pushed 325 with max context 1000
# Pushed 387 with max context 1000
# Pushed 470 with max context 1000
# Pushed 991 with max context 1000
# Pushed 918 with max context 1000
# Pushed 683 with max context 1000
# Pushed 128 with max context 1000
# Pushed 289 with max context 1000
# Pushed 130 with max context 1000
# Pushed 585 with max context 1000
# Pushed 618 with max context 1000
# Pushed 621 with max context 1000
# Pushed 614 with max context 1000
# Pushed 570 with max context 1000
# Popped 570 | New max: 1000
# Pushed 144 with max context 1000
# Popped 144 | New max: 1000
# Pushed 848 with max context 1000
# Popped 848 | New max: 1000
# Pushed 526 with max context 1000
# Popped 526 | New max: 1000
# Pushed 779 with max context 1000
# Popped 779 | New max: 1000
# Pushed 976 with max context 1000
# Popped 976 | New max: 1000
# Pushed 501 with max context 1000
# Popped 501 | New max: 1000
# Pushed 243 with max context 1000
# Popped 243 | New max: 1000
# Pushed 589 with max context 1000
# Popped 589 | New max: 1000
# Pushed 726 with max context 1000
# Popped 726 | New max: 1000
# Pushed 739 with max context 1000
# Popped 739 | New max: 1000
# Pushed 867 with max context 1000
# Popped 867 | New max: 1000
# Pushed 266 with max context 1000
# Popped 266 | New max: 1000
# Pushed 68 with max context 1000
# Popped 68 | New max: 1000
# Pushed 92 with max context 1000
# Popped 92 | New max: 1000
# Pushed 861 with max context 1000
# Popped 861 | New max: 1000
# Pushed 859 with max context 1000
# Popped 859 | New max: 1000
# Pushed 837 with max context 1000
# Popped 837 | New max: 1000
# Pushed 87 with max context 1000
# Popped 87 | New max: 1000
# Pushed 832 with max context 1000
# Popped 832 | New max: 1000
# Pushed 118 with max context 1000
# Popped 118 | New max: 1000
# Pushed 691 with max context 1000
# Popped 691 | New max: 1000
# Pushed 6 with max context 1000
# Popped 6 | New max: 1000
# Pushed 81 with max context 1000
# Popped 81 | New max: 1000
# Pushed 393 with max context 1000
# Popped 393 | New max: 1000
# Pushed 494 with max context 1000
# Popped 494 | New max: 1000
# Pushed 897 with max context 1000
# Popped 897 | New max: 1000
# Pushed 420 with max context 1000
# Popped 420 | New max: 1000
# Pushed 462 with max context 1000
# Popped 462 | New max: 1000
# Pushed 73 with max context 1000
# Popped 73 | New max: 1000
# Pushed 280 with max context 1000
# Popped 280 | New max: 1000
# Pushed 588 with max context 1000
# Popped 588 | New max: 1000
# Pushed 69 with max context 1000
# Popped 69 | New max: 1000
# Pushed 33 with max context 1000
# Popped 33 | New max: 1000
# Pushed 338 with max context 1000
# Popped 338 | New max: 1000
# Pushed 995 with max context 1000
# Popped 995 | New max: 1000
# Pushed 990 with max context 1000
# Popped 990 | New max: 1000
# Pushed 601 with max context 1000
# Popped 601 | New max: 1000
# Pushed 735 with max context 1000
# Popped 735 | New max: 1000
# Pushed 840 with max context 1000
# Popped 840 | New max: 1000
# Pushed 405 with max context 1000
# Popped 405 | New max: 1000
# Pushed 109 with max context 1000
# Popped 109 | New max: 1000
# Pushed 156 with max context 1000
# Popped 156 | New max: 1000
# Pushed 565 with max context 1000
# Popped 565 | New max: 1000
# Pushed 904 with max context 1000
# Popped 904 | New max: 1000
# Pushed 256 with max context 1000
# Popped 256 | New max: 1000
# Pushed 888 with max context 1000
# Popped 888 | New max: 1000
# Pushed 475 with max context 1000
# Popped 475 | New max: 1000
# Pushed 672 with max context 1000
# Popped 672 | New max: 1000
# Pushed 834 with max context 1000
# Popped 834 | New max: 1000
# Pushed 239 with max context 1000
# Popped 239 | New max: 1000
# Pushed 678 with max context 1000
# Popped 678 | New max: 1000
# Pushed 731 with max context 1000
# Popped 731 | New max: 1000
# Pushed 445 with max context 1000
# Popped 445 | New max: 1000
# Pushed 400 with max context 1000
# Popped 400 | New max: 1000
# Pushed 144 with max context 1000
# Popped 144 | New max: 1000
# Pushed 670 with max context 1000
# Popped 670 | New max: 1000
# Pushed 35 with max context 1000
# Popped 35 | New max: 1000
# Pushed 890 with max context 1000
# Popped 890 | New max: 1000
# Pushed 593 with max context 1000
# Popped 593 | New max: 1000
# Pushed 322 with max context 1000
# Popped 322 | New max: 1000
# Pushed 873 with max context 1000
# Popped 873 | New max: 1000
# Pushed 172 with max context 1000
# Popped 172 | New max: 1000
# Pushed 638 with max context 1000
# Popped 638 | New max: 1000
# Pushed 352 with max context 1000
# Popped 352 | New max: 1000
# Pushed 982 with max context 1000
# Popped 982 | New max: 1000
# Pushed 299 with max context 1000
# Popped 299 | New max: 1000
# Pushed 114 with max context 1000
# Popped 114 | New max: 1000
# Pushed 287 with max context 1000
# Popped 287 | New max: 1000
# Pushed 989 with max context 1000
# Popped 989 | New max: 1000
# Pushed 875 with max context 1000
# Popped 875 | New max: 1000
# Pushed 82 with max context 1000
# Popped 82 | New max: 1000
# Pushed 426 with max context 1000
# Popped 426 | New max: 1000
# Pushed 438 with max context 1000
# Popped 438 | New max: 1000
# Pushed 109 with max context 1000
# Popped 109 | New max: 1000
# Pushed 726 with max context 1000
# Popped 726 | New max: 1000
# Pushed 341 with max context 1000
# Popped 341 | New max: 1000
# Pushed 307 with max context 1000
# Popped 307 | New max: 1000
# Pushed 666 with max context 1000
# Popped 666 | New max: 1000
# Pushed 640 with max context 1000
# Popped 640 | New max: 1000
# Pushed 616 with max context 1000
# Popped 616 | New max: 1000
# Pushed 792 with max context 1000
# Popped 792 | New max: 1000
# Pushed 915 with max context 1000
# Popped 915 | New max: 1000
# Pushed 378 with max context 1000
# Popped 378 | New max: 1000
# Pushed 815 with max context 1000
# Popped 815 | New max: 1000
# Pushed 454 with max context 1000
# Popped 454 | New max: 1000
# Pushed 592 with max context 1000
# Popped 592 | New max: 1000
# Pushed 419 with max context 1000
# Popped 419 | New max: 1000
# Pushed 1000 with max context 1000
# Popped 1000 | New max: 1000
# Pushed 411 with max context 1000
# Popped 411 | New max: 1000
# Pushed 282 with max context 1000
# Popped 282 | New max: 1000
# Pushed 818 with max context 1000
# Popped 818 | New max: 1000
# Pushed 728 with max context 1000
# Popped 728 | New max: 1000
# Pushed 866 with max context 1000
# Popped 866 | New max: 1000
# Pushed 33 with max context 1000
# Popped 33 | New max: 1000
# Pushed 133 with max context 1000
# Popped 133 | New max: 1000
# Pushed 704 with max context 1000
# Popped 704 | New max: 1000
# Pushed 480 with max context 1000
# Popped 480 | New max: 1000
# Pushed 913 with max context 1000
# Popped 913 | New max: 1000
# Pushed 140 with max context 1000
# Popped 140 | New max: 1000
# Pushed 855 with max context 1000
# Popped 855 | New max: 1000
# Pushed 188 with max context 1000
# Popped 188 | New max: 1000
# Pushed 367 with max context 1000
# Popped 367 | New max: 1000
# Pushed 571 with max context 1000
# Popped 571 | New max: 1000
# Pushed 710 with max context 1000
# Popped 710 | New max: 1000
# Pushed 124 with max context 1000
# Popped 124 | New max: 1000
# Pushed 822 with max context 1000
# Popped 822 | New max: 1000
# Pushed 803 with max context 1000
# Popped 803 | New max: 1000
# Pushed 25 with max context 1000
# Popped 25 | New max: 1000
# Pushed 686 with max context 1000
# Popped 686 | New max: 1000
# Pushed 627 with max context 1000
# Popped 627 | New max: 1000
# Pushed 316 with max context 1000
# Popped 316 | New max: 1000
# Pushed 235 with max context 1000
# Popped 235 | New max: 1000
# Pushed 499 with max context 1000
# Popped 499 | New max: 1000
# Pushed 800 with max context 1000
# Popped 800 | New max: 1000
# Pushed 479 with max context 1000
# Popped 479 | New max: 1000
# Pushed 55 with max context 1000
# Popped 55 | New max: 1000
# Pushed 698 with max context 1000
# Popped 698 | New max: 1000
# Pushed 764 with max context 1000
# Popped 764 | New max: 1000
# Pushed 939 with max context 1000
# Popped 939 | New max: 1000
# Pushed 614 with max context 1000
# Popped 614 | New max: 1000
# Pushed 8 with max context 1000
# Popped 8 | New max: 1000
# Pushed 338 with max context 1000
# Popped 338 | New max: 1000
# Pushed 371 with max context 1000
# Popped 371 | New max: 1000
# Pushed 34 with max context 1000
# Popped 34 | New max: 1000
# Pushed 435 with max context 1000
# Popped 435 | New max: 1000
# Pushed 381 with max context 1000
# Popped 381 | New max: 1000
# Pushed 259 with max context 1000
# Popped 259 | New max: 1000
# Pushed 190 with max context 1000
# Popped 190 | New max: 1000
# Pushed 287 with max context 1000
# Popped 287 | New max: 1000
# Pushed 768 with max context 1000
# Popped 768 | New max: 1000
# Pushed 965 with max context 1000
# Popped 965 | New max: 1000
# Pushed 47 with max context 1000
# Popped 47 | New max: 1000
# Pushed 39 with max context 1000
# Popped 39 | New max: 1000
# Pushed 610 with max context 1000
# Popped 610 | New max: 1000
# Pushed 88 with max context 1000
# Popped 88 | New max: 1000
# Pushed 553 with max context 1000
# Popped 553 | New max: 1000
# Pushed 466 with max context 1000
# Popped 466 | New max: 1000
# Pushed 359 with max context 1000
# Popped 359 | New max: 1000
# Pushed 8 with max context 1000
# Popped 8 | New max: 1000
# Pushed 457 with max context 1000
# Popped 457 | New max: 1000
# Pushed 297 with max context 1000
# Popped 297 | New max: 1000
# Pushed 722 with max context 1000
# Popped 722 | New max: 1000
# Pushed 883 with max context 1000
# Popped 883 | New max: 1000
# Pushed 952 with max context 1000
# Popped 952 | New max: 1000
# Pushed 565 with max context 1000
# Popped 565 | New max: 1000
# Pushed 106 with max context 1000
# Popped 106 | New max: 1000
# Pushed 65 with max context 1000
# Popped 65 | New max: 1000
# Pushed 204 with max context 1000
# Popped 204 | New max: 1000
# Pushed 388 with max context 1000
# Popped 388 | New max: 1000
# Pushed 115 with max context 1000
# Popped 115 | New max: 1000
# Pushed 393 with max context 1000
# Popped 393 | New max: 1000
# Pushed 197 with max context 1000
# Popped 197 | New max: 1000
# Pushed 376 with max context 1000
# Popped 376 | New max: 1000
# Pushed 279 with max context 1000
# Popped 279 | New max: 1000
# Pushed 86 with max context 1000
# Popped 86 | New max: 1000
# Pushed 29 with max context 1000
# Popped 29 | New max: 1000
# Pushed 551 with max context 1000
# Popped 551 | New max: 1000
# Pushed 264 with max context 1000
# Popped 264 | New max: 1000
# Pushed 44 with max context 1000
# Popped 44 | New max: 1000
# Pushed 446 with max context 1000
# Popped 446 | New max: 1000
# Pushed 800 with max context 1000
# Popped 800 | New max: 1000
# Pushed 566 with max context 1000
# Popped 566 | New max: 1000
# Pushed 471 with max context 1000
# Popped 471 | New max: 1000
# Pushed 774 with max context 1000
# Popped 774 | New max: 1000
# Pushed 538 with max context 1000
# Popped 538 | New max: 1000
# Pushed 255 with max context 1000
# Popped 255 | New max: 1000
# Pushed 722 with max context 1000
# Popped 722 | New max: 1000
# Pushed 539 with max context 1000
# Popped 539 | New max: 1000
# Pushed 184 with max context 1000
# Popped 184 | New max: 1000
# Pushed 608 with max context 1000
# Popped 608 | New max: 1000
# Pushed 539 with max context 1000
# Popped 539 | New max: 1000
# Pushed 413 with max context 1000
# Popped 413 | New max: 1000
# Pushed 624 with max context 1000
# Popped 624 | New max: 1000
# Pushed 187 with max context 1000
# Popped 187 | New max: 1000
# Pushed 609 with max context 1000
# Popped 609 | New max: 1000
# Pushed 381 with max context 1000
# Popped 381 | New max: 1000
# Pushed 952 with max context 1000
# Popped 952 | New max: 1000
# Pushed 305 with max context 1000
# Popped 305 | New max: 1000
# Pushed 805 with max context 1000
# Popped 805 | New max: 1000
# Pushed 712 with max context 1000
# Popped 712 | New max: 1000
# Pushed 598 with max context 1000
# Popped 598 | New max: 1000
# Pushed 944 with max context 1000
# Popped 944 | New max: 1000
# Pushed 883 with max context 1000
# Popped 883 | New max: 1000
# Pushed 398 with max context 1000
# Popped 398 | New max: 1000
# Pushed 727 with max context 1000
# Popped 727 | New max: 1000
# Pushed 126 with max context 1000
# Popped 126 | New max: 1000
# Pushed 255 with max context 1000
# Popped 255 | New max: 1000
# Pushed 520 with max context 1000
# Popped 520 | New max: 1000
# Pushed 442 with max context 1000
# Popped 442 | New max: 1000
# Pushed 755 with max context 1000
# Popped 755 | New max: 1000
# Pushed 119 with max context 1000
# Popped 119 | New max: 1000
# Pushed 972 with max context 1000
# Popped 972 | New max: 1000
# Pushed 220 with max context 1000
# Popped 220 | New max: 1000
# Pushed 936 with max context 1000
# Popped 936 | New max: 1000
# Pushed 881 with max context 1000
# Popped 881 | New max: 1000
# Pushed 356 with max context 1000
# Popped 356 | New max: 1000
# Pushed 58 with max context 1000
# Popped 58 | New max: 1000
# Pushed 589 with max context 1000
# Popped 589 | New max: 1000
# Pushed 913 with max context 1000
# Popped 913 | New max: 1000
# Pushed 861 with max context 1000
# Popped 861 | New max: 1000
# Pushed 268 with max context 1000
# Popped 268 | New max: 1000
# Pushed 683 with max context 1000
# Popped 683 | New max: 1000
# Pushed 727 with max context 1000
# Popped 727 | New max: 1000
# Pushed 212 with max context 1000
# Popped 212 | New max: 1000
# Pushed 917 with max context 1000
# Popped 917 | New max: 1000
# Pushed 151 with max context 1000
# Popped 151 | New max: 1000
# Pushed 402 with max context 1000
# Popped 402 | New max: 1000
# Pushed 949 with max context 1000
# Popped 949 | New max: 1000
# Pushed 751 with max context 1000
# Popped 751 | New max: 1000
# Pushed 37 with max context 1000
# Popped 37 | New max: 1000
# Pushed 949 with max context 1000
# Popped 949 | New max: 1000
# Pushed 277 with max context 1000
# Popped 277 | New max: 1000
# Pushed 196 with max context 1000
# Popped 196 | New max: 1000
# Pushed 171 with max context 1000
# Popped 171 | New max: 1000
# Pushed 25 with max context 1000
# Popped 25 | New max: 1000
# Pushed 240 with max context 1000
# Popped 240 | New max: 1000
# Pushed 867 with max context 1000
# Popped 867 | New max: 1000
# Pushed 218 with max context 1000
# Popped 218 | New max: 1000
# Pushed 395 with max context 1000
# Popped 395 | New max: 1000
# Pushed 317 with max context 1000
# Popped 317 | New max: 1000
# Pushed 42 with max context 1000
# Popped 42 | New max: 1000
# Pushed 658 with max context 1000
# Popped 658 | New max: 1000
# Pushed 64 with max context 1000
# Popped 64 | New max: 1000
# Pushed 444 with max context 1000
# Popped 444 | New max: 1000
# Pushed 457 with max context 1000
# Popped 457 | New max: 1000
# Pushed 467 with max context 1000
# Popped 467 | New max: 1000
# Pushed 556 with max context 1000
# Popped 556 | New max: 1000
# Pushed 83 with max context 1000
# Popped 83 | New max: 1000
# Pushed 912 with max context 1000
# Popped 912 | New max: 1000
# Pushed 54 with max context 1000
# Popped 54 | New max: 1000
# Pushed 736 with max context 1000
# Popped 736 | New max: 1000
# Pushed 525 with max context 1000
# Popped 525 | New max: 1000
# Pushed 656 with max context 1000
# Popped 656 | New max: 1000
# Pushed 850 with max context 1000
# Popped 850 | New max: 1000
# Pushed 247 with max context 1000
# Popped 247 | New max: 1000
# Pushed 84 with max context 1000
# Popped 84 | New max: 1000
# Pushed 324 with max context 1000
# Popped 324 | New max: 1000
# Pushed 986 with max context 1000
# Popped 986 | New max: 1000
# Pushed 890 with max context 1000
# Popped 890 | New max: 1000
# Pushed 772 with max context 1000
# Popped 772 | New max: 1000
# Pushed 539 with max context 1000
# Popped 539 | New max: 1000
# Pushed 37 with max context 1000
# Popped 37 | New max: 1000
# Pushed 670 with max context 1000
# Popped 670 | New max: 1000
# Pushed 171 with max context 1000
# Popped 171 | New max: 1000
# Pushed 383 with max context 1000
# Popped 383 | New max: 1000
# Pushed 479 with max context 1000
# Popped 479 | New max: 1000
# Pushed 415 with max context 1000
# Popped 415 | New max: 1000
# Pushed 679 with max context 1000
# Popped 679 | New max: 1000
# Pushed 585 with max context 1000
# Popped 585 | New max: 1000
# Pushed 416 with max context 1000
# LinkedList Pairs:     0.041785 seconds
# Fastest: Array Two-Stack

# %% [markdown]
# ## Complete Complexity Analysis
#
# ### Time Complexity Comparison
#
# | Operation | Array Two-Stack | Array Pairs | LinkedList Two-Stack | LinkedList Pairs |
# |-----------|----------------|-------------|---------------------|------------------|
# | **push()** | O(1) | O(1) | O(1) | O(1) |
# | **pop()** | O(1) | O(1) | O(1) | O(1) |
# | **peek()** | O(1) | O(1) | O(1) | O(1) |
# | **getMax()** | O(1) | O(1) | O(1) | O(1) |
# | **isEmpty()** | O(1) | O(1) | O(1) | O(1) |
# | **size()** | O(1) | O(1) | O(1) | O(1) |
#
# ### Space Complexity Analysis
#
# | Implementation | Space per Element | Total Space | Auxiliary Space |
# |----------------|-------------------|-------------|-----------------|
# | **Array Two-Stack** | O(1) + O(1) for max* | O(n) | O(k) where k ≤ n |
# | **Array Pairs** | O(1) for value + O(1) for max | O(2n) | O(1) |
# | **LinkedList Two-Stack** | O(1) + pointer + O(1) for max* | O(n) + pointer overhead | O(k) where k ≤ n |
# | **LinkedList Pairs** | O(1) for value + O(1) for max + pointer | O(3n) + pointer overhead | O(1) |
#
# *Space optimization: max stack only stores elements when they are new maximums
#
# ### Memory Usage Details
#
# **Array Two-Stack Approach:**
# - **Best Case**: O(n) when all elements are in decreasing order (max stack has only first element)
# - **Worst Case**: O(2n) when all elements are in increasing order (both stacks full)
# - **Average Case**: O(1.5n) typical real-world usage
#
# **Array Pairs Approach:**
# - **All Cases**: O(2n) - consistent memory usage
# - Each element stores both value and maximum context
#
# **LinkedList Two-Stack Approach:**
# - **Best Case**: O(n) + pointer overhead when max stack is minimal
# - **Worst Case**: O(2n) + pointer overhead
# - **Pointer Overhead**: Additional 8 bytes per node on 64-bit systems
#
# **LinkedList Pairs Approach:**
# - **All Cases**: O(3n) + pointer overhead
# - Highest memory usage but simplest logic
#
# ### When to Use Each Approach
#
# | Scenario | Recommended Approach | Reason |
# |----------|---------------------|---------|
# | **Memory Critical** | Array Two-Stack | Most space efficient on average |
# | **Simplicity Priority** | Array Pairs | Easiest to understand and debug |
# | **Unknown Size** | LinkedList Two-Stack | Dynamic sizing with good memory efficiency |
# | **Rapid Prototyping** | LinkedList Pairs | Simplest implementation, no size limits |
# | **Cache Performance** | Array-based | Better cache locality |
# | **Concurrent Access** | LinkedList-based | Easier to make thread-safe |
# | **High-Performance Systems** | Array Two-Stack | Predictable memory patterns |
#
# ### Real-world Considerations
#
# **For System Monitoring:**
# - Use Array Two-Stack for predictable memory usage in monitoring systems
# - LinkedList approaches better for dynamic monitoring scenarios
#
# **For Gaming Applications:**
# - Array Pairs offers good balance for score tracking
# - LinkedList approaches better for variable game state sizes
#
# **For Trading Systems:**
# - Array Two-Stack minimizes memory fragmentation for high-frequency data
# - Consider memory access patterns for real-time requirements
#
# **For Performance Analytics:**
# - LinkedList approaches better for variable-length performance windows
# - Array approaches better for fixed-window analysis

# %% [markdown]
# ## Practical Applications and Use Cases
#
# ### 1. **System Performance Monitoring**
# Track peak system performance metrics in real-time:
#
# ```python
# # Monitor CPU usage with peak tracking
# cpu_monitor = MaxStack()
# cpu_monitor.push(get_current_cpu_usage())
# peak_cpu = cpu_monitor.get_max()
# alert_if_peak_exceeded(peak_cpu, threshold=90)
# ```
#
# ### 2. **Trading and Financial Systems**
# Monitor highest stock prices, transaction volumes:
#
# ```python
# # Track highest stock price in current session
# stock_price_stack = MaxStack()
# for price in real_time_prices:
#     stock_price_stack.push(price)
#     current_high = stock_price_stack.get_max()
#     if should_sell(current_high, price):
#         execute_sell_order()
# ```
#
# ### 3. **Gaming and Leaderboards**
# Track high scores and maximum achievements:
#
# ```python
# # Player score tracking with high score monitoring
# player_score_stack = MaxStack()
# player_score_stack.push(current_score)
# if player_score_stack.get_max() > all_time_high:
#     trigger_high_score_celebration()
# ```
#
# ### 4. **Quality Control and SLA Monitoring**
# Track maximum response times, error rates:
#
# ```python
# # Monitor maximum response time in service window
# response_time_stack = MaxStack()
# response_time_stack.push(get_response_time())
# max_response = response_time_stack.get_max()
# check_sla_compliance(max_response)
# ```
#
# ### 5. **Resource Management**
# Monitor peak resource usage:
#
# ```python
# # Track maximum memory usage
# memory_usage_stack = MaxStack()
# memory_usage_stack.push(get_current_memory())
# peak_memory = memory_usage_stack.get_max()
# optimize_if_needed(peak_memory)
# ```
#
# ### 6. **Algorithm Optimization**
# Many algorithms benefit from quick maximum access:
#
# - **Sliding Window Maximum**: Process data streams with maximum tracking
# - **Expression Evaluation**: Track maximum operand values
# - **Dynamic Programming**: Optimize state transitions
# - **Graph Algorithms**: Maximum weight path calculations
#
# ### 7. **Data Stream Analytics**
# Real-time analytics with maximum value tracking:
#
# ```python
# # Process incoming metrics stream
# metrics_stream_stack = MaxStack()
# for metric in stream:
#     metrics_stream_stack.push(metric)
#     trend_analysis(metrics_stream_stack.get_max())
# ```
#
# ### 8. **Network Performance Analysis**
# Track maximum bandwidth usage, latency spikes:
#
# ```python
# # Monitor network performance peaks
# bandwidth_stack = MaxStack()
# bandwidth_stack.push(current_bandwidth)
# peak_usage = bandwidth_stack.get_max()
# capacity_planning(peak_usage)
# ```
#
# ## Comparison with Min Stack
#
# | Aspect | Max Stack | Min Stack | Use Case Difference |
# |--------|-----------|-----------|-------------------|
# | **Primary Focus** | Maximum tracking | Minimum tracking | Peak vs. baseline monitoring |
# | **Alert Scenarios** | Peak performance, capacity limits | Performance degradation, resource shortage |
# | **Business Logic** | Scaling decisions, capacity planning | Optimization opportunities, efficiency gains |
# | **Monitoring Type** | Upper bound tracking | Lower bound tracking |
# | **Risk Management** | Overload prevention | Performance baseline maintenance |
#
# ## Summary
#
# **Max Stack** is a powerful data structure that extends regular stack functionality with constant-time maximum element access. The choice of implementation depends on specific requirements:
#
# - **Use Array Two-Stack** for memory-critical, high-performance applications
# - **Use Array Pairs** for simplicity and consistent memory usage
# - **Use LinkedList Two-Stack** for dynamic sizing with efficiency
# - **Use LinkedList Pairs** for maximum simplicity and unlimited growth
#
# All implementations maintain **O(1)** time complexity for core operations while providing different trade-offs in space complexity and implementation complexity.
#
# The Max Stack pattern is fundamental in performance monitoring, resource management, and real-time analytics, making it an essential tool for system design and optimization scenarios where peak value tracking is critical.
#
# **Key Advantages:**
# - **Real-time peak tracking** without full data traversal
# - **Efficient memory usage** with optimized implementations
# - **Scalable solutions** for various application sizes
# - **Simple integration** into existing systems
# - **Consistent performance** regardless of data distribution
#
# Max Stack complements Min Stack perfectly, and together they provide comprehensive range monitoring capabilities for sophisticated data analysis and system monitoring applications.
