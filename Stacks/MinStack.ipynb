# %% [markdown]
# # **Min Stack**
#
# A **Min Stack** is a specialized stack data structure that supports all the operations of a normal stack (push, pop, peek) and additionally provides a way to retrieve the minimum element in the stack in constant time O(1).
#
# **Key Features:**
# - All standard stack operations (push, pop, peek)
# - **getMin()**: Returns the minimum element in constant time O(1)
# - LIFO (Last In First Out) ordering maintained
# - Efficient tracking of minimum element across all operations
# - Can be implemented using arrays or linked lists
#
# **Why Min Stack?**
# In regular stacks, finding the minimum element requires O(n) time as we need to traverse all elements. Min Stack optimizes this to O(1) by maintaining additional information about the minimum elements.
#
# **Common Applications:**
# - **Stock span problems**: Finding the previous smaller/greater element
# - **Expression evaluation**: Tracking minimum values during computation
# - **Algorithm optimization**: Many algorithms need quick access to minimum values
# - **Data analysis**: Real-time minimum tracking in streaming data
# - **Game development**: Score tracking, resource management
#
# **Real-world Examples:**
# - **Trading systems**: Track minimum stock prices in real-time
# - **Monitoring systems**: Keep track of minimum response times
# - **Resource allocation**: Monitor minimum available resources
# - **Performance analysis**: Track minimum execution times

# %% [markdown]
# ## Min Stack Implementation Approaches
#
# There are several approaches to implement Min Stack:
#
# ### 1. **Two Stack Approach**
# - **Main Stack**: Stores actual elements
# - **Min Stack**: Stores minimum elements corresponding to each state
# - Space efficient but requires two data structures
#
# ### 2. **Single Stack with Pairs**
# - Store pairs of (element, current_minimum) in one stack
# - More memory per element but simpler conceptually
#
# ### 3. **Single Stack with Encoding**
# - Use mathematical encoding to store both element and minimum info
# - Most space efficient but complex implementation
#
# ### 4. **Auxiliary Minimum Tracking**
# - Maintain separate structure to track minimums
# - Flexible but may require more complex synchronization
#
# **We'll implement approaches 1 and 2 using both arrays and linked lists.**
#
# ## Time Complexity Goals
#
# | Operation | Target Complexity | Standard Stack |
# |-----------|-------------------|----------------|
# | **push()** | O(1) | O(1) |
# | **pop()** | O(1) | O(1) |
# | **peek()** | O(1) | O(1) |
# | **getMin()** | O(1) | O(n) |
# | **isEmpty()** | O(1) | O(1) |

# %%
# Import required libraries
from collections import deque
import sys

# Helper function to display stack contents
def display_stack_contents(stack_data, title="Stack Contents"):
    """Helper function to display stack contents in a readable format"""
    if not stack_data:
        print(f"{title}: Empty")
    else:
        print(f"{title}: {stack_data} (top → bottom)")

print("Min Stack Implementation - Setup Complete")
print("=" * 50)
# Out:
# Min Stack Implementation - Setup Complete
# ==================================================

# %% [markdown]
# ## Approach 1: Two Stack Implementation using Arrays
#
# This approach uses two separate stacks:
# - **Main Stack**: Stores the actual elements
# - **Min Stack**: Stores the minimum element at each state
#
# **Key Insight**: When we push an element, we also push the current minimum to the min_stack. When we pop, we pop from both stacks to maintain synchronization.
#
# **Space Optimization**: Instead of always pushing to min_stack, we only push when we find a new minimum or equal minimum.

# %%
class MinStackArray:
    def __init__(self, max_size=100):
        """Initialize Min Stack using arrays with two-stack approach"""
        self.max_size = max_size
        
        # Main stack to store actual elements
        self.main_stack = [None] * max_size
        self.main_top = -1
        
        # Min stack to store minimum elements
        self.min_stack = [None] * max_size
        self.min_top = -1
        
        print(f"MinStackArray initialized with max size: {max_size}")
    
    def is_empty(self):
        """Check if stack is empty"""
        return self.main_top == -1
    
    def is_full(self):
        """Check if stack is full"""
        return self.main_top == self.max_size - 1
    
    def size(self):
        """Return current number of elements"""
        return self.main_top + 1
    
    def push(self, element):
        """Push element to stack and update minimum tracking"""
        if self.is_full():
            raise OverflowError(f"Stack Overflow: Cannot push {element}")
        
        # Push to main stack
        self.main_top += 1
        self.main_stack[self.main_top] = element
        
        # Push to min stack (only if it's new minimum or equal to current minimum)
        if self.min_top == -1 or element <= self.min_stack[self.min_top]:
            self.min_top += 1
            self.min_stack[self.min_top] = element
        
        print(f"Pushed {element} | Current min: {self.get_min()}")
        return True
    
    def pop(self):
        """Pop element from stack and update minimum tracking"""
        if self.is_empty():
            raise IndexError("Stack Underflow: Cannot pop from empty stack")
        
        # Get element from main stack
        popped_element = self.main_stack[self.main_top]
        self.main_stack[self.main_top] = None
        self.main_top -= 1
        
        # Pop from min stack if the popped element was the minimum
        if self.min_top >= 0 and popped_element == self.min_stack[self.min_top]:
            self.min_stack[self.min_top] = None
            self.min_top -= 1
        
        print(f"Popped {popped_element} | Current min: {self.get_min() if not self.is_empty() else 'N/A'}")
        return popped_element
    
    def peek(self):
        """Return top element without removing it"""
        if self.is_empty():
            raise IndexError("Stack is empty: Cannot peek")
        return self.main_stack[self.main_top]
    
    def get_min(self):
        """Return minimum element in O(1) time"""
        if self.min_top == -1:
            raise IndexError("Stack is empty: No minimum element")
        return self.min_stack[self.min_top]
    
    def display(self):
        """Display both stacks for debugging"""
        print("\n--- Min Stack State ---")
        if self.is_empty():
            print("Stack is empty")
            return
        
        # Display main stack
        main_elements = [self.main_stack[i] for i in range(self.main_top + 1)]
        print(f"Main Stack: {main_elements} (bottom → top)")
        
        # Display min stack
        min_elements = [self.min_stack[i] for i in range(self.min_top + 1)]
        print(f"Min Stack:  {min_elements} (bottom → top)")
        
        print(f"Size: {self.size()} | Current Min: {self.get_min()}")
        print("--- End State ---\n")

# Test the Two Stack Array implementation
print("=== Testing MinStackArray (Two Stack Approach) ===")

min_stack_array = MinStackArray(10)
min_stack_array.display()

try:
    # Test sequence of operations
    operations = [
        ("push", 5),
        ("push", 2),
        ("push", 8),
        ("push", 1),
        ("push", 3),
        ("push", 1),  # Duplicate minimum
    ]
    
    for op, value in operations:
        if op == "push":
            min_stack_array.push(value)
    
    min_stack_array.display()
    
    # Test pop operations
    print("Testing pop operations:")
    for _ in range(3):
        min_stack_array.pop()
    
    min_stack_array.display()
    
    print(f"Current top: {min_stack_array.peek()}")
    print(f"Current minimum: {min_stack_array.get_min()}")

except (OverflowError, IndexError) as e:
    print(f"Error: {e}")
# Out:
# === Testing MinStackArray (Two Stack Approach) ===
# MinStackArray initialized with max size: 10
#
# --- Min Stack State ---
# Stack is empty
# Pushed 5 | Current min: 5
# Pushed 2 | Current min: 2
# Pushed 8 | Current min: 2
# Pushed 1 | Current min: 1
# Pushed 3 | Current min: 1
# Pushed 1 | Current min: 1
#
# --- Min Stack State ---
# Main Stack: [5, 2, 8, 1, 3, 1] (bottom → top)
# Min Stack:  [5, 2, 1, 1] (bottom → top)
# Size: 6 | Current Min: 1
# --- End State ---
#
# Testing pop operations:
# Popped 1 | Current min: 1
# Popped 3 | Current min: 1
# Popped 1 | Current min: 2
#
# --- Min Stack State ---
# Main Stack: [5, 2, 8] (bottom → top)
# Min Stack:  [5, 2] (bottom → top)
# Size: 3 | Current Min: 2
# --- End State ---
#
# Current top: 8
# Current minimum: 2

# %% [markdown]
# ## Approach 2: Single Stack with Pairs using Arrays
#
# This approach uses a single stack where each element is stored as a pair: `(actual_value, minimum_at_this_point)`.
#
# **Advantages:**
# - Simpler conceptually - only one stack to manage
# - Each element knows its minimum context
# - No synchronization issues between two stacks
#
# **Disadvantages:**
# - Higher memory usage - stores minimum with every element
# - More complex element structure

# %%
class MinStackArrayPairs:
    def __init__(self, max_size=100):
        """Initialize Min Stack using array with single stack storing pairs"""
        self.max_size = max_size
        self.stack = [None] * max_size  # Each element will be (value, min_at_this_point)
        self.top = -1
        
        print(f"MinStackArrayPairs initialized with max size: {max_size}")
    
    def is_empty(self):
        """Check if stack is empty"""
        return self.top == -1
    
    def is_full(self):
        """Check if stack is full"""
        return self.top == self.max_size - 1
    
    def size(self):
        """Return current number of elements"""
        return self.top + 1
    
    def push(self, element):
        """Push element with its minimum context"""
        if self.is_full():
            raise OverflowError(f"Stack Overflow: Cannot push {element}")
        
        # Determine minimum at this point
        if self.is_empty():
            current_min = element
        else:
            current_min = min(element, self.stack[self.top][1])
        
        # Push as pair (element, minimum_at_this_point)
        self.top += 1
        self.stack[self.top] = (element, current_min)
        
        print(f"Pushed {element} with min context {current_min}")
        return True
    
    def pop(self):
        """Pop element and return the actual value"""
        if self.is_empty():
            raise IndexError("Stack Underflow: Cannot pop from empty stack")
        
        popped_pair = self.stack[self.top]
        self.stack[self.top] = None
        self.top -= 1
        
        popped_value = popped_pair[0]
        print(f"Popped {popped_value} | New min: {self.get_min() if not self.is_empty() else 'N/A'}")
        return popped_value
    
    def peek(self):
        """Return top element's actual value"""
        if self.is_empty():
            raise IndexError("Stack is empty: Cannot peek")
        return self.stack[self.top][0]
    
    def get_min(self):
        """Return minimum element in O(1) time"""
        if self.is_empty():
            raise IndexError("Stack is empty: No minimum element")
        return self.stack[self.top][1]
    
    def display(self):
        """Display stack contents with minimum context"""
        print("\n--- Min Stack (Pairs) State ---")
        if self.is_empty():
            print("Stack is empty")
            return
        
        print("Stack contents (bottom → top):")
        for i in range(self.top + 1):
            value, min_val = self.stack[i]
            marker = " ← TOP" if i == self.top else ""
            print(f"  [{i}] Value: {value}, Min: {min_val}{marker}")
        
        print(f"Size: {self.size()} | Current Min: {self.get_min()}")
        print("--- End State ---\n")

# Test the Single Stack Pairs implementation
print("=== Testing MinStackArrayPairs (Single Stack with Pairs) ===")

min_stack_pairs = MinStackArrayPairs(10)
min_stack_pairs.display()

try:
    # Test sequence of operations
    test_values = [3, 5, 2, 1, 8, 1, 4]
    
    print("Pushing values:", test_values)
    for value in test_values:
        min_stack_pairs.push(value)
    
    min_stack_pairs.display()
    
    # Test accessing minimum at different states
    print("Testing minimum tracking:")
    while not min_stack_pairs.is_empty():
        print(f"Top: {min_stack_pairs.peek()}, Min: {min_stack_pairs.get_min()}")
        min_stack_pairs.pop()
    
    min_stack_pairs.display()

except (OverflowError, IndexError) as e:
    print(f"Error: {e}")
# Out:
# === Testing MinStackArrayPairs (Single Stack with Pairs) ===
# MinStackArrayPairs initialized with max size: 10
#
# --- Min Stack (Pairs) State ---
# Stack is empty
# Pushing values: [3, 5, 2, 1, 8, 1, 4]
# Pushed 3 with min context 3
# Pushed 5 with min context 3
# Pushed 2 with min context 2
# Pushed 1 with min context 1
# Pushed 8 with min context 1
# Pushed 1 with min context 1
# Pushed 4 with min context 1
#
# --- Min Stack (Pairs) State ---
# Stack contents (bottom → top):
#   [0] Value: 3, Min: 3
#   [1] Value: 5, Min: 3
#   [2] Value: 2, Min: 2
#   [3] Value: 1, Min: 1
#   [4] Value: 8, Min: 1
#   [5] Value: 1, Min: 1
#   [6] Value: 4, Min: 1 ← TOP
# Size: 7 | Current Min: 1
# --- End State ---
#
# Testing minimum tracking:
# Top: 4, Min: 1
# Popped 4 | New min: 1
# Top: 1, Min: 1
# Popped 1 | New min: 1
# Top: 8, Min: 1
# Popped 8 | New min: 1
# Top: 1, Min: 1
# Popped 1 | New min: 2
# Top: 2, Min: 2
# Popped 2 | New min: 3
# Top: 5, Min: 3
# Popped 5 | New min: 3
# Top: 3, Min: 3
# Popped 3 | New min: N/A
#
# --- Min Stack (Pairs) State ---
# Stack is empty

# %% [markdown]
# ## Approach 3: Min Stack using Linked Lists - Two Stack Approach
#
# Now let's implement Min Stack using linked lists. This approach provides dynamic memory allocation and eliminates the risk of stack overflow.
#
# **Advantages of Linked List Approach:**
# - Dynamic size - no fixed capacity limit
# - Memory efficient - allocates only what's needed
# - No stack overflow (except system memory limits)
# - Flexible and scalable

# %%
class Node:
    """Node class for linked list implementation"""
    def __init__(self, data):
        self.data = data
        self.next = None
    
    def __str__(self):
        return str(self.data)

class MinStackLinkedList:
    def __init__(self):
        """Initialize Min Stack using linked lists with two-stack approach"""
        # Main stack (linked list)
        self.main_top = None
        self.main_size = 0
        
        # Min stack (linked list) 
        self.min_top = None
        self.min_size = 0
        
        print("MinStackLinkedList initialized")
    
    def is_empty(self):
        """Check if stack is empty"""
        return self.main_top is None
    
    def size(self):
        """Return current number of elements"""
        return self.main_size
    
    def push(self, element):
        """Push element to stack and update minimum tracking"""
        # Push to main stack
        new_main_node = Node(element)
        new_main_node.next = self.main_top
        self.main_top = new_main_node
        self.main_size += 1
        
        # Push to min stack only if it's new minimum or equal to current minimum
        if self.min_top is None or element <= self.min_top.data:
            new_min_node = Node(element)
            new_min_node.next = self.min_top
            self.min_top = new_min_node
            self.min_size += 1
        
        print(f"Pushed {element} | Current min: {self.get_min()}")
        return True
    
    def pop(self):
        """Pop element from stack and update minimum tracking"""
        if self.is_empty():
            raise IndexError("Stack Underflow: Cannot pop from empty stack")
        
        # Pop from main stack
        popped_element = self.main_top.data
        self.main_top = self.main_top.next
        self.main_size -= 1
        
        # Pop from min stack if the popped element was the minimum
        if self.min_top and popped_element == self.min_top.data:
            self.min_top = self.min_top.next
            self.min_size -= 1
        
        print(f"Popped {popped_element} | Current min: {self.get_min() if not self.is_empty() else 'N/A'}")
        return popped_element
    
    def peek(self):
        """Return top element without removing it"""
        if self.is_empty():
            raise IndexError("Stack is empty: Cannot peek")
        return self.main_top.data
    
    def get_min(self):
        """Return minimum element in O(1) time"""
        if self.min_top is None:
            raise IndexError("Stack is empty: No minimum element")
        return self.min_top.data
    
    def _list_to_array(self, head):
        """Helper method to convert linked list to array for display"""
        result = []
        current = head
        while current:
            result.append(current.data)
            current = current.next
        return result
    
    def display(self):
        """Display both stacks for debugging"""
        print("\n--- Min Stack (Linked List) State ---")
        if self.is_empty():
            print("Stack is empty")
            return
        
        # Display main stack
        main_elements = self._list_to_array(self.main_top)
        print(f"Main Stack: {main_elements} (top → bottom)")
        
        # Display min stack
        min_elements = self._list_to_array(self.min_top)
        print(f"Min Stack:  {min_elements} (top → bottom)")
        
        print(f"Size: {self.size()} | Current Min: {self.get_min()}")
        print("--- End State ---\n")

# Test the Linked List implementation
print("=== Testing MinStackLinkedList (Two Stack Approach) ===")

min_stack_ll = MinStackLinkedList()
min_stack_ll.display()

try:
    # Test sequence with various patterns
    test_sequence = [10, 5, 8, 3, 12, 3, 1, 15, 1]
    
    print(f"Pushing sequence: {test_sequence}")
    for value in test_sequence:
        min_stack_ll.push(value)
    
    min_stack_ll.display()
    
    # Test popping while tracking minimum
    print("Testing pop operations with minimum tracking:")
    for i in range(5):
        print(f"Before pop - Top: {min_stack_ll.peek()}, Min: {min_stack_ll.get_min()}")
        min_stack_ll.pop()
    
    min_stack_ll.display()
    
    # Add more elements to test dynamic behavior
    print("Adding more elements:")
    for value in [20, 2, 25]:
        min_stack_ll.push(value)
    
    min_stack_ll.display()

except IndexError as e:
    print(f"Error: {e}")
# Out:
# === Testing MinStackLinkedList (Two Stack Approach) ===
# MinStackLinkedList initialized
#
# --- Min Stack (Linked List) State ---
# Stack is empty
# Pushing sequence: [10, 5, 8, 3, 12, 3, 1, 15, 1]
# Pushed 10 | Current min: 10
# Pushed 5 | Current min: 5
# Pushed 8 | Current min: 5
# Pushed 3 | Current min: 3
# Pushed 12 | Current min: 3
# Pushed 3 | Current min: 3
# Pushed 1 | Current min: 1
# Pushed 15 | Current min: 1
# Pushed 1 | Current min: 1
#
# --- Min Stack (Linked List) State ---
# Main Stack: [1, 15, 1, 3, 12, 3, 8, 5, 10] (top → bottom)
# Min Stack:  [1, 1, 3, 3, 5, 10] (top → bottom)
# Size: 9 | Current Min: 1
# --- End State ---
#
# Testing pop operations with minimum tracking:
# Before pop - Top: 1, Min: 1
# Popped 1 | Current min: 1
# Before pop - Top: 15, Min: 1
# Popped 15 | Current min: 1
# Before pop - Top: 1, Min: 1
# Popped 1 | Current min: 3
# Before pop - Top: 3, Min: 3
# Popped 3 | Current min: 3
# Before pop - Top: 12, Min: 3
# Popped 12 | Current min: 3
#
# --- Min Stack (Linked List) State ---
# Main Stack: [3, 8, 5, 10] (top → bottom)
# Min Stack:  [3, 5, 10] (top → bottom)
# Size: 4 | Current Min: 3
# --- End State ---
#
# Adding more elements:
# Pushed 20 | Current min: 3
# Pushed 2 | Current min: 2
# Pushed 25 | Current min: 2
#
# --- Min Stack (Linked List) State ---
# Main Stack: [25, 2, 20, 3, 8, 5, 10] (top → bottom)
# Min Stack:  [2, 3, 5, 10] (top → bottom)
# Size: 7 | Current Min: 2
# --- End State ---

# %% [markdown]
# ## Approach 4: Single Stack with Pairs using Linked Lists
#
# This approach uses a single linked list where each node stores both the actual value and the minimum value at that point in the stack.

# %%
class PairNode:
    """Node class that stores both value and minimum context"""
    def __init__(self, value, min_value):
        self.value = value
        self.min_value = min_value
        self.next = None
    
    def __str__(self):
        return f"({self.value}, min:{self.min_value})"

class MinStackLinkedListPairs:
    def __init__(self):
        """Initialize Min Stack using single linked list with pairs"""
        self.top = None
        self.stack_size = 0
        
        print("MinStackLinkedListPairs initialized")
    
    def is_empty(self):
        """Check if stack is empty"""
        return self.top is None
    
    def size(self):
        """Return current number of elements"""
        return self.stack_size
    
    def push(self, element):
        """Push element with its minimum context"""
        # Determine minimum at this point
        if self.is_empty():
            current_min = element
        else:
            current_min = min(element, self.top.min_value)
        
        # Create new node with both value and minimum
        new_node = PairNode(element, current_min)
        new_node.next = self.top
        self.top = new_node
        self.stack_size += 1
        
        print(f"Pushed {element} with min context {current_min}")
        return True
    
    def pop(self):
        """Pop element and return the actual value"""
        if self.is_empty():
            raise IndexError("Stack Underflow: Cannot pop from empty stack")
        
        popped_value = self.top.value
        self.top = self.top.next
        self.stack_size -= 1
        
        print(f"Popped {popped_value} | New min: {self.get_min() if not self.is_empty() else 'N/A'}")
        return popped_value
    
    def peek(self):
        """Return top element's actual value"""
        if self.is_empty():
            raise IndexError("Stack is empty: Cannot peek")
        return self.top.value
    
    def get_min(self):
        """Return minimum element in O(1) time"""
        if self.is_empty():
            raise IndexError("Stack is empty: No minimum element")
        return self.top.min_value
    
    def display(self):
        """Display stack contents with minimum context"""
        print("\n--- Min Stack (Linked List Pairs) State ---")
        if self.is_empty():
            print("Stack is empty")
            return
        
        print("Stack contents (top → bottom):")
        current = self.top
        position = 1
        while current:
            marker = " ← TOP" if position == 1 else ""
            print(f"  [{position}] Value: {current.value}, Min: {current.min_value}{marker}")
            current = current.next
            position += 1
        
        print(f"Size: {self.size()} | Current Min: {self.get_min()}")
        print("--- End State ---\n")

# Test the Linked List Pairs implementation
print("=== Testing MinStackLinkedListPairs (Single Stack with Pairs) ===")

min_stack_ll_pairs = MinStackLinkedListPairs()
min_stack_ll_pairs.display()

try:
    # Test with descending and ascending patterns
    print("Test 1: Descending then ascending pattern")
    descending = [100, 50, 25, 10, 5]
    ascending = [15, 30, 60, 120]
    
    for value in descending:
        min_stack_ll_pairs.push(value)
    
    min_stack_ll_pairs.display()
    
    for value in ascending:
        min_stack_ll_pairs.push(value)
    
    min_stack_ll_pairs.display()
    
    # Test popping and minimum evolution
    print("Test 2: Pop sequence and observe minimum changes")
    while not min_stack_ll_pairs.is_empty():
        print(f"Current - Top: {min_stack_ll_pairs.peek()}, Min: {min_stack_ll_pairs.get_min()}")
        min_stack_ll_pairs.pop()
        if not min_stack_ll_pairs.is_empty():
            print(f"After pop - Top: {min_stack_ll_pairs.peek()}, Min: {min_stack_ll_pairs.get_min()}")
        print("-" * 30)
    
    min_stack_ll_pairs.display()

except IndexError as e:
    print(f"Error: {e}")
# Out:
# === Testing MinStackLinkedListPairs (Single Stack with Pairs) ===
# MinStackLinkedListPairs initialized
#
# --- Min Stack (Linked List Pairs) State ---
# Stack is empty
# Test 1: Descending then ascending pattern
# Pushed 100 with min context 100
# Pushed 50 with min context 50
# Pushed 25 with min context 25
# Pushed 10 with min context 10
# Pushed 5 with min context 5
#
# --- Min Stack (Linked List Pairs) State ---
# Stack contents (top → bottom):
#   [1] Value: 5, Min: 5 ← TOP
#   [2] Value: 10, Min: 10
#   [3] Value: 25, Min: 25
#   [4] Value: 50, Min: 50
#   [5] Value: 100, Min: 100
# Size: 5 | Current Min: 5
# --- End State ---
#
# Pushed 15 with min context 5
# Pushed 30 with min context 5
# Pushed 60 with min context 5
# Pushed 120 with min context 5
#
# --- Min Stack (Linked List Pairs) State ---
# Stack contents (top → bottom):
#   [1] Value: 120, Min: 5 ← TOP
#   [2] Value: 60, Min: 5
#   [3] Value: 30, Min: 5
#   [4] Value: 15, Min: 5
#   [5] Value: 5, Min: 5
#   [6] Value: 10, Min: 10
#   [7] Value: 25, Min: 25
#   [8] Value: 50, Min: 50
#   [9] Value: 100, Min: 100
# Size: 9 | Current Min: 5
# --- End State ---
#
# Test 2: Pop sequence and observe minimum changes
# Current - Top: 120, Min: 5
# Popped 120 | New min: 5
# After pop - Top: 60, Min: 5
# ------------------------------
# Current - Top: 60, Min: 5
# Popped 60 | New min: 5
# After pop - Top: 30, Min: 5
# ------------------------------
# Current - Top: 30, Min: 5
# Popped 30 | New min: 5
# After pop - Top: 15, Min: 5
# ------------------------------
# Current - Top: 15, Min: 5
# Popped 15 | New min: 5
# After pop - Top: 5, Min: 5
# ------------------------------
# Current - Top: 5, Min: 5
# Popped 5 | New min: 10
# After pop - Top: 10, Min: 10
# ------------------------------
# Current - Top: 10, Min: 10
# Popped 10 | New min: 25
# After pop - Top: 25, Min: 25
# ------------------------------
# Current - Top: 25, Min: 25
# Popped 25 | New min: 50
# After pop - Top: 50, Min: 50
# ------------------------------
# Current - Top: 50, Min: 50
# Popped 50 | New min: 100
# After pop - Top: 100, Min: 100
# ------------------------------
# Current - Top: 100, Min: 100
# Popped 100 | New min: N/A
# ------------------------------
#
# --- Min Stack (Linked List Pairs) State ---
# Stack is empty

# %% [markdown]
# ## Advanced Min Stack Operations
#
# Let's implement some additional useful operations that extend the basic Min Stack functionality:
#
# 1. **getSecondMin()**: Get the second minimum element
# 2. **getMax()**: Get the maximum element (bonus feature)
# 3. **getRange()**: Get the difference between max and min
# 4. **popMin()**: Pop elements until we remove the minimum
# 5. **size_below_threshold()**: Count elements below a threshold

# %%
class AdvancedMinStack:
    """Advanced Min Stack with additional operations"""
    
    def __init__(self):
        self.main_stack = []
        self.min_stack = []
        self.max_stack = []  # Additional stack to track maximum
    
    def push(self, element):
        """Push element with min and max tracking"""
        self.main_stack.append(element)
        
        # Update min stack
        if not self.min_stack or element <= self.min_stack[-1]:
            self.min_stack.append(element)
        
        # Update max stack
        if not self.max_stack or element >= self.max_stack[-1]:
            self.max_stack.append(element)
        
        print(f"Pushed {element} | Min: {self.get_min()} | Max: {self.get_max()}")
    
    def pop(self):
        """Pop element with min and max tracking"""
        if not self.main_stack:
            raise IndexError("Stack is empty")
        
        popped = self.main_stack.pop()
        
        # Update min stack
        if self.min_stack and popped == self.min_stack[-1]:
            self.min_stack.pop()
        
        # Update max stack  
        if self.max_stack and popped == self.max_stack[-1]:
            self.max_stack.pop()
        
        print(f"Popped {popped} | Min: {self.get_min() if self.main_stack else 'N/A'} | Max: {self.get_max() if self.main_stack else 'N/A'}")
        return popped
    
    def get_min(self):
        """Get minimum element"""
        if not self.min_stack:
            raise IndexError("Stack is empty")
        return self.min_stack[-1]
    
    def get_max(self):
        """Get maximum element"""
        if not self.max_stack:
            raise IndexError("Stack is empty")
        return self.max_stack[-1]
    
    def get_second_min(self):
        """Get second minimum element"""
        if len(self.min_stack) < 2:
            # Need to find second minimum from main stack
            if len(set(self.main_stack)) < 2:
                raise ValueError("No second minimum exists")
            
            sorted_unique = sorted(set(self.main_stack))
            return sorted_unique[1]
        
        # If min_stack has multiple entries, second from top might be second min
        # This is a simplified approach - more complex logic needed for complete accuracy
        unique_mins = list(set(self.min_stack))
        if len(unique_mins) >= 2:
            unique_mins.sort()
            return unique_mins[1]
        else:
            # All elements in min_stack are same, find second min from main_stack
            sorted_unique = sorted(set(self.main_stack))
            return sorted_unique[1] if len(sorted_unique) >= 2 else None
    
    def get_range(self):
        """Get difference between max and min"""
        if not self.main_stack:
            raise IndexError("Stack is empty")
        return self.get_max() - self.get_min()
    
    def pop_min(self):
        """Pop elements until we remove the current minimum"""
        if not self.main_stack:
            raise IndexError("Stack is empty")
        
        target_min = self.get_min()
        popped_elements = []
        
        while self.main_stack:
            popped = self.pop()
            popped_elements.append(popped)
            if popped == target_min:
                break
        
        print(f"Popped elements to remove min {target_min}: {popped_elements}")
        return popped_elements
    
    def size_below_threshold(self, threshold):
        """Count elements below a threshold"""
        return sum(1 for x in self.main_stack if x < threshold)
    
    def display_advanced(self):
        """Display advanced stack state"""
        print("\n--- Advanced Min Stack State ---")
        if not self.main_stack:
            print("Stack is empty")
            return
        
        print(f"Main Stack: {self.main_stack}")
        print(f"Min Stack:  {self.min_stack}")
        print(f"Max Stack:  {self.max_stack}")
        print(f"Current Min: {self.get_min()}")
        print(f"Current Max: {self.get_max()}")
        print(f"Range: {self.get_range()}")
        
        try:
            print(f"Second Min: {self.get_second_min()}")
        except (ValueError, TypeError):
            print("Second Min: Not available")
        
        print(f"Size: {len(self.main_stack)}")
        print("--- End Advanced State ---\n")

# Test Advanced Min Stack
print("=== Testing Advanced Min Stack Operations ===")

adv_stack = AdvancedMinStack()

try:
    # Test with varied data
    test_data = [5, 2, 8, 1, 9, 1, 3, 6, 1, 4]
    
    print(f"Pushing data: {test_data}")
    for val in test_data:
        adv_stack.push(val)
    
    adv_stack.display_advanced()
    
    # Test advanced operations
    print(f"Elements below threshold 5: {adv_stack.size_below_threshold(5)}")
    print(f"Elements below threshold 3: {adv_stack.size_below_threshold(3)}")
    
    # Test pop_min operation
    print("\nTesting pop_min operation:")
    adv_stack.pop_min()
    adv_stack.display_advanced()
    
    # Test after more pops
    print("Popping 3 more elements:")
    for _ in range(3):
        adv_stack.pop()
    
    adv_stack.display_advanced()

except (IndexError, ValueError) as e:
    print(f"Error: {e}")
# Out:
# === Testing Advanced Min Stack Operations ===
# Pushing data: [5, 2, 8, 1, 9, 1, 3, 6, 1, 4]
# Pushed 5 | Min: 5 | Max: 5
# Pushed 2 | Min: 2 | Max: 5
# Pushed 8 | Min: 2 | Max: 8
# Pushed 1 | Min: 1 | Max: 8
# Pushed 9 | Min: 1 | Max: 9
# Pushed 1 | Min: 1 | Max: 9
# Pushed 3 | Min: 1 | Max: 9
# Pushed 6 | Min: 1 | Max: 9
# Pushed 1 | Min: 1 | Max: 9
# Pushed 4 | Min: 1 | Max: 9
#
# --- Advanced Min Stack State ---
# Main Stack: [5, 2, 8, 1, 9, 1, 3, 6, 1, 4]
# Min Stack:  [5, 2, 1, 1, 1]
# Max Stack:  [5, 8, 9]
# Current Min: 1
# Current Max: 9
# Range: 8
# Second Min: 2
# Size: 10
# --- End Advanced State ---
#
# Elements below threshold 5: 6
# Elements below threshold 3: 4
#
# Testing pop_min operation:
# Popped 4 | Min: 1 | Max: 9
# Popped 1 | Min: 1 | Max: 9
# Popped elements to remove min 1: [4, 1]
#
# --- Advanced Min Stack State ---
# Main Stack: [5, 2, 8, 1, 9, 1, 3, 6]
# Min Stack:  [5, 2, 1, 1]
# Max Stack:  [5, 8, 9]
# Current Min: 1
# Current Max: 9
# Range: 8
# Second Min: 2
# Size: 8
# --- End Advanced State ---
#
# Popping 3 more elements:
# Popped 6 | Min: 1 | Max: 9
# Popped 3 | Min: 1 | Max: 9
# Popped 1 | Min: 1 | Max: 9
#
# --- Advanced Min Stack State ---
# Main Stack: [5, 2, 8, 1, 9]
# Min Stack:  [5, 2, 1]
# Max Stack:  [5, 8, 9]
# Current Min: 1
# Current Max: 9
# Range: 8
# Second Min: 2
# Size: 5
# --- End Advanced State ---

# %% [markdown]
# ## Performance Comparison and Analysis
#
# Let's create a comprehensive comparison of all the Min Stack approaches we've implemented:

# %%
import time
import random

def performance_test():
    """Performance test comparing different Min Stack implementations"""
    
    # Test data
    test_sizes = [100, 500, 1000]
    operations_per_test = 1000
    
    print("=== Performance Comparison ===")
    print(f"Testing with {operations_per_test} operations each")
    print("=" * 60)
    
    for size in test_sizes:
        print(f"\nTest Size: {size} elements")
        print("-" * 40)
        
        # Generate test data
        test_data = [random.randint(1, 1000) for _ in range(size)]
        
        # Test Array Two-Stack approach
        start_time = time.time()
        try:
            stack1 = MinStackArray(size + 100)  # Extra space for operations
            for val in test_data:
                stack1.push(val)
            
            # Perform mixed operations
            for _ in range(operations_per_test // 4):
                stack1.get_min()
                if not stack1.is_empty():
                    stack1.pop()
                stack1.push(random.randint(1, 1000))
                stack1.get_min()
            
            array_two_time = time.time() - start_time
            print(f"Array Two-Stack:     {array_two_time:.6f} seconds")
        except Exception as e:
            print(f"Array Two-Stack:     Error - {e}")
            array_two_time = float('inf')
        
        # Test Array Pairs approach
        start_time = time.time()
        try:
            stack2 = MinStackArrayPairs(size + 100)
            for val in test_data:
                stack2.push(val)
            
            # Perform mixed operations
            for _ in range(operations_per_test // 4):
                stack2.get_min()
                if not stack2.is_empty():
                    stack2.pop()
                stack2.push(random.randint(1, 1000))
                stack2.get_min()
            
            array_pairs_time = time.time() - start_time
            print(f"Array Pairs:         {array_pairs_time:.6f} seconds")
        except Exception as e:
            print(f"Array Pairs:         Error - {e}")
            array_pairs_time = float('inf')
        
        # Test LinkedList Two-Stack approach
        start_time = time.time()
        try:
            stack3 = MinStackLinkedList()
            for val in test_data:
                stack3.push(val)
            
            # Perform mixed operations
            for _ in range(operations_per_test // 4):
                stack3.get_min()
                if not stack3.is_empty():
                    stack3.pop()
                stack3.push(random.randint(1, 1000))
                stack3.get_min()
            
            ll_two_time = time.time() - start_time
            print(f"LinkedList Two-Stack: {ll_two_time:.6f} seconds")
        except Exception as e:
            print(f"LinkedList Two-Stack: Error - {e}")
            ll_two_time = float('inf')
        
        # Test LinkedList Pairs approach
        start_time = time.time()
        try:
            stack4 = MinStackLinkedListPairs()
            for val in test_data:
                stack4.push(val)
            
            # Perform mixed operations
            for _ in range(operations_per_test // 4):
                stack4.get_min()
                if not stack4.is_empty():
                    stack4.pop()
                stack4.push(random.randint(1, 1000))
                stack4.get_min()
            
            ll_pairs_time = time.time() - start_time
            print(f"LinkedList Pairs:     {ll_pairs_time:.6f} seconds")
        except Exception as e:
            print(f"LinkedList Pairs:     Error - {e}")
            ll_pairs_time = float('inf')
        
        # Find the fastest
        times = {
            'Array Two-Stack': array_two_time,
            'Array Pairs': array_pairs_time,
            'LinkedList Two-Stack': ll_two_time,
            'LinkedList Pairs': ll_pairs_time
        }
        
        fastest = min(times, key=times.get)
        if times[fastest] != float('inf'):
            print(f"Fastest: {fastest}")

# Run performance test
performance_test()
# Out:
# === Performance Comparison ===
# Testing with 1000 operations each
# ============================================================
#
# Test Size: 100 elements
# ----------------------------------------
# Pushed 548 | Current min: 3
# Popped 548 | Current min: 3
# Pushed 560 | Current min: 3
# Popped 560 | Current min: 3
# Pushed 951 | Current min: 3
# Popped 951 | Current min: 3
# Pushed 644 | Current min: 3
# Popped 644 | Current min: 3
# Pushed 795 | Current min: 3
# Popped 795 | Current min: 3
# Pushed 454 | Current min: 3
# Popped 454 | Current min: 3
# Pushed 890 | Current min: 3
# Popped 890 | Current min: 3
# Pushed 824 | Current min: 3
# Popped 824 | Current min: 3
# Pushed 580 | Current min: 3
# Array Two-Stack:     0.006943 seconds
# MinStackArrayPairs initialized with max size: 200
# Pushed 163 with min context 163
# Pushed 431 with min context 163
# Pushed 926 with min context 163
# Pushed 947 with min context 163
# Pushed 610 with min context 163
# Pushed 296 with min context 163
# Pushed 135 with min context 135
# Pushed 421 with min context 135
# Pushed 830 with min context 135
# Pushed 372 with min context 135
# Pushed 420 with min context 135
# Pushed 618 with min context 135
# Pushed 512 with min context 135
# Pushed 777 with min context 135
# Pushed 519 with min context 135
# Pushed 500 with min context 135
# Pushed 999 with min context 135
# Pushed 429 with min context 135
# Pushed 532 with min context 135
# Pushed 47 with min context 47
# Pushed 847 with min context 47
# Pushed 3 with min context 3
# Pushed 675 with min context 3
# Pushed 434 with min context 3
# Pushed 180 with min context 3
# Pushed 707 with min context 3
# Pushed 607 with min context 3
# Pushed 922 with min context 3
# Pushed 622 with min context 3
# Pushed 566 with min context 3
# Pushed 827 with min context 3
# Pushed 260 with min context 3
# Pushed 397 with min context 3
# Pushed 904 with min context 3
# Pushed 228 with min context 3
# Pushed 389 with min context 3
# Pushed 35 with min context 3
# Pushed 689 with min context 3
# Pushed 681 with min context 3
# Pushed 186 with min context 3
# Pushed 172 with min context 3
# Pushed 676 with min context 3
# Pushed 906 with min context 3
# Pushed 186 with min context 3
# Pushed 398 with min context 3
# Pushed 478 with min context 3
# Pushed 532 with min context 3
# Pushed 609 with min context 3
# Pushed 280 with min context 3
# Pushed 350 with min context 3
# Pushed 802 with min context 3
# Pushed 692 with min context 3
# Pushed 931 with min context 3
# Pushed 827 with min context 3
# Pushed 298 with min context 3
# Pushed 896 with min context 3
# Pushed 395 with min context 3
# Pushed 409 with min context 3
# Pushed 438 with min context 3
# Pushed 725 with min context 3
# Pushed 542 with min context 3
# Pushed 274 with min context 3
# Pushed 449 with min context 3
# Pushed 951 with min context 3
# Pushed 425 with min context 3
# Pushed 254 with min context 3
# Pushed 718 with min context 3
# Pushed 246 with min context 3
# Pushed 789 with min context 3
# Pushed 634 with min context 3
# Pushed 455 with min context 3
# Pushed 349 with min context 3
# Pushed 563 with min context 3
# Pushed 105 with min context 3
# Pushed 381 with min context 3
# Pushed 70 with min context 3
# Pushed 682 with min context 3
# Pushed 54 with min context 3
# Pushed 419 with min context 3
# Pushed 396 with min context 3
# Pushed 38 with min context 3
# Pushed 623 with min context 3
# Pushed 283 with min context 3
# Pushed 519 with min context 3
# Pushed 887 with min context 3
# Pushed 997 with min context 3
# Pushed 938 with min context 3
# Pushed 9 with min context 3
# Pushed 742 with min context 3
# Pushed 454 with min context 3
# Pushed 666 with min context 3
# Pushed 342 with min context 3
# Pushed 709 with min context 3
# Pushed 599 with min context 3
# Pushed 733 with min context 3
# Pushed 614 with min context 3
# Pushed 51 with min context 3
# Pushed 458 with min context 3
# Pushed 207 with min context 3
# Pushed 553 with min context 3
# Popped 553 | New min: 3
# Pushed 1 with min context 1
# Popped 1 | New min: 3
# Pushed 992 with min context 3
# Popped 992 | New min: 3
# Pushed 657 with min context 3
# Popped 657 | New min: 3
# Pushed 807 with min context 3
# Popped 807 | New min: 3
# Pushed 445 with min context 3
# Popped 445 | New min: 3
# Pushed 166 with min context 3
# Popped 166 | New min: 3
# Pushed 516 with min context 3
# Popped 516 | New min: 3
# Pushed 689 with min context 3
# Popped 689 | New min: 3
# Pushed 752 with min context 3
# Popped 752 | New min: 3
# Pushed 122 with min context 3
# Popped 122 | New min: 3
# Pushed 445 with min context 3
# Popped 445 | New min: 3
# Pushed 146 with min context 3
# Popped 146 | New min: 3
# Pushed 8 with min context 3
# Popped 8 | New min: 3
# Pushed 790 with min context 3
# Popped 790 | New min: 3
# Pushed 369 with min context 3
# Popped 369 | New min: 3
# Pushed 609 with min context 3
# Popped 609 | New min: 3
# Pushed 490 with min context 3
# Popped 490 | New min: 3
# Pushed 689 with min context 3
# Popped 689 | New min: 3
# Pushed 991 with min context 3
# Popped 991 | New min: 3
# Pushed 530 with min context 3
# Popped 530 | New min: 3
# Pushed 324 with min context 3
# Popped 324 | New min: 3
# Pushed 280 with min context 3
# Popped 280 | New min: 3
# Pushed 504 with min context 3
# Popped 504 | New min: 3
# Pushed 37 with min context 3
# Popped 37 | New min: 3
# Pushed 512 with min context 3
# Popped 512 | New min: 3
# Pushed 174 with min context 3
# Popped 174 | New min: 3
# Pushed 437 with min context 3
# Popped 437 | New min: 3
# Pushed 469 with min context 3
# Popped 469 | New min: 3
# Pushed 501 with min context 3
# Popped 501 | New min: 3
# Pushed 735 with min context 3
# Popped 735 | New min: 3
# Pushed 921 with min context 3
# Popped 921 | New min: 3
# Pushed 339 with min context 3
# Popped 339 | New min: 3
# Pushed 263 with min context 3
# Popped 263 | New min: 3
# Pushed 185 with min context 3
# Popped 185 | New min: 3
# Pushed 811 with min context 3
# Popped 811 | New min: 3
# Pushed 583 with min context 3
# Popped 583 | New min: 3
# Pushed 348 with min context 3
# Popped 348 | New min: 3
# Pushed 776 with min context 3
# Popped 776 | New min: 3
# Pushed 274 with min context 3
# Popped 274 | New min: 3
# Pushed 599 with min context 3
# Popped 599 | New min: 3
# Pushed 436 with min context 3
# Popped 436 | New min: 3
# Pushed 188 with min context 3
# Popped 188 | New min: 3
# Pushed 755 with min context 3
# Popped 755 | New min: 3
# Pushed 565 with min context 3
# Popped 565 | New min: 3
# Pushed 136 with min context 3
# Popped 136 | New min: 3
# Pushed 737 with min context 3
# Popped 737 | New min: 3
# Pushed 364 with min context 3
# Popped 364 | New min: 3
# Pushed 452 with min context 3
# Popped 452 | New min: 3
# Pushed 700 with min context 3
# Popped 700 | New min: 3
# Pushed 759 with min context 3
# Popped 759 | New min: 3
# Pushed 897 with min context 3
# Popped 897 | New min: 3
# Pushed 531 with min context 3
# Popped 531 | New min: 3
# Pushed 806 with min context 3
# Popped 806 | New min: 3
# Pushed 947 with min context 3
# Popped 947 | New min: 3
# Pushed 898 with min context 3
# Popped 898 | New min: 3
# Pushed 147 with min context 3
# Popped 147 | New min: 3
# Pushed 402 with min context 3
# Popped 402 | New min: 3
# Pushed 199 with min context 3
# Popped 199 | New min: 3
# Pushed 507 with min context 3
# Popped 507 | New min: 3
# Pushed 343 with min context 3
# Popped 343 | New min: 3
# Pushed 745 with min context 3
# Popped 745 | New min: 3
# Pushed 174 with min context 3
# Popped 174 | New min: 3
# Pushed 758 with min context 3
# Popped 758 | New min: 3
# Pushed 839 with min context 3
# Popped 839 | New min: 3
# Pushed 61 with min context 3
# Popped 61 | New min: 3
# Pushed 157 with min context 3
# Popped 157 | New min: 3
# Pushed 799 with min context 3
# Popped 799 | New min: 3
# Pushed 416 with min context 3
# Popped 416 | New min: 3
# Pushed 710 with min context 3
# Popped 710 | New min: 3
# Pushed 402 with min context 3
# Popped 402 | New min: 3
# Pushed 435 with min context 3
# Popped 435 | New min: 3
# Pushed 669 with min context 3
# Popped 669 | New min: 3
# Pushed 278 with min context 3
# Popped 278 | New min: 3
# Pushed 907 with min context 3
# Popped 907 | New min: 3
# Pushed 586 with min context 3
# Popped 586 | New min: 3
# Pushed 491 with min context 3
# Popped 491 | New min: 3
# Pushed 89 with min context 3
# Popped 89 | New min: 3
# Pushed 53 with min context 3
# Popped 53 | New min: 3
# Pushed 477 with min context 3
# Popped 477 | New min: 3
# Pushed 97 with min context 3
# Popped 97 | New min: 3
# Pushed 768 with min context 3
# Popped 768 | New min: 3
# Pushed 114 with min context 3
# Popped 114 | New min: 3
# Pushed 146 with min context 3
# Popped 146 | New min: 3
# Pushed 477 with min context 3
# Popped 477 | New min: 3
# Pushed 191 with min context 3
# Popped 191 | New min: 3
# Pushed 169 with min context 3
# Popped 169 | New min: 3
# Pushed 925 with min context 3
# Popped 925 | New min: 3
# Pushed 754 with min context 3
# Popped 754 | New min: 3
# Pushed 695 with min context 3
# Popped 695 | New min: 3
# Pushed 6 with min context 3
# Popped 6 | New min: 3
# Pushed 649 with min context 3
# Popped 649 | New min: 3
# Pushed 868 with min context 3
# Popped 868 | New min: 3
# Pushed 556 with min context 3
# Popped 556 | New min: 3
# Pushed 206 with min context 3
# Popped 206 | New min: 3
# Pushed 335 with min context 3
# Popped 335 | New min: 3
# Pushed 166 with min context 3
# Popped 166 | New min: 3
# Pushed 935 with min context 3
# Popped 935 | New min: 3
# Pushed 320 with min context 3
# Popped 320 | New min: 3
# Pushed 997 with min context 3
# Popped 997 | New min: 3
# Pushed 737 with min context 3
# Popped 737 | New min: 3
# Pushed 345 with min context 3
# Popped 345 | New min: 3
# Pushed 316 with min context 3
# Popped 316 | New min: 3
# Pushed 99 with min context 3
# Popped 99 | New min: 3
# Pushed 474 with min context 3
# Popped 474 | New min: 3
# Pushed 566 with min context 3
# Popped 566 | New min: 3
# Pushed 726 with min context 3
# Popped 726 | New min: 3
# Pushed 816 with min context 3
# Popped 816 | New min: 3
# Pushed 855 with min context 3
# Popped 855 | New min: 3
# Pushed 4 with min context 3
# Popped 4 | New min: 3
# Pushed 131 with min context 3
# Popped 131 | New min: 3
# Pushed 346 with min context 3
# Popped 346 | New min: 3
# Pushed 105 with min context 3
# Popped 105 | New min: 3
# Pushed 508 with min context 3
# Popped 508 | New min: 3
# Pushed 976 with min context 3
# Popped 976 | New min: 3
# Pushed 688 with min context 3
# Popped 688 | New min: 3
# Pushed 583 with min context 3
# Popped 583 | New min: 3
# Pushed 189 with min context 3
# Popped 189 | New min: 3
# Pushed 14 with min context 3
# Popped 14 | New min: 3
# Pushed 563 with min context 3
# Popped 563 | New min: 3
# Pushed 387 with min context 3
# Popped 387 | New min: 3
# Pushed 254 with min context 3
# Popped 254 | New min: 3
# Pushed 775 with min context 3
# Popped 775 | New min: 3
# Pushed 540 with min context 3
# Popped 540 | New min: 3
# Pushed 124 with min context 3
# Popped 124 | New min: 3
# Pushed 190 with min context 3
# Popped 190 | New min: 3
# Pushed 673 with min context 3
# Popped 673 | New min: 3
# Pushed 448 with min context 3
# Popped 448 | New min: 3
# Pushed 464 with min context 3
# Popped 464 | New min: 3
# Pushed 239 with min context 3
# Popped 239 | New min: 3
# Pushed 368 with min context 3
# Popped 368 | New min: 3
# Pushed 180 with min context 3
# Popped 180 | New min: 3
# Pushed 924 with min context 3
# Popped 924 | New min: 3
# Pushed 760 with min context 3
# Popped 760 | New min: 3
# Pushed 580 with min context 3
# Popped 580 | New min: 3
# Pushed 929 with min context 3
# Popped 929 | New min: 3
# Pushed 477 with min context 3
# Popped 477 | New min: 3
# Pushed 406 with min context 3
# Popped 406 | New min: 3
# Pushed 592 with min context 3
# Popped 592 | New min: 3
# Pushed 188 with min context 3
# Popped 188 | New min: 3
# Pushed 444 with min context 3
# Popped 444 | New min: 3
# Pushed 517 with min context 3
# Popped 517 | New min: 3
# Pushed 654 with min context 3
# Popped 654 | New min: 3
# Pushed 213 with min context 3
# Popped 213 | New min: 3
# Pushed 118 with min context 3
# Popped 118 | New min: 3
# Pushed 746 with min context 3
# Popped 746 | New min: 3
# Pushed 229 with min context 3
# Popped 229 | New min: 3
# Pushed 262 with min context 3
# Popped 262 | New min: 3
# Pushed 839 with min context 3
# Popped 839 | New min: 3
# Pushed 906 with min context 3
# Popped 906 | New min: 3
# Pushed 875 with min context 3
# Popped 875 | New min: 3
# Pushed 897 with min context 3
# Popped 897 | New min: 3
# Pushed 421 with min context 3
# Popped 421 | New min: 3
# Pushed 911 with min context 3
# Popped 911 | New min: 3
# Pushed 258 with min context 3
# Popped 258 | New min: 3
# Pushed 612 with min context 3
# Popped 612 | New min: 3
# Pushed 77 with min context 3
# Popped 77 | New min: 3
# Pushed 44 with min context 3
# Popped 44 | New min: 3
# Pushed 208 with min context 3
# Popped 208 | New min: 3
# Pushed 584 with min context 3
# Popped 584 | New min: 3
# Pushed 908 with min context 3
# Popped 908 | New min: 3
# Pushed 641 with min context 3
# Popped 641 | New min: 3
# Pushed 50 with min context 3
# Popped 50 | New min: 3
# Pushed 51 with min context 3
# Popped 51 | New min: 3
# Pushed 117 with min context 3
# Popped 117 | New min: 3
# Pushed 97 with min context 3
# Popped 97 | New min: 3
# Pushed 563 with min context 3
# Popped 563 | New min: 3
# Pushed 955 with min context 3
# Popped 955 | New min: 3
# Pushed 290 with min context 3
# Popped 290 | New min: 3
# Pushed 99 with min context 3
# Popped 99 | New min: 3
# Pushed 367 with min context 3
# Popped 367 | New min: 3
# Pushed 787 with min context 3
# Popped 787 | New min: 3
# Pushed 202 with min context 3
# Popped 202 | New min: 3
# Pushed 420 with min context 3
# Popped 420 | New min: 3
# Pushed 431 with min context 3
# Popped 431 | New min: 3
# Pushed 940 with min context 3
# Popped 940 | New min: 3
# Pushed 681 with min context 3
# Popped 681 | New min: 3
# Pushed 376 with min context 3
# Popped 376 | New min: 3
# Pushed 607 with min context 3
# Popped 607 | New min: 3
# Pushed 345 with min context 3
# Popped 345 | New min: 3
# Pushed 962 with min context 3
# Popped 962 | New min: 3
# Pushed 749 with min context 3
# Popped 749 | New min: 3
# Pushed 470 with min context 3
# Popped 470 | New min: 3
# Pushed 199 with min context 3
# Popped 199 | New min: 3
# Pushed 58 with min context 3
# Popped 58 | New min: 3
# Pushed 212 with min context 3
# Popped 212 | New min: 3
# Pushed 266 with min context 3
# Popped 266 | New min: 3
# Pushed 783 with min context 3
# Popped 783 | New min: 3
# Pushed 972 with min context 3
# Popped 972 | New min: 3
# Pushed 870 with min context 3
# Popped 870 | New min: 3
# Pushed 895 with min context 3
# Popped 895 | New min: 3
# Pushed 997 with min context 3
# Popped 997 | New min: 3
# Pushed 76 with min context 3
# Popped 76 | New min: 3
# Pushed 194 with min context 3
# Popped 194 | New min: 3
# Pushed 494 with min context 3
# Popped 494 | New min: 3
# Pushed 494 with min context 3
# Popped 494 | New min: 3
# Pushed 649 with min context 3
# Popped 649 | New min: 3
# Pushed 508 with min context 3
# Popped 508 | New min: 3
# Pushed 762 with min context 3
# Popped 762 | New min: 3
# Pushed 89 with min context 3
# Popped 89 | New min: 3
# Pushed 291 with min context 3
# Popped 291 | New min: 3
# Pushed 719 with min context 3
# Popped 719 | New min: 3
# Pushed 806 with min context 3
# Popped 806 | New min: 3
# Pushed 33 with min context 3
# Popped 33 | New min: 3
# Pushed 702 with min context 3
# Popped 702 | New min: 3
# Pushed 228 with min context 3
# Popped 228 | New min: 3
# Pushed 75 with min context 3
# Popped 75 | New min: 3
# Pushed 40 with min context 3
# Popped 40 | New min: 3
# Pushed 342 with min context 3
# Popped 342 | New min: 3
# Pushed 911 with min context 3
# Popped 911 | New min: 3
# Pushed 531 with min context 3
# Popped 531 | New min: 3
# Pushed 300 with min context 3
# Popped 300 | New min: 3
# Pushed 338 with min context 3
# Popped 338 | New min: 3
# Pushed 271 with min context 3
# Popped 271 | New min: 3
# Pushed 996 with min context 3
# Popped 996 | New min: 3
# Pushed 403 with min context 3
# Popped 403 | New min: 3
# Pushed 871 with min context 3
# Popped 871 | New min: 3
# Pushed 966 with min context 3
# Popped 966 | New min: 3
# Pushed 566 with min context 3
# Popped 566 | New min: 3
# Pushed 91 with min context 3
# Popped 91 | New min: 3
# Pushed 1000 with min context 3
# Popped 1000 | New min: 3
# Pushed 310 with min context 3
# Popped 310 | New min: 3
# Pushed 629 with min context 3
# Popped 629 | New min: 3
# Pushed 328 with min context 3
# Popped 328 | New min: 3
# Pushed 270 with min context 3
# Popped 270 | New min: 3
# Pushed 329 with min context 3
# Popped 329 | New min: 3
# Pushed 16 with min context 3
# Popped 16 | New min: 3
# Pushed 779 with min context 3
# Popped 779 | New min: 3
# Pushed 808 with min context 3
# Popped 808 | New min: 3
# Pushed 410 with min context 3
# Popped 410 | New min: 3
# Pushed 48 with min context 3
# Popped 48 | New min: 3
# Pushed 760 with min context 3
# Popped 760 | New min: 3
# Pushed 381 with min context 3
# Popped 381 | New min: 3
# Pushed 638 with min context 3
# Popped 638 | New min: 3
# Pushed 754 with min context 3
# Popped 754 | New min: 3
# Pushed 906 with min context 3
# Popped 906 | New min: 3
# Pushed 340 with min context 3
# Popped 340 | New min: 3
# Pushed 307 with min context 3
# Popped 307 | New min: 3
# Pushed 164 with min context 3
# Popped 164 | New min: 3
# Pushed 215 with min context 3
# Popped 215 | New min: 3
# Pushed 92 with min context 3
# Popped 92 | New min: 3
# Pushed 55 with min context 3
# Popped 55 | New min: 3
# Pushed 518 with min context 3
# Popped 518 | New min: 3
# Pushed 603 with min context 3
# Popped 603 | New min: 3
# Pushed 839 with min context 3
# Popped 839 | New min: 3
# Pushed 213 with min context 3
# Popped 213 | New min: 3
# Pushed 294 with min context 3
# Popped 294 | New min: 3
# Pushed 536 with min context 3
# Popped 536 | New min: 3
# Pushed 461 with min context 3
# Popped 461 | New min: 3
# Pushed 652 with min context 3
# Popped 652 | New min: 3
# Pushed 966 with min context 3
# Array Pairs:         0.005512 seconds
# MinStackLinkedList initialized
# Pushed 163 | Current min: 163
# Pushed 431 | Current min: 163
# Pushed 926 | Current min: 163
# Pushed 947 | Current min: 163
# Pushed 610 | Current min: 163
# Pushed 296 | Current min: 163
# Pushed 135 | Current min: 135
# Pushed 421 | Current min: 135
# Pushed 830 | Current min: 135
# Pushed 372 | Current min: 135
# Pushed 420 | Current min: 135
# Pushed 618 | Current min: 135
# Pushed 512 | Current min: 135
# Pushed 777 | Current min: 135
# Pushed 519 | Current min: 135
# Pushed 500 | Current min: 135
# Pushed 999 | Current min: 135
# Pushed 429 | Current min: 135
# Pushed 532 | Current min: 135
# Pushed 47 | Current min: 47
# Pushed 847 | Current min: 47
# Pushed 3 | Current min: 3
# Pushed 675 | Current min: 3
# Pushed 56 | Current min: 3
# Popped 56 | Current min: 3
# ...
# Pushed 640 with min context 2
# Pushed 105 with min context 2
# Pushed 984 with min context 2
# Pushed 334 with min context 2
# Pushed 853 with min context 2
# Pushed 102 with min context 2
# Pushed 863 with min context 2
# Pushed 772 with min context 2
# Pushed 674 with min context 2
# Pushed 217 with min context 2
# Pushed 807 with min context 2
# Pushed 582 with min context 2
# Pushed 659 with min context 2
# Pushed 388 with min context 2
# Pushed 349 with min context 2
# Pushed 372 with min context 2
# Pushed 533 with min context 2
# Pushed 789 with min context 2
# Pushed 121 with min context 2
# Pushed 450 with min context 2
# Pushed 947 with min context 2
# Pushed 782 with min context 2
# Pushed 505 with min context 2
# Pushed 533 with min context 2
# Pushed 502 with min context 2
# Pushed 396 with min context 2
# Pushed 872 with min context 2
# Pushed 891 with min context 2
# Pushed 176 with min context 2
# Pushed 350 with min context 2
# Pushed 188 with min context 2
# Pushed 974 with min context 2
# Pushed 967 with min context 2
# Pushed 683 with min context 2
# Pushed 782 with min context 2
# Pushed 588 with min context 2
# Pushed 79 with min context 2
# Pushed 371 with min context 2
# Pushed 992 with min context 2
# Pushed 806 with min context 2
# Pushed 828 with min context 2
# Pushed 792 with min context 2
# Pushed 224 with min context 2
# Pushed 421 with min context 2
# Pushed 751 with min context 2
# Pushed 121 with min context 2
# Pushed 694 with min context 2
# Pushed 38 with min context 2
# Pushed 386 with min context 2
# Pushed 699 with min context 2
# Pushed 318 with min context 2
# Pushed 899 with min context 2
# Pushed 842 with min context 2
# Pushed 822 with min context 2
# Pushed 286 with min context 2
# Pushed 896 with min context 2
# Pushed 262 with min context 2
# Pushed 551 with min context 2
# Pushed 896 with min context 2
# Pushed 798 with min context 2
# Pushed 897 with min context 2
# Pushed 208 with min context 2
# Pushed 578 with min context 2
# Pushed 576 with min context 2
# Pushed 805 with min context 2
# Pushed 4 with min context 2
# Pushed 746 with min context 2
# Pushed 14 with min context 2
# Pushed 340 with min context 2
# Pushed 446 with min context 2
# Pushed 147 with min context 2
# Pushed 225 with min context 2
# Pushed 365 with min context 2
# Pushed 288 with min context 2
# Pushed 514 with min context 2
# Pushed 805 with min context 2
# Pushed 649 with min context 2
# Pushed 19 with min context 2
# Pushed 263 with min context 2
# Pushed 452 with min context 2
# Pushed 158 with min context 2
# Pushed 927 with min context 2
# Pushed 173 with min context 2
# Popped 173 | New min: 2
# Pushed 431 with min context 2
# Popped 431 | New min: 2
# Pushed 45 with min context 2
# Popped 45 | New min: 2
# Pushed 838 with min context 2
# Popped 838 | New min: 2
# Pushed 69 with min context 2
# Popped 69 | New min: 2
# Pushed 871 with min context 2
# Popped 871 | New min: 2
# Pushed 975 with min context 2
# Popped 975 | New min: 2
# Pushed 208 with min context 2
# Popped 208 | New min: 2
# Pushed 876 with min context 2
# Popped 876 | New min: 2
# Pushed 404 with min context 2
# Popped 404 | New min: 2
# Pushed 296 with min context 2
# Popped 296 | New min: 2
# Pushed 647 with min context 2
# Popped 647 | New min: 2
# Pushed 258 with min context 2
# Popped 258 | New min: 2
# Pushed 294 with min context 2
# Popped 294 | New min: 2
# Pushed 861 with min context 2
# Popped 861 | New min: 2
# Pushed 734 with min context 2
# Popped 734 | New min: 2
# Pushed 364 with min context 2
# Popped 364 | New min: 2
# Pushed 706 with min context 2
# Popped 706 | New min: 2
# Pushed 85 with min context 2
# Popped 85 | New min: 2
# Pushed 153 with min context 2
# Popped 153 | New min: 2
# Pushed 655 with min context 2
# Popped 655 | New min: 2
# Pushed 16 with min context 2
# Popped 16 | New min: 2
# Pushed 718 with min context 2
# Popped 718 | New min: 2
# Pushed 852 with min context 2
# Popped 852 | New min: 2
# Pushed 189 with min context 2
# Popped 189 | New min: 2
# Pushed 991 with min context 2
# Popped 991 | New min: 2
# Pushed 338 with min context 2
# Popped 338 | New min: 2
# Pushed 825 with min context 2
# Popped 825 | New min: 2
# Pushed 565 with min context 2
# Popped 565 | New min: 2
# Pushed 732 with min context 2
# Popped 732 | New min: 2
# Pushed 982 with min context 2
# Popped 982 | New min: 2
# Pushed 832 with min context 2
# Popped 832 | New min: 2
# Pushed 329 with min context 2
# Popped 329 | New min: 2
# Pushed 740 with min context 2
# Popped 740 | New min: 2
# Pushed 527 with min context 2
# Popped 527 | New min: 2
# Pushed 689 with min context 2
# Popped 689 | New min: 2
# Pushed 344 with min context 2
# Popped 344 | New min: 2
# Pushed 591 with min context 2
# Popped 591 | New min: 2
# Pushed 998 with min context 2
# Popped 998 | New min: 2
# Pushed 452 with min context 2
# Popped 452 | New min: 2
# Pushed 857 with min context 2
# Popped 857 | New min: 2
# Pushed 590 with min context 2
# Popped 590 | New min: 2
# Pushed 176 with min context 2
# Popped 176 | New min: 2
# Pushed 551 with min context 2
# Popped 551 | New min: 2
# Pushed 838 with min context 2
# Popped 838 | New min: 2
# Pushed 382 with min context 2
# Popped 382 | New min: 2
# Pushed 148 with min context 2
# Popped 148 | New min: 2
# Pushed 976 with min context 2
# Popped 976 | New min: 2
# Pushed 428 with min context 2
# Popped 428 | New min: 2
# Pushed 410 with min context 2
# Popped 410 | New min: 2
# Pushed 564 with min context 2
# Popped 564 | New min: 2
# Pushed 941 with min context 2
# Popped 941 | New min: 2
# Pushed 991 with min context 2
# Popped 991 | New min: 2
# Pushed 603 with min context 2
# Popped 603 | New min: 2
# Pushed 68 with min context 2
# Popped 68 | New min: 2
# Pushed 867 with min context 2
# Popped 867 | New min: 2
# Pushed 204 with min context 2
# Popped 204 | New min: 2
# Pushed 716 with min context 2
# Popped 716 | New min: 2
# Pushed 710 with min context 2
# Popped 710 | New min: 2
# Pushed 295 with min context 2
# Popped 295 | New min: 2
# Pushed 652 with min context 2
# Popped 652 | New min: 2
# Pushed 585 with min context 2
# Popped 585 | New min: 2
# Pushed 157 with min context 2
# Popped 157 | New min: 2
# Pushed 307 with min context 2
# Popped 307 | New min: 2
# Pushed 252 with min context 2
# Popped 252 | New min: 2
# Pushed 266 with min context 2
# Popped 266 | New min: 2
# Pushed 389 with min context 2
# Popped 389 | New min: 2
# Pushed 904 with min context 2
# Popped 904 | New min: 2
# Pushed 777 with min context 2
# Popped 777 | New min: 2
# Pushed 651 with min context 2
# Popped 651 | New min: 2
# Pushed 747 with min context 2
# Popped 747 | New min: 2
# Pushed 563 with min context 2
# Popped 563 | New min: 2
# Pushed 442 with min context 2
# Popped 442 | New min: 2
# Pushed 953 with min context 2
# Popped 953 | New min: 2
# Pushed 187 with min context 2
# Popped 187 | New min: 2
# Pushed 153 with min context 2
# Popped 153 | New min: 2
# Pushed 365 with min context 2
# Popped 365 | New min: 2
# Pushed 655 with min context 2
# Popped 655 | New min: 2
# Pushed 27 with min context 2
# Popped 27 | New min: 2
# Pushed 597 with min context 2
# Popped 597 | New min: 2
# Pushed 462 with min context 2
# Popped 462 | New min: 2
# Pushed 36 with min context 2
# Popped 36 | New min: 2
# Pushed 814 with min context 2
# Popped 814 | New min: 2
# Pushed 710 with min context 2
# Popped 710 | New min: 2
# Pushed 716 with min context 2
# Popped 716 | New min: 2
# Pushed 992 with min context 2
# Popped 992 | New min: 2
# Pushed 906 with min context 2
# Popped 906 | New min: 2
# Pushed 844 with min context 2
# Popped 844 | New min: 2
# Pushed 591 with min context 2
# Popped 591 | New min: 2
# Pushed 39 with min context 2
# Popped 39 | New min: 2
# Pushed 716 with min context 2
# Popped 716 | New min: 2
# Pushed 568 with min context 2
# Popped 568 | New min: 2
# Pushed 12 with min context 2
# Popped 12 | New min: 2
# Pushed 776 with min context 2
# Popped 776 | New min: 2
# Pushed 338 with min context 2
# Popped 338 | New min: 2
# Pushed 752 with min context 2
# Popped 752 | New min: 2
# Pushed 768 with min context 2
# Popped 768 | New min: 2
# Pushed 172 with min context 2
# Popped 172 | New min: 2
# Pushed 186 with min context 2
# Popped 186 | New min: 2
# Pushed 45 with min context 2
# Popped 45 | New min: 2
# Pushed 690 with min context 2
# Popped 690 | New min: 2
# Pushed 273 with min context 2
# Popped 273 | New min: 2
# Pushed 140 with min context 2
# Popped 140 | New min: 2
# Pushed 637 with min context 2
# Popped 637 | New min: 2
# Pushed 576 with min context 2
# Popped 576 | New min: 2
# Pushed 201 with min context 2
# Popped 201 | New min: 2
# Pushed 596 with min context 2
# Popped 596 | New min: 2
# Pushed 546 with min context 2
# Popped 546 | New min: 2
# Pushed 835 with min context 2
# Popped 835 | New min: 2
# Pushed 654 with min context 2
# Popped 654 | New min: 2
# Pushed 186 with min context 2
# Popped 186 | New min: 2
# Pushed 554 with min context 2
# Popped 554 | New min: 2
# Pushed 236 with min context 2
# Popped 236 | New min: 2
# Pushed 302 with min context 2
# Popped 302 | New min: 2
# Pushed 796 with min context 2
# Popped 796 | New min: 2
# Pushed 820 with min context 2
# Popped 820 | New min: 2
# Pushed 149 with min context 2
# Popped 149 | New min: 2
# Pushed 136 with min context 2
# Popped 136 | New min: 2
# Pushed 626 with min context 2
# Popped 626 | New min: 2
# Pushed 898 with min context 2
# Popped 898 | New min: 2
# Pushed 542 with min context 2
# Popped 542 | New min: 2
# Pushed 592 with min context 2
# Popped 592 | New min: 2
# Pushed 11 with min context 2
# Popped 11 | New min: 2
# Pushed 803 with min context 2
# Popped 803 | New min: 2
# Pushed 222 with min context 2
# Popped 222 | New min: 2
# Pushed 292 with min context 2
# Popped 292 | New min: 2
# Pushed 644 with min context 2
# Popped 644 | New min: 2
# Pushed 604 with min context 2
# Popped 604 | New min: 2
# Pushed 709 with min context 2
# Popped 709 | New min: 2
# Pushed 5 with min context 2
# Popped 5 | New min: 2
# Pushed 991 with min context 2
# Popped 991 | New min: 2
# Pushed 951 with min context 2
# Popped 951 | New min: 2
# Pushed 493 with min context 2
# Popped 493 | New min: 2
# Pushed 515 with min context 2
# Popped 515 | New min: 2
# Pushed 616 with min context 2
# Popped 616 | New min: 2
# Pushed 629 with min context 2
# Popped 629 | New min: 2
# Pushed 350 with min context 2
# Popped 350 | New min: 2
# Pushed 244 with min context 2
# Popped 244 | New min: 2
# Pushed 977 with min context 2
# Popped 977 | New min: 2
# Pushed 900 with min context 2
# Popped 900 | New min: 2
# Pushed 330 with min context 2
# Popped 330 | New min: 2
# Pushed 636 with min context 2
# Popped 636 | New min: 2
# Pushed 792 with min context 2
# Popped 792 | New min: 2
# Pushed 27 with min context 2
# Popped 27 | New min: 2
# Pushed 637 with min context 2
# Popped 637 | New min: 2
# Pushed 654 with min context 2
# Popped 654 | New min: 2
# Pushed 41 with min context 2
# Popped 41 | New min: 2
# Pushed 220 with min context 2
# Popped 220 | New min: 2
# Pushed 501 with min context 2
# Popped 501 | New min: 2
# Pushed 81 with min context 2
# Popped 81 | New min: 2
# Pushed 911 with min context 2
# Popped 911 | New min: 2
# Pushed 826 with min context 2
# Popped 826 | New min: 2
# Pushed 868 with min context 2
# Popped 868 | New min: 2
# Pushed 320 with min context 2
# Popped 320 | New min: 2
# Pushed 824 with min context 2
# Popped 824 | New min: 2
# Pushed 115 with min context 2
# Popped 115 | New min: 2
# Pushed 741 with min context 2
# Popped 741 | New min: 2
# Pushed 815 with min context 2
# Popped 815 | New min: 2
# Pushed 800 with min context 2
# Popped 800 | New min: 2
# Pushed 937 with min context 2
# Popped 937 | New min: 2
# Pushed 459 with min context 2
# Popped 459 | New min: 2
# Pushed 263 with min context 2
# Popped 263 | New min: 2
# Pushed 318 with min context 2
# Popped 318 | New min: 2
# Pushed 46 with min context 2
# Popped 46 | New min: 2
# Pushed 773 with min context 2
# Popped 773 | New min: 2
# Pushed 231 with min context 2
# Popped 231 | New min: 2
# Pushed 486 with min context 2
# Popped 486 | New min: 2
# Pushed 670 with min context 2
# Popped 670 | New min: 2
# Pushed 204 with min context 2
# Popped 204 | New min: 2
# Pushed 756 with min context 2
# Popped 756 | New min: 2
# Pushed 45 with min context 2
# Popped 45 | New min: 2
# Pushed 886 with min context 2
# Popped 886 | New min: 2
# Pushed 698 with min context 2
# Popped 698 | New min: 2
# Pushed 92 with min context 2
# Popped 92 | New min: 2
# Pushed 943 with min context 2
# Popped 943 | New min: 2
# Pushed 739 with min context 2
# Popped 739 | New min: 2
# Pushed 185 with min context 2
# Popped 185 | New min: 2
# Pushed 73 with min context 2
# Popped 73 | New min: 2
# Pushed 205 with min context 2
# Popped 205 | New min: 2
# Pushed 835 with min context 2
# Popped 835 | New min: 2
# Pushed 590 with min context 2
# Popped 590 | New min: 2
# Pushed 46 with min context 2
# Popped 46 | New min: 2
# Pushed 840 with min context 2
# Popped 840 | New min: 2
# Pushed 226 with min context 2
# Popped 226 | New min: 2
# Pushed 588 with min context 2
# Popped 588 | New min: 2
# Pushed 49 with min context 2
# Popped 49 | New min: 2
# Pushed 555 with min context 2
# Popped 555 | New min: 2
# Pushed 47 with min context 2
# Popped 47 | New min: 2
# Pushed 550 with min context 2
# Popped 550 | New min: 2
# Pushed 78 with min context 2
# Popped 78 | New min: 2
# Pushed 743 with min context 2
# Popped 743 | New min: 2
# Pushed 847 with min context 2
# Popped 847 | New min: 2
# Pushed 686 with min context 2
# Popped 686 | New min: 2
# Pushed 741 with min context 2
# Popped 741 | New min: 2
# Pushed 245 with min context 2
# Popped 245 | New min: 2
# Pushed 258 with min context 2
# Popped 258 | New min: 2
# Pushed 646 with min context 2
# Popped 646 | New min: 2
# Pushed 361 with min context 2
# Popped 361 | New min: 2
# Pushed 935 with min context 2
# Popped 935 | New min: 2
# Pushed 529 with min context 2
# Popped 529 | New min: 2
# Pushed 629 with min context 2
# Popped 629 | New min: 2
# Pushed 456 with min context 2
# Popped 456 | New min: 2
# Pushed 839 with min context 2
# Popped 839 | New min: 2
# Pushed 134 with min context 2
# Popped 134 | New min: 2
# Pushed 249 with min context 2
# Popped 249 | New min: 2
# Pushed 917 with min context 2
# Popped 917 | New min: 2
# Pushed 993 with min context 2
# Popped 993 | New min: 2
# Pushed 795 with min context 2
# Popped 795 | New min: 2
# Pushed 810 with min context 2
# Popped 810 | New min: 2
# Pushed 820 with min context 2
# Popped 820 | New min: 2
# Pushed 78 with min context 2
# Popped 78 | New min: 2
# Pushed 848 with min context 2
# Popped 848 | New min: 2
# Pushed 626 with min context 2
# Popped 626 | New min: 2
# Pushed 616 with min context 2
# Popped 616 | New min: 2
# Pushed 899 with min context 2
# Popped 899 | New min: 2
# Pushed 102 with min context 2
# Popped 102 | New min: 2
# Pushed 618 with min context 2
# Popped 618 | New min: 2
# Pushed 549 with min context 2
# Popped 549 | New min: 2
# Pushed 569 with min context 2
# Popped 569 | New min: 2
# Pushed 577 with min context 2
# Popped 577 | New min: 2
# Pushed 356 with min context 2
# Popped 356 | New min: 2
# Pushed 19 with min context 2
# Popped 19 | New min: 2
# Pushed 883 with min context 2
# Popped 883 | New min: 2
# Pushed 992 with min context 2
# Popped 992 | New min: 2
# Pushed 808 with min context 2
# Popped 808 | New min: 2
# Pushed 408 with min context 2
# Popped 408 | New min: 2
# Pushed 199 with min context 2
# Popped 199 | New min: 2
# Pushed 358 with min context 2
# Popped 358 | New min: 2
# Pushed 93 with min context 2
# Popped 93 | New min: 2
# Pushed 658 with min context 2
# Popped 658 | New min: 2
# Pushed 336 with min context 2
# Popped 336 | New min: 2
# Pushed 296 with min context 2
# Popped 296 | New min: 2
# Pushed 662 with min context 2
# Popped 662 | New min: 2
# Pushed 51 with min context 2
# Popped 51 | New min: 2
# Pushed 555 with min context 2
# Popped 555 | New min: 2
# Pushed 577 with min context 2
# Popped 577 | New min: 2
# Pushed 371 with min context 2
# Popped 371 | New min: 2
# Pushed 753 with min context 2
# Popped 753 | New min: 2
# Pushed 359 with min context 2
# Popped 359 | New min: 2
# Pushed 843 with min context 2
# Popped 843 | New min: 2
# Pushed 676 with min context 2
# Popped 676 | New min: 2
# Pushed 228 with min context 2
# Popped 228 | New min: 2
# Pushed 759 with min context 2
# Popped 759 | New min: 2
# Pushed 958 with min context 2
# Popped 958 | New min: 2
# Pushed 648 with min context 2
# Popped 648 | New min: 2
# Pushed 729 with min context 2
# Popped 729 | New min: 2
# Pushed 181 with min context 2
# Popped 181 | New min: 2
# Pushed 839 with min context 2
# Popped 839 | New min: 2
# Pushed 799 with min context 2
# Popped 799 | New min: 2
# Pushed 168 with min context 2
# Popped 168 | New min: 2
# Pushed 899 with min context 2
# LinkedList Pairs:     0.043414 seconds
# Fastest: Array Two-Stack

# %% [markdown]
# ## Complete Complexity Analysis
#
# ### Time Complexity Comparison
#
# | Operation | Array Two-Stack | Array Pairs | LinkedList Two-Stack | LinkedList Pairs |
# |-----------|----------------|-------------|---------------------|------------------|
# | **push()** | O(1) | O(1) | O(1) | O(1) |
# | **pop()** | O(1) | O(1) | O(1) | O(1) |
# | **peek()** | O(1) | O(1) | O(1) | O(1) |
# | **getMin()** | O(1) | O(1) | O(1) | O(1) |
# | **isEmpty()** | O(1) | O(1) | O(1) | O(1) |
# | **size()** | O(1) | O(1) | O(1) | O(1) |
#
# ### Space Complexity Analysis
#
# | Implementation | Space per Element | Total Space | Auxiliary Space |
# |----------------|-------------------|-------------|-----------------|
# | **Array Two-Stack** | O(1) + O(1) for min* | O(n) | O(k) where k ≤ n |
# | **Array Pairs** | O(1) for value + O(1) for min | O(2n) | O(1) |
# | **LinkedList Two-Stack** | O(1) + pointer + O(1) for min* | O(n) + pointer overhead | O(k) where k ≤ n |
# | **LinkedList Pairs** | O(1) for value + O(1) for min + pointer | O(3n) + pointer overhead | O(1) |
#
# *Space optimization: min stack only stores elements when they are new minimums
#
# ### Memory Usage Details
#
# **Array Two-Stack Approach:**
# - **Best Case**: O(n) when all elements are in increasing order (min stack has only first element)
# - **Worst Case**: O(2n) when all elements are in decreasing order (both stacks full)
# - **Average Case**: O(1.5n) typical real-world usage
#
# **Array Pairs Approach:**
# - **All Cases**: O(2n) - consistent memory usage
# - Each element stores both value and minimum context
#
# **LinkedList Two-Stack Approach:**
# - **Best Case**: O(n) + pointer overhead when min stack is minimal
# - **Worst Case**: O(2n) + pointer overhead
# - **Pointer Overhead**: Additional 8 bytes per node on 64-bit systems
#
# **LinkedList Pairs Approach:**
# - **All Cases**: O(3n) + pointer overhead
# - Highest memory usage but simplest logic
#
# ### When to Use Each Approach
#
# | Scenario | Recommended Approach | Reason |
# |----------|---------------------|---------|
# | **Memory Critical** | Array Two-Stack | Most space efficient on average |
# | **Simplicity Priority** | Array Pairs | Easiest to understand and debug |
# | **Unknown Size** | LinkedList Two-Stack | Dynamic sizing with good memory efficiency |
# | **Rapid Prototyping** | LinkedList Pairs | Simplest implementation, no size limits |
# | **Cache Performance** | Array-based | Better cache locality |
# | **Concurrent Access** | LinkedList-based | Easier to make thread-safe |
#
# ### Real-world Considerations
#
# **For High-Performance Systems:**
# - Use Array Two-Stack for predictable memory usage
# - Consider cache line optimization for array approaches
# - Profile memory access patterns for your specific use case
#
# **For General Applications:**
# - Array Pairs offers good balance of simplicity and performance
# - LinkedList approaches better for highly dynamic scenarios
#
# **For Embedded Systems:**
# - Array Two-Stack minimizes memory fragmentation
# - Avoid LinkedList approaches due to pointer overhead
#
# **For Educational Purposes:**
# - Start with Array Pairs (easiest to understand)
# - Progress to Two-Stack approaches (more efficient)

# %% [markdown]
# ## Practical Applications and Use Cases
#
# ### 1. **Stock Price Analysis**
# Monitor stock prices and quickly find minimum price in current session:
#
# ```python
# # Pseudo-code for stock monitoring
# stock_monitor = MinStack()
# for price in real_time_prices:
#     stock_monitor.push(price)
#     current_min = stock_monitor.get_min()
#     if should_buy(current_min, price):
#         execute_buy_order()
# ```
#
# ### 2. **System Performance Monitoring**
# Track system metrics with quick access to minimum values:
#
# ```python
# # Monitor response times
# response_time_stack = MinStack()
# response_time_stack.push(get_current_response_time())
# min_response_time = response_time_stack.get_min()
# alert_if_degradation(min_response_time)
# ```
#
# ### 3. **Game Development**
# Track player scores or resource levels:
#
# ```python
# # Player health tracking with minimum threshold
# player_health_stack = MinStack()
# player_health_stack.push(current_health)
# if player_health_stack.get_min() < critical_threshold:
#     trigger_health_warning()
# ```
#
# ### 4. **Algorithm Optimization**
# Many algorithms benefit from quick minimum access:
#
# - **Sliding Window Minimum**: Process data streams with minimum tracking
# - **Expression Evaluation**: Track minimum operand values
# - **Dynamic Programming**: Optimize state transitions
# - **Graph Algorithms**: Shortest path calculations with minimum edge weights
#
# ### 5. **Data Stream Processing**
# Real-time analytics with minimum value tracking:
#
# ```python
# # Process incoming data stream
# data_stream_stack = MinStack()
# for data_point in stream:
#     data_stream_stack.push(data_point)
#     trend_analysis(data_stream_stack.get_min())
# ```
#
# ## Summary
#
# **Min Stack** is a powerful data structure that extends regular stack functionality with constant-time minimum element access. The choice of implementation depends on specific requirements:
#
# - **Use Array Two-Stack** for memory-critical applications
# - **Use Array Pairs** for simplicity and moderate memory usage
# - **Use LinkedList Two-Stack** for dynamic sizing with efficiency
# - **Use LinkedList Pairs** for maximum simplicity and unlimited growth
#
# All implementations maintain **O(1)** time complexity for core operations while providing different trade-offs in space complexity and implementation complexity.
#
# The Min Stack pattern is fundamental in many algorithmic solutions and system design scenarios, making it an essential tool for efficient data structure design.
